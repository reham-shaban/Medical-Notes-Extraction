# %% [markdown]
# # Preparing

# %%
import pandas as pd
import json
import ast
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter
#from wordcloud import WordCloud
import re

# %% [markdown]
# # loading the data

# %%
train = pd.read_csv("data/train.csv")
test = pd.read_csv("data/test.csv")

# %%
train.head()
# Out:
#    ID                                               Note  \
# 0   1  **Clinical Notes**\n\n**Patient Information:**...
# 1   2  Clinical Notes:\n\nPatient: 56-year-old male\n...
# 2   3  Clinical Notes:\n\nPatient: 73-year-old female...
# 3   4  **Clinical Notes**\n\n**Patient Information:**...
# 4   5  **Clinical Notes**\n\n**Patient:** Male, age 5...
#
#                                                 json
# 0  {"patient_info": {"age": 41, "gender": "Male"}...
# 1  {"patient_info": {"age": 56, "gender": "Male"}...
# 2  {"patient_info": {"age": 73, "gender": "Female...
# 3  {"patient_info": {"age": 32, "gender": "Female...
# 4  {"patient_info": {"age": 51, "gender": "Male"}...

# %%
train["Note"][100:150]
# Out:
# 100    Clinical Notes:\n\nPatient: 49-year-old male\n...
# 101    **Clinical Notes**\n\n**Patient Information:**...
# 102    **Clinical Notes**\n\nPatient, a 36-year-old m...
# 103    **Clinical Notes**\n\n**Patient Information:**...
# 104    **Clinical Notes:**\n\n**Patient Information:*...
# 105    **Clinical Notes**\n\n**Patient Information:**...
# 106    **Clinical Notes**\n\n**Patient Information:**...
# 107    **Clinical Notes**\n\nPatient [ID] (59 years o...
# 108    **Clinical Notes:**\n\n**Patient Information:*...
# 109    **Clinical Notes**\n\n**Patient Information:**...
# 110    **Clinical Notes**\n\nThe patient, an 98-year-...
# 111    **Clinical Notes**\n\n**Patient Information:**...
# 112    Clinical Notes:\n\nPatient Information:\n- Age...
# 113    **Clinical Notes:**\n\n**Patient Information:*...
# 114    **Clinical Notes:**\n\n**Patient Information:*...
# 115    **Clinical Notes:**\n\n**Patient Information:*...
# 116    **Clinical Notes**\n\n**Patient Information:**...
# 117    **Clinical Notes**\n\n**Patient Information:**...
# 118    **Clinical Notes**\n\n**Patient Information:**...
# 119    **Clinical Notes**\n\n**Patient Information:**...
# 120    **Clinical Notes**\n\nPatient Information:\nTh...
# 121    **Clinical Notes**\n\nPatient, a 35-year-old f...
# 122    **Clinical Notes**\n\n**Patient Information:**...
# 123    **Clinical Notes**\n\n**Patient Information:**...
# 124    **Clinical Notes**\n\n**Patient Information:**...
# 125    **Clinical Notes**\n\n**Patient Information:**...
# 126    **Clinical Notes**\n\n**Patient Information:**...
# 127    **Clinical Notes:**\n\n**Patient Information:*...
# 128    **Clinical Notes**\n\n**Patient Information:**...
# 129    **Clinical Notes:**\n\n**Patient Information:*...
# 130    Clinical Notes:\n\nPatient Profile:\nThe patie...
# 131    **Clinical Note**\n\n**Patient Info:**\n- Age:...
# 132    Clinical Notes:\n\nPatient Information:\n- Age...
# 133    Clinical Notes:\n\nPatient Profile:\nThe patie...
# 134    **Clinical Notes**\n\n**Patient Information:**...
# 135    Clinical Notes:\n\nPatient Profile:\nThe patie...
# 136    **Clinical Notes**\n\n**Patient Information:**...
# 137    **Clinical Notes**\n\n**Patient Information:**...
# 138    Clinical Note:\n\nPatient: 55-year-old male\nC...
# 139    Clinical Notes:\n\nPatient Profile:\nThe patie...
# 140    Clinical Notes:\n\nPatient Information:\n- Age...
# 141    Clinical Note:\n\nPatient: 17-year-old male\nC...
# 142    **Clinical Notes**\n\n**Patient Information:**...
# 143    Clinical Notes:\n\nPatient Profile:\nThe patie...
# 144    **Clinical Notes:**\n\n**Patient Information:*...
# 145    **Clinical Notes**\n\n**Patient Information:**...
# 146    Clinical Notes:\n\nPatient Information:\n- Age...
# 147    **Clinical Notes**\n\n**Patient Information:**...
# 148    **Clinical Notes**\n\n**Patient Information:**...
# 149    **Clinical Notes**\n\n**Patient Information:**...
# Name: Note, dtype: object

# %%
test.head()
# Out:
#       ID                                               Note
# 0  10823  **Clinical Notes**\n\n**Patient Information:**...
# 1  10824  **Clinical Notes**\n\n**Patient Information:**...
# 2  10825  Clinical Note:\n\nPatient: 71-year-old male\nC...
# 3  10826  **Clinical Notes**\n\n**Patient Information:**...
# 4  10827  **Clinical Notes**\n\n**Patient Information:**...

# %%
print("Train size: ", len(train))
print("Test size: ", len(test))
# Out:
# Train size:  10822
# Test size:  3796

# %% [markdown]
# **Checking out what an example note and JSON looks like**

# %%
print(train["Note"][0])
# Out:
# **Clinical Notes**
#
# **Patient Information:**
# - Age: 41 years old
# - Gender: Male
#
# **Visit Motivation:** Anemia evaluation
#
# **Chief Complaints and Symptoms:**
# The patient presents with complaints of anemia, fever, fatigue, difficulty breathing (dyspnea), vomiting, dizziness, blurred vision, wheezing, and pale skin. The patient reports that these symptoms have been progressively worsening over the past few weeks.
#
# **History of Present Illness:**
# - **Fever**: Intermittent low-grade fevers for approximately 2 weeks.
# - **Fatigue**: Persistent and severe fatigue affecting daily activities.
# - **Difficulty Breathing (Dyspnea)**: Experiencing shortness of breath, particularly with exertion. No history of chronic respiratory conditions.
# - **Vomiting**: Occasional episodes of non-bilious vomiting for the past week.
# - **Dizziness**: Episodes of dizziness, especially upon standing, which can be severe enough to cause near-fainting spells.
# - **Blurred Vision**: New onset of blurred vision, with occasional transient visual disturbances.
# - **Wheezing**: Recent history of wheezing noted by the patient during exertion or when lying down.
#
# **Review of Systems:**
# - Constitutional: Fatigue, fever
# - Respiratory: Dyspnea, wheezing
# - Gastrointestinal: Vomiting
# - Cardiovascular: Palpitations (not specifically reported but heart rate is elevated)
# - Neurological: Dizziness, blurred vision
#
# **Physical Examination:**
# - General Appearance: Patient appears pale and fatigued.
# - Vital Signs:
#   - Heart Rate: 114 bpm (tachycardia)
#   - Oxygen Saturation: 98.4% on room air
#   - Blood Pressure: BP not provided but should be assessed.
#   - Temperature: Not provided, but given the history of fever, elevated temperature should be considered.
#
# **Laboratory Findings and Vital Signs:**
# - **Hemoglobin**: Not directly measured in this note but anemia is noted as the visit motivation. Further workup for hemoglobin levels is necessary.
# - Cholesterol Level: 132.8 mg/dL (within normal range)
# - Glucose Level: 110.6 mg/dL (normal)
#
# **Assessment and Plan:**
# The patient presents with a constellation of symptoms including fever, fatigue, dyspnea, vomiting, dizziness, blurred vision, wheezing, and pale skin, all of which may be related to anemia or other underlying conditions. The elevated heart rate could be secondary to the anemia and/or inflammatory response.
#
# **Diagnosis Considerations:**
# 1. **Anemia**: Given the presentation of fatigue, dyspnea, and pale skin.
# 2. **Infectious Process**: Potential infectious etiology contributing to fever and tachycardia.
# 3. **Respiratory Issues**: Possible exacerbation of underlying respiratory conditions or secondary to anemia.
# 4. **Gastrointestinal Disturbances**: Vomiting may indicate gastrointestinal involvement.
#
# **Plan:**
# 1. Order complete blood count (CBC) with differential, reticulocyte count, and ferritin levels to assess the type and severity of anemia.
# 2. Consider ordering chest X-ray and pulmonary function tests if respiratory symptoms are prominent.
# 3. Monitor for signs of infection, including a CBC, CRP, and possibly cultures if clinically indicated.
# 4. Address gastrointestinal symptoms with further evaluation if necessary (e.g., stool studies, abdominal imaging).
# 5. Follow-up in 1-2 weeks or sooner based on the patient’s response to treatment and clinical status.
#
# **Nursing Care:**
# Monitor for signs of worsening anemia, dehydration from vomiting, and respiratory distress. Ensure adequate hydration and nutrition support as needed.

# %%
json.loads(train["json"][0])
# Out:
# {'patient_info': {'age': 41, 'gender': 'Male'},
#  'visit_motivation': 'Anemia',
#  'symptoms': ['fever',
#   'fatigue',
#   'difficulty_breathing',
#   'vomiting',
#   'dizziness',
#   'blurred_vision',
#   'wheezing',
#   'pale_skin'],
#  'vital_signs': {'heart_rate': {'value': 114, 'unit': 'bpm'},
#   'oxygen_saturation': {'value': 98.4, 'unit': '%'},
#   'cholesterol_level': {'value': 132.8, 'unit': 'mg/dL'},
#   'glucose_level': {'value': 110.6, 'unit': 'mg/dL'}}}

# %% [markdown]
# ## add json columns

# %%
# Parse the JSON column
extracted_json = train['json'].apply(json.loads)

# Create new columns from the parsed JSON
json_fields_df = pd.json_normalize(extracted_json)

# Concatenate the original structured_structured_dataFrame with the new fields
train_data = pd.concat([train, json_fields_df], axis=1)

# %%
json_fields_df.head()
# Out:
#     visit_motivation                                           symptoms  \
# 0             Anemia  [fever, fatigue, difficulty_breathing, vomitin...
# 1          Allergies  [runny_nose, sneezing, itchy_eyes, blurred_vis...
# 2  Diabetes (Type 2)  [fever, headache, difficulty_breathing, chest_...
# 3          Allergies  [fatigue, abdominal_pain, runny_nose, rash, jo...
# 4  Tuberculosis (TB)  [fever, cough, nausea, joint_pain, sneezing, f...
#
#    patient_info.age patient_info.gender  vital_signs.heart_rate.value  \
# 0                41                Male                         114.0
# 1                56                Male                           NaN
# 2                73              Female                          92.0
# 3                32              Female                          70.0
# 4                51                Male                           NaN
#
#   vital_signs.heart_rate.unit  vital_signs.oxygen_saturation.value  \
# 0                         bpm                                 98.4
# 1                         NaN                                  NaN
# 2                         bpm                                  NaN
# 3                         bpm                                 98.2
# 4                         NaN                                  NaN
#
#   vital_signs.oxygen_saturation.unit  vital_signs.cholesterol_level.value  \
# 0                                  %                                132.8
# 1                                NaN                                  NaN
# 2                                NaN                                173.0
# 3                                  %                                  NaN
# 4                                NaN                                125.7
#
#   vital_signs.cholesterol_level.unit  vital_signs.glucose_level.value  \
# 0                              mg/dL                            110.6
# 1                                NaN                             99.0
# 2                              mg/dL                            224.8
# 3                                NaN                            139.8
# 4                              mg/dL                             70.7
#
#   vital_signs.glucose_level.unit  vital_signs.temperature.value  \
# 0                          mg/dL                            NaN
# 1                          mg/dL                           36.6
# 2                          mg/dL                            NaN
# 3                          mg/dL                           36.9
# 4                          mg/dL                            NaN
#
#   vital_signs.temperature.unit  vital_signs.respiratory_rate.value  \
# 0                          NaN                                 NaN
# 1                           °C                                13.0
# 2                          NaN                                18.0
# 3                           °C                                19.0
# 4                          NaN                                19.0
#
#   vital_signs.respiratory_rate.unit  \
# 0                               NaN
# 1                       breaths/min
# 2                       breaths/min
# 3                       breaths/min
# 4                       breaths/min
#
#    vital_signs.blood_pressure.systolic.value  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                       97.0
# 4                                       92.0
#
#   vital_signs.blood_pressure.systolic.unit  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                     mmHg
# 4                                     mmHg
#
#    vital_signs.blood_pressure.diastolic.value  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                        79.0
# 4                                        74.0
#
#   vital_signs.blood_pressure.diastolic.unit
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                      mmHg
# 4                                      mmHg

# %%
#Resulting normalized columns for analysis
print(train_data.columns)
# Out:
# Index(['ID', 'Note', 'json', 'visit_motivation', 'symptoms',
#        'patient_info.age', 'patient_info.gender',
#        'vital_signs.heart_rate.value', 'vital_signs.heart_rate.unit',
#        'vital_signs.oxygen_saturation.value',
#        'vital_signs.oxygen_saturation.unit',
#        'vital_signs.cholesterol_level.value',
#        'vital_signs.cholesterol_level.unit', 'vital_signs.glucose_level.value',
#        'vital_signs.glucose_level.unit', 'vital_signs.temperature.value',
#        'vital_signs.temperature.unit', 'vital_signs.respiratory_rate.value',
#        'vital_signs.respiratory_rate.unit',
#        'vital_signs.blood_pressure.systolic.value',
#        'vital_signs.blood_pressure.systolic.unit',
#        'vital_signs.blood_pressure.diastolic.value',
#        'vital_signs.blood_pressure.diastolic.unit'],
#       dtype='object')

# %%
column_rename_map = {
    'visit_motivation':'visit motivation',
    'patient_info.age': 'age',
    'patient_info.gender': 'gender',
    'vital_signs.heart_rate.value': 'heart rate value',
    'vital_signs.heart_rate.unit': 'heart rate unit',
    'vital_signs.oxygen_saturation.value': 'oxygen saturation value',
    'vital_signs.oxygen_saturation.unit': 'oxygen saturation unit',
    'vital_signs.cholesterol_level.value': 'cholesterol level value',
    'vital_signs.cholesterol_level.unit': 'cholesterol level unit',
    'vital_signs.glucose_level.value': 'glucose level value',
    'vital_signs.glucose_level.unit': 'glucose level unit',
    'vital_signs.temperature.value': 'temperature value',
    'vital_signs.temperature.unit': 'temperature unit',
    'vital_signs.respiratory_rate.value': 'respiratory rate value',
    'vital_signs.respiratory_rate.unit': 'respiratory rate unit',
    'vital_signs.blood_pressure.systolic.value': 'blood pressure systolic value',
    'vital_signs.blood_pressure.systolic.unit': 'blood pressure systolic unit',
    'vital_signs.blood_pressure.diastolic.value': 'blood pressure diastolic value',
    'vital_signs.blood_pressure.diastolic.unit': 'blood pressure diastolic unit'
}

train_data.rename(columns=column_rename_map, inplace=True)

# %%
train_data.head()
# Out:
#    ID                                               Note  \
# 0   1  **Clinical Notes**\n\n**Patient Information:**...
# 1   2  Clinical Notes:\n\nPatient: 56-year-old male\n...
# 2   3  Clinical Notes:\n\nPatient: 73-year-old female...
# 3   4  **Clinical Notes**\n\n**Patient Information:**...
# 4   5  **Clinical Notes**\n\n**Patient:** Male, age 5...
#
#                                                 json   visit motivation  \
# 0  {"patient_info": {"age": 41, "gender": "Male"}...             Anemia
# 1  {"patient_info": {"age": 56, "gender": "Male"}...          Allergies
# 2  {"patient_info": {"age": 73, "gender": "Female...  Diabetes (Type 2)
# 3  {"patient_info": {"age": 32, "gender": "Female...          Allergies
# 4  {"patient_info": {"age": 51, "gender": "Male"}...  Tuberculosis (TB)
#
#                                             symptoms  age  gender  \
# 0  [fever, fatigue, difficulty_breathing, vomitin...   41    Male
# 1  [runny_nose, sneezing, itchy_eyes, blurred_vis...   56    Male
# 2  [fever, headache, difficulty_breathing, chest_...   73  Female
# 3  [fatigue, abdominal_pain, runny_nose, rash, jo...   32  Female
# 4  [fever, cough, nausea, joint_pain, sneezing, f...   51    Male
#
#    heart rate value heart rate unit  oxygen saturation value  ...  \
# 0             114.0             bpm                     98.4  ...
# 1               NaN             NaN                      NaN  ...
# 2              92.0             bpm                      NaN  ...
# 3              70.0             bpm                     98.2  ...
# 4               NaN             NaN                      NaN  ...
#
#   glucose level value  glucose level unit temperature value  temperature unit  \
# 0               110.6               mg/dL               NaN               NaN
# 1                99.0               mg/dL              36.6                °C
# 2               224.8               mg/dL               NaN               NaN
# 3               139.8               mg/dL              36.9                °C
# 4                70.7               mg/dL               NaN               NaN
#
#   respiratory rate value  respiratory rate unit blood pressure systolic value  \
# 0                    NaN                    NaN                           NaN
# 1                   13.0            breaths/min                           NaN
# 2                   18.0            breaths/min                           NaN
# 3                   19.0            breaths/min                          97.0
# 4                   19.0            breaths/min                          92.0
#
#    blood pressure systolic unit blood pressure diastolic value  \
# 0                           NaN                            NaN
# 1                           NaN                            NaN
# 2                           NaN                            NaN
# 3                          mmHg                           79.0
# 4                          mmHg                           74.0
#
#    blood pressure diastolic unit
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                           mmHg
# 4                           mmHg
#
# [5 rows x 23 columns]

# %% [markdown]
# Number of rows and columns

# %%
print(f"Dataset Shape: {train_data.shape}")
# Out:
# Dataset Shape: (10822, 23)

# %% [markdown]
# ## Data Types

# %%
print("Data Types:\n", train_data.dtypes)
# Out:
# Data Types:
#  ID                                  int64
# Note                               object
# json                               object
# visit motivation                   object
# symptoms                           object
# age                                 int64
# gender                             object
# heart rate value                  float64
# heart rate unit                    object
# oxygen saturation value           float64
# oxygen saturation unit             object
# cholesterol level value           float64
# cholesterol level unit             object
# glucose level value               float64
# glucose level unit                 object
# temperature value                 float64
# temperature unit                   object
# respiratory rate value            float64
# respiratory rate unit              object
# blood pressure systolic value     float64
# blood pressure systolic unit       object
# blood pressure diastolic value    float64
# blood pressure diastolic unit      object
# dtype: object

# %%
for column in [col for col in train_data.columns if 'unit' in col]:
    print(f"Unique values in {column}: {train_data[column].unique()}")
# Out:
# Unique values in heart rate unit: ['bpm' nan]
# Unique values in oxygen saturation unit: ['%' nan]
# Unique values in cholesterol level unit: ['mg/dL' nan]
# Unique values in glucose level unit: ['mg/dL' nan]
# Unique values in temperature unit: [nan '°C']
# Unique values in respiratory rate unit: [nan 'breaths/min']
# Unique values in blood pressure systolic unit: [nan 'mmHg']
# Unique values in blood pressure diastolic unit: [nan 'mmHg']

# %% [markdown]
# Change the data type of objects

# %%
#to string
train_data['Note'] = train_data['Note'].astype('string')
train_data['visit motivation'] = train_data['visit motivation'].astype('string')
#to list

#to category
units_columns = [
    'gender',
    'heart rate unit',
    'oxygen saturation unit',
    'cholesterol level unit',
    'glucose level unit',
    'temperature unit',
    'respiratory rate unit',
    'blood pressure systolic unit',
    'blood pressure diastolic unit'
]
for col in units_columns:
    train_data[col] = train_data[col].astype('category')

# %%
print(train_data.select_dtypes(include='object').columns)
# Out:
# Index(['json', 'symptoms'], dtype='object')

# %%
print(train_data.dtypes)
# Out:
# ID                                         int64
# Note                              string[python]
# json                                      object
# visit motivation                  string[python]
# symptoms                                  object
# age                                        int64
# gender                                  category
# heart rate value                         float64
# heart rate unit                         category
# oxygen saturation value                  float64
# oxygen saturation unit                  category
# cholesterol level value                  float64
# cholesterol level unit                  category
# glucose level value                      float64
# glucose level unit                      category
# temperature value                        float64
# temperature unit                        category
# respiratory rate value                   float64
# respiratory rate unit                   category
# blood pressure systolic value            float64
# blood pressure systolic unit            category
# blood pressure diastolic value           float64
# blood pressure diastolic unit           category
# dtype: object

# %% [markdown]
# Missing Values

# %%
print("Missing Values:\n", train_data.isnull().sum())
# Out:
# Missing Values:
#  ID                                   0
# Note                                 0
# json                                 0
# visit motivation                     0
# symptoms                             0
# age                                  0
# gender                               0
# heart rate value                  5045
# heart rate unit                   5045
# oxygen saturation value           5238
# oxygen saturation unit            5238
# cholesterol level value           5495
# cholesterol level unit            5495
# glucose level value               5402
# glucose level unit                5402
# temperature value                 4911
# temperature unit                  4911
# respiratory rate value            5171
# respiratory rate unit             5171
# blood pressure systolic value     5532
# blood pressure systolic unit      5532
# blood pressure diastolic value    5532
# blood pressure diastolic unit     5532
# dtype: int64

# %% [markdown]
# unique values

# %%
for column in train_data.columns:
    if column == 'symptoms':

        temp_column = train_data[column].apply(lambda x: ', '.join(x) if isinstance(x, list) else str(x))
        unique_values = temp_column.nunique()
    else:
        unique_values = train_data[column].nunique()
    
    print(f"{column}: {unique_values} unique values")
# Out:
# ID: 10822 unique values
# Note: 10822 unique values
# json: 10822 unique values
# visit motivation: 20 unique values
# symptoms: 10814 unique values
# age: 86 unique values
# gender: 2 unique values
# heart rate value: 81 unique values
# heart rate unit: 1 unique values
# oxygen saturation value: 142 unique values
# oxygen saturation unit: 1 unique values
# cholesterol level value: 751 unique values
# cholesterol level unit: 1 unique values
# glucose level value: 1057 unique values
# glucose level unit: 1 unique values
# temperature value: 32 unique values
# temperature unit: 1 unique values
# respiratory rate value: 19 unique values
# respiratory rate unit: 1 unique values
# blood pressure systolic value: 82 unique values
# blood pressure systolic unit: 1 unique values
# blood pressure diastolic value: 57 unique values
# blood pressure diastolic unit: 1 unique values

# %% [markdown]
# Value Counts

# %%
for column in ['gender']:  
    print(f"Value Counts for {column}:\n", train_data[column].value_counts())
# Out:
# Value Counts for gender:
#  gender
# Female    5437
# Male      5385
# Name: count, dtype: int64

# %%
for column in ['visit motivation']:  
    print(f"Value Counts for {column}:\n", train_data[column].value_counts())
# Out:
# Value Counts for visit motivation:
#  visit motivation
# Urinary Tract Infection (UTI)                   598
# Hypertension (High Blood Pressure)              593
# Allergies                                       584
# Gastroesophageal Reflux Disease (GERD)          582
# Eczema (Atopic Dermatitis)                      578
# Anxiety Disorders                               571
# Strep Throat                                    567
# Influenza (Flu)                                 559
# Tuberculosis (TB)                               535
# Depression                                      533
# Diabetes (Type 2)                               533
# Ear Infection (Otitis Media)                    533
# Anemia                                          525
# Heart Disease (Coronary Artery Disease)         512
# Pneumonia                                       511
# Sinusitis                                       510
# Chronic Obstructive Pulmonary Disease (COPD)    504
# Asthma                                          502
# Common Cold                                     498
# COVID-19                                        494
# Name: count, dtype: Int64

# %% [markdown]
# split train data and test data

# %%
train_data, test_data = train_test_split(train_data, test_size=0.2, random_state=42)

print(f"Train data size: {len(train_data)}")
print(f"Test data size: {len(test_data)}")
# Out:
# Train data size: 8657
# Test data size: 2165

# %% [markdown]
# # Data analysis

# %% [markdown]
# Descriptive Statistics

# %%
print("Descriptive Statistics:\n", train_data.describe())
# Count: عدد القيم غير المفقودة في كل عمود.
# Mean: المتوسط الحسابي للقيم في العمود.
# Std: الانحراف المعياري (يُظهر مدى تباعد القيم عن المتوسط).
# Min: القيمة الصغرى في العمود.
# 25%: الربع الأول (25% من البيانات أقل من هذه القيمة).
# 50% (Median): الوسيط (50% من البيانات أقل من هذه القيمة).
# 75%: الربع الثالث (75% من البيانات أقل من هذه القيمة).
# Max: القيمة الكبرى في العمود.
# Out:
# Descriptive Statistics:
#                   ID          age  heart rate value  oxygen saturation value  \
# count   8657.000000  8657.000000       4633.000000              4465.000000
# mean    5419.029571    48.415155         85.836175                96.292228
# std     3121.974939    23.459486         18.376265                 3.277364
# min        2.000000    15.000000         60.000000                85.000000
# 25%     2699.000000    28.000000         72.000000                95.600000
# 50%     5442.000000    46.000000         83.000000                97.100000
# 75%     8123.000000    65.000000         95.000000                98.500000
# max    10820.000000   100.000000        140.000000               100.000000
#
#        cholesterol level value  glucose level value  temperature value  \
# count              4283.000000          4334.000000        4726.000000
# mean                161.607074           114.546585          37.425011
# std                  21.570895            40.921420           0.896734
# min                 125.000000            70.000000          36.500000
# 25%                 142.600000            88.600000          36.800000
# 50%                 161.700000           107.900000          37.100000
# 75%                 179.900000           126.775000          37.400000
# max                 199.900000           299.900000          40.000000
#
#        respiratory rate value  blood pressure systolic value  \
# count             4496.000000                    4196.000000
# mean                16.727091                     109.255958
# std                  3.366396                      16.596430
# min                 12.000000                      90.000000
# 25%                 14.000000                      98.000000
# 50%                 16.000000                     106.000000
# 75%                 19.000000                     114.000000
# max                 30.000000                     180.000000
#
#        blood pressure diastolic value
# count                     4196.000000
# mean                        72.791230
# std                         10.956248
# min                         60.000000
# 25%                         65.000000
# 50%                         71.000000
# 75%                         76.000000
# max                        120.000000

# %% [markdown]
# ## Charts

# %% [markdown]
# Distribution of Age

# %%
sns.histplot(train_data['age'], kde=True)
plt.title('Distribution of Age')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()
# Out:
# c:\Users\EUROPELAPTOP\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# Count the values ​​in each category

# %%
train_data['gender'].value_counts().plot(kind='bar')
plt.title('Gender Distribution')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()

# %%
train_data['visit motivation'].value_counts().plot(kind='bar')
plt.title('visit motivation Distribution')
plt.xlabel('visit motivation')
plt.ylabel('Count')
plt.show()

# %%
train_data['symptoms'] = train_data['symptoms'].apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else x)

symptoms_flat = [symptom for sublist in train_data['symptoms'] if isinstance(sublist, list) for symptom in sublist]

symptom_counts = Counter(symptoms_flat)

plt.figure(figsize=(10, 8)) 
sns.barplot(x=list(symptom_counts.values()), y=list(symptom_counts.keys()))

plt.title('Most Common Symptoms', fontsize=16)
plt.xlabel('Frequency', fontsize=14)
plt.ylabel('Symptoms', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

plt.show()
# Out:
# c:\Users\EUROPELAPTOP\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1765: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   order = pd.unique(vector)

# %% [markdown]
# ## WordCloud

# %%
# Collect texts from notes and json column
notes_text = " ".join(train_data['Note'].dropna())
json_text = " ".join(train_data['json'].dropna())

# Split texts into words
notes_words = notes_text.split()
json_words = json_text.split()

# Count repeated words
notes_counter = Counter(notes_words)
json_counter = Counter(json_words)

# %%
# Extract unique and duplicate words
unique_notes_words = set(notes_words) - set(json_words)  # notes
unique_json_words = set(json_words) - set(notes_words)  # json
common_words = set(notes_words).intersection(set(json_words))  # Common words

# %%
# drawing Word Cloud for all words in notes
wordcloud_notes = WordCloud(width=800, height=400, background_color='white').generate(notes_text)

plt.figure(figsize=(12, 8))
plt.imshow(wordcloud_notes, interpolation='bilinear')
plt.axis('off')
plt.title("Word Cloud for Notes (All Words)", fontsize=16)
plt.show()

# %%
#drawing Word Cloud only for unique words in notes
wordcloud_unique_notes = WordCloud(width=800, height=400, background_color='white').generate(" ".join(unique_notes_words))

plt.figure(figsize=(12, 8))
plt.imshow(wordcloud_unique_notes, interpolation='bilinear')
plt.axis('off')
plt.title("Unique Words in Notes (Not in JSON)", fontsize=16)
plt.show()

# %%
#drawing Word Cloud  for words shared between notes and json
wordcloud_common = WordCloud(width=800, height=400, background_color='white').generate(" ".join(common_words))

plt.figure(figsize=(12, 8))
plt.imshow(wordcloud_common, interpolation='bilinear')
plt.axis('off')
plt.title("Common Words between Notes and JSON", fontsize=16)
plt.show()

# %%
#Display statistics
print("Top 20 Most Common Words in Notes:")
print(notes_counter.most_common(20))

print("\nTop 20 Most Common Words in JSON:")
print(json_counter.most_common(20))

print("\nWords in Notes but not in JSON (Unique to Notes):")
print(list(unique_notes_words)[:20])

print("\nWords in JSON but not in Notes (Unique to JSON):")
print(list(unique_json_words)[:20])
# Out:
# Top 20 Most Common Words in Notes:
# [('-', 109233), ('and', 105243), ('of', 66254), ('the', 55185), ('to', 55156), ('a', 46761), ('The', 44824), ('or', 33213), ('patient', 31384), ('for', 29983), ('with', 29291), ('symptoms', 28390), ('*', 24505), ('is', 22491), ('be', 20119), ("patient's", 19510), ('may', 13758), ('normal', 13461), ('in', 12872), ('on', 12838)]
#
# Top 20 Most Common Words in JSON:
# [('{"value":', 35329), ('"unit":', 35329), ('{"patient_info":', 8657), ('{"age":', 8657), ('"gender":', 8657), ('"visit_motivation":', 8657), ('"symptoms":', 8657), ('"vital_signs":', 8657), ('"mg/dL"}}}', 6531), ('"\\u00b0C"},', 4599), ('"Female"},', 4353), ('"bpm"},', 4331), ('"Male"},', 4304), ('"glucose_level":', 4276), ('"oxygen_saturation":', 4236), ('{"blood_pressure":', 4196), ('{"systolic":', 4196), ('"mmHg"},', 4196), ('"diastolic":', 4196), ('"cholesterol_level":', 4166)]
#
# Words in Notes but not in JSON (Unique to Notes):
# ['mostly', '**Elevated', '**Nausea**,', '114/69', 'Conjunctiva', 'empyema.', '(103.6°F)', 'avoid', '**GERD-related', 'g', '12-20),', 'reassess', '148.4', '(out-of-range', '(95.7', 'believes', '100/80', 'hypothyroidism,', '98.3%.', '(4/10),']
#
# Words in JSON but not in Notes (Unique to JSON):
# ['106.0,', '152.0,', '115.1,', '243.6,', '146.8,', '166.3,', '73.4,', '117.4,', '90.9,', '{"respiratory_rate":', '170.8,', '114.3,', '83.7,', '91.4,', '38.2,', '194.5,', '296.1,', '108.4,', '83,', '157.5,']

# %% [markdown]
# ## Finding patterns

# %%
train_data.isna().sum()
# Out:
# ID                                   0
# Note                                 0
# json                                 0
# visit motivation                     0
# symptoms                             0
# age                                  0
# gender                               0
# heart rate value                  4024
# heart rate unit                   4024
# oxygen saturation value           4192
# oxygen saturation unit            4192
# cholesterol level value           4374
# cholesterol level unit            4374
# glucose level value               4323
# glucose level unit                4323
# temperature value                 3931
# temperature unit                  3931
# respiratory rate value            4161
# respiratory rate unit             4161
# blood pressure systolic value     4461
# blood pressure systolic unit      4461
# blood pressure diastolic value    4461
# blood pressure diastolic unit     4461
# dtype: int64

# %%
# Function to find notes missing any age pattern
def find_missing_pattern_notes(Notes, patterns):
    """
    Identifies notes that do not match any of the expected age patterns.

    Args:
        df (pd.Dataframe): A pandas Datafram containing medical notes column.
        patterns (list): A list of regex patterns for column (age).

    Returns:
        set: A set of notes with no age pattern matches.
    """
    missed_notes = []

    for note in Notes:
        if not any(re.search(pattern, note, re.IGNORECASE) for pattern in patterns):
            missed_notes.append(note)

    return missed_notes

# %% [markdown]
# ### age

# %%
age_patterns = [
    r'age[: ]+(\d+)',
    r'\*\*Age\*\*[: ]+(\d+)',
    r'\*\*Age:\*\*\s+(\d+)',
    r'\*\*Age/Gender:\*\*\s*(\d+)',
    r'(\d+)[-\s]?years?[-\s]?old',
    r'age is (\d+)',
    r'(\d+)\s*yo\b',
    r'(\d+) years?',
    r'age \(?(\d+)\)?',
    r'(\d+)[FM]',
]

# %%
# Find notes missing age patterns
missed_age_notes = find_missing_pattern_notes(train["Note"], expected_age_pattern)

# Display the missed notes
print("Notes missing information count: ", len(missed_age_notes))
# Out:
# Notes missing age information count:  9

# %%
missed_age_notes
# Out:
# ["**Clinical Notes**\n\nPatient presented with a history of eczema (atopic dermatitis) and current complaints of rash, painful urination, and dry skin.\n\nVital signs:\n\n* Blood pressure: 95/76 mmHg (systolic/diastolic)\n* Heart rate: 65 bpm\n* Respiratory rate: 17 breaths/min\n* Oxygen saturation: 96.5% (normal)\n* Cholesterol level: 145.8 mg/dL (elevated)\n* Glucose level: 122.6 mg/dL (mildly elevated)\n\nNotably, the patient's blood pressure is slightly low, which may be related to the eczema. The elevated cholesterol and glucose levels suggest the presence of a metabolic component to this case.\n\nGiven the combination of symptoms and lab results, I am making a diagnosis of **eczema (atopic dermatitis) complicated by hypertension, dyslipidemia, and mild hyperglycemia**.\n\nThe patient's painful urination suggests possible urinary tract involvement or secondary infection. Further evaluation with urinalysis and possibly imaging studies may be necessary to determine the cause of this symptom.\n\nThe rash is consistent with eczema, but further examination is needed to assess its severity and potential for complications such as infection or scarring.\n\nI recommend initiating treatment with topical corticosteroids for the eczema and considering referral to a dermatologist for further evaluation and management. Additionally, lifestyle modifications such as dietary changes and increased hydration may be necessary to manage blood pressure, cholesterol, and glucose levels.\n\n**Plan**\n\n* Initiate topical corticosteroids (e.g., triamcinolone acetonide 0.1%) for eczema\n* Refer patient to dermatologist for further evaluation and management\n* Consider referral to endocrinology or cardiology for hypertension, dyslipidemia, and mild hyperglycemia\n* Educate patient on lifestyle modifications (dietary changes, increased hydration) to manage metabolic components\n* Schedule follow-up appointment in 2-4 weeks to reassess symptoms and adjust treatment plan as necessary.",
#  "**Clinical Notes**\n\nPatient presented to the emergency department with a history of hypertension, and upon further evaluation, exhibited several concerning symptoms.\n\nThe patient, an elderly male aged 98, reported a series of symptoms including headache, difficulty breathing, chest pain, abdominal pain, dizziness, sneezing, itchy eyes, blurred vision, swollen lymph nodes, and heartburn. Notably, the patient's primary complaint was hypertension, but the breadth and severity of his presenting symptoms warrant further investigation.\n\nUpon assessment, the patient's temperature was 36.5°C, which is slightly elevated. His cholesterol level was found to be significantly elevated at 186.2 mg/dL.\n\nGiven the patient's age, history of hypertension, and the presence of multiple systemic symptoms, a diagnosis of **Pulmonary Embolism with Secondary Hypertension** is proposed. The patient's vitals, including an elevated temperature and cholesterol level, suggest a possible infectious or inflammatory component to his presentation.\n\nThe patient will require immediate attention in the intensive care unit for further evaluation and management. A computed tomography pulmonary angiogram (CTPA) is ordered to confirm the diagnosis of pulmonary embolism and assess for any additional complications.\n\n**Differential Diagnosis**: Given the patient's age and comorbidities, other potential diagnoses such as dehydration, sepsis, or acute coronary syndrome must also be considered. **Workup in Progress**\n\n**Medications**: Anticoagulation therapy will be initiated immediately to prevent further thromboembolic events.\n\n**Follow-up**: The patient will require close monitoring and follow-up appointments to evaluate the effectiveness of treatment and address any potential complications.",
#  "**Clinical Notes**\n\nPatient presented with a chief complaint of allergies and a history of similar symptoms. Physical examination revealed a male patient aged 33, who is currently experiencing the following symptoms:\n\n- Fever\n- Cough\n- Runny nose\n- Sneezing\n- Itchy eyes\n- Increased thirst\n- Night sweats\n- Facial pain\n- Pale skin\n\nVital signs were obtained and are as follows:\n- Temperature: 36.8°C, which is slightly elevated but not in a critically concerning range.\n- Heart rate: 63 bpm, within normal limits.\n- Cholesterol level: 125.5 mg/dL, which is above the average range.\n\nConsidering the patient's symptoms and vital signs, I am concerned that this may be an allergic reaction to something environmental or external. The fever and night sweats suggest a possible infectious component, but the elevated cholesterol level raises concerns about potential cardiovascular implications.\n\nGiven the constellation of symptoms, I would like to order further testing, including:\n- Complete Blood Count (CBC) to assess for any signs of infection or inflammation.\n- Allergy panel to identify potential allergens.\n- Lipid profile to further evaluate cholesterol levels and rule out any underlying metabolic disorders.\n- Skin prick test to confirm the presence of an allergic reaction.\n\nBased on this information, I would like to schedule a follow-up appointment in one week to reassess the patient's condition.",
#  "**Clinical Notes**\n\nPatient presented with a chief complaint of Diabetes (Type 2) and is now experiencing a range of concerning symptoms including fever, fatigue, difficulty breathing, vomiting, abdominal pain, rash, increased thirst, and blurred vision. Upon further evaluation, the patient's vital signs reveal an elevated respiratory rate of 18 breaths/min, suggesting potential respiratory distress.\n\nThe patient's cholesterol level is also notable at 143.8 mg/dL, which is above the desired range. This finding raises concerns for cardiovascular complications in a patient with diabetes.\n\nGiven the combination of respiratory symptoms and abnormal vital signs, I am inclined to suspect an infectious etiology such as pneumonia or sepsis, particularly given the patient's underlying diabetes. The rash and increased thirst are also concerning for a possible urinary tract infection or diabetic ketoacidosis.\n\nI would like to proceed with further evaluation, including ordering laboratory tests (e.g., complete blood count, comprehensive metabolic panel) and imaging studies (e.g., chest X-ray) to better assess the patient's condition and guide potential treatment.",
#  "**Clinical Notes**\n\nPatient presented with a chief complaint of anxiety disorders and a multitude of symptoms that have been distressing him lately.\n\n**Vital Signs:**\n- Temperature: 36.8°C, which is slightly elevated.\n- Other vital signs are within normal limits.\n\n**Subjective Symptoms:**\nThe patient reports experiencing:\n- A persistent headache\n- Sore throat\n- Abdominal pain\n- Dizziness on multiple occasions\n- Night sweats\n- Facial pain\n- Persistent feelings of sadness and anxiety\n- Restlessness, making it difficult for him to concentrate\n\nGiven the combination and severity of these symptoms, I am inclined to consider a diagnosis that may involve an underlying medical condition contributing to his anxiety disorders. Further investigation is required to determine a definitive cause.\n\n**Assessment:**\nThe elevated temperature could indicate an underlying infection or inflammatory process. However, without further diagnostic testing, it's difficult to pinpoint the exact cause of these symptoms.\n\n**Recommendations:**\n- Order a comprehensive physical examination\n- Conduct routine laboratory tests including complete blood count (CBC), electrolytes, and liver function tests\n- Consider imaging studies such as a chest X-ray or abdominal ultrasound if necessary\n\nThe patient will be scheduled for follow-up to reassess his condition.",
#  "**Clinical Notes**\n\nPatient: [Redacted for confidentiality]\n\n**Chief Complaint:** Chronic Obstructive Pulmonary Disease (COPD)\n\n**History of Present Illness:** The patient presents with a 2-week history of worsening shortness of breath, coughing up yellow sputum, and chest pain. These symptoms have progressively worsened over the past week, leading to significant distress.\n\n**Physical Examination:**\n\n- **Vital Signs:** \n  * Temperature: 36.9°C (normal)\n  * Heart Rate: 94 bpm (elevated)\n  * Respiratory Rate: 15 breaths/min (mildly elevated, but not concerning for respiratory failure at this point)\n  * Oxygen Saturation: 98.6% (normal)\n  * Glucose Level: 73.5 mg/dL (within normal limits)\n\n- **Cardiovascular:** The patient's heart rate is elevated, which could be indicative of anxiety or a compensatory mechanism.\n\n- **Respiratory:** The patient experiences significant shortness of breath and coughs up yellow sputum, suggesting an acute exacerbation of COPD. Chest pain may indicate pulmonary embolism or atypical chest pain patterns, warranting further evaluation.\n\n- **Neurological:** The patient reports difficulty concentrating, which could be related to the chronic nature of their condition or potential hypoxemia.\n\n**Additional Notes:**\n\n- The patient's loss of taste and smell is a red flag symptom that may indicate COVID-19 infection.\n- Frequent urination could be a sign of overactive bladder or diabetes-related issues, given the patient's glucose level is within normal limits but not entirely ruling out diabetic nephropathy.\n- Blurred vision is concerning for possible optic neuritis or hypoxemia.\n\n**Assessment and Plan:**\n\n- The patient will require oxygen therapy to support their respiratory status and alleviate hypoxemia.\n- Regular monitoring of vital signs, including respiratory rate, heart rate, and oxygen saturation, will be necessary to reassess the patient's condition.\n- Further testing for COVID-19, pneumonia, or pulmonary embolism may be warranted based on the patient's symptoms and vitals.\n- The patient will also benefit from a comprehensive review of their COPD management plan, including medication adjustments as needed.\n\n**Next Steps:** Consultation with the pulmonologist to manage acute exacerbations of COPD.",
#  "**Clinical Notes**\n\nPatient presents with a chief complaint of tuberculosis (TB). Upon further evaluation, the patient reports:\n\n* A prolonged cough lasting for several days, which worsens at night\n* Headache and sore throat, indicating possible respiratory involvement\n* Nausea and vomiting, suggesting potential gastrointestinal involvement or systemic symptoms\n* Runny nose, consistent with a respiratory infection\n* Dizziness on multiple occasions, raising concern for neurological or cardiovascular involvements\n* Loss of taste and smell, indicative of potentially severe respiratory disease\n* Ear pain, which may be related to Eustachian tube dysfunction or middle ear involvement\n\nVital signs reveal:\n\n* Elevated respiratory rate at 19 breaths/min (normal range: 12-20 breaths/min), indicating possible acute respiratory distress\n* Moderate oxygen saturation at 96.3% (normal range: 95-100%), suggesting some degree of hypoxemia\n* Elevated cholesterol level at 142.8 mg/dL (normal range: 100-200 mg/dL), which may be a sign of chronic inflammation or metabolic dysregulation\n* Normal glucose level at 96.1 mg/dL (normal range: 70-110 mg/dL)\n\nConsidering the patient's age, symptoms, and vital signs, the clinical picture suggests an acute exacerbation of tuberculosis, with potential involvement of respiratory and gastrointestinal systems. Further diagnostic testing, including sputum cultures and imaging studies, will be necessary to confirm the diagnosis and guide treatment decisions.",
#  "**Clinical Notes**\n\nPatient presented with a history of COVID-19, who is currently experiencing a range of symptoms including fever (38.3°C), cough, fatigue, headache, difficulty breathing, chest pain, abdominal pain, joint pain, sneezing, blurred vision, night sweats, facial pain, and ear pain.\n\nUpon assessment of vital signs, the patient's oxygen saturation was noted to be 88.3%, which is below normal limits (90-94%). This finding warrants further investigation for potential respiratory compromise.\n\nLaboratory results also revealed elevated cholesterol levels at 174.2 mg/dL and glucose levels at 137.9 mg/dL. These findings are concerning for metabolic syndrome, particularly in the context of an acute illness like COVID-19.\n\nThe patient's symptoms and laboratory results collectively suggest a diagnosis of COVID-19 with respiratory involvement, likely pneumonia. The presence of systemic symptoms such as fever, fatigue, and joint pain may indicate a more severe infection or a co-infection. Further testing, including chest imaging and potentially a lumbar puncture, may be necessary to determine the extent of the infection.\n\nIt is also worth noting that the patient's elevated cholesterol levels and glucose levels raise concerns for long-term cardiovascular risk. The patient should be educated on lifestyle modifications to mitigate these risks and referred to a cardiologist for further evaluation if necessary.\n\n**Initial Treatment Plan**\n\n* Continue COVID-19 treatment as prescribed by previous healthcare providers.\n* Administer oxygen therapy to maintain an oxygen saturation of 90% or greater.\n* Prescribe antiviral medication as indicated by local health guidelines.\n* Refer patient to a cardiologist for evaluation and management of elevated cholesterol levels and glucose levels.\n\n**Next Steps**\n\n* Order chest imaging (CT scan or X-ray) to evaluate for pneumonia or other respiratory complications.\n* Perform a lumbar puncture if symptoms suggest meningitis or encephalitis.\n* Schedule follow-up appointment in 1-2 weeks to reassess patient's condition and adjust treatment plan as needed.",
#  "**Clinical Notes**\n\nPatient presents with a chief complaint of Tuberculosis (TB) and is experiencing a variety of systemic symptoms that are concerning for an active pulmonary infection.\n\nThe patient's vital signs reveal:\n\n* Blood pressure: Systolic 118/62 mmHg, which is within normal limits but slightly elevated, considering the patient's suspected acute infection.\n* Temperature: 37.0°C, which is slightly low and could indicate a recent infection or inflammatory process.\n* Oxygen saturation: 97.0%, which is within normal limits but slightly decreased, possibly indicating some degree of chronic lung disease or smoking history.\n* Cholesterol level: 158.7 mg/dL, which is elevated and warrants further investigation, particularly in the context of a suspected infectious process.\n\nThe patient's symptoms are quite concerning and suggest an active infection. The presence of cough, fatigue, dizziness, night sweats, weight loss, and swollen lymph nodes is consistent with pulmonary tuberculosis. The recent onset of itchy eyes, loss of taste and smell, and difficulty concentrating suggests involvement of the central nervous system.\n\nGiven the patient's symptoms and laboratory findings, a diagnosis of active pulmonary tuberculosis with possible extrapulmonary manifestations (e.g., CNS involvement) is considered. Further testing, including sputum smear and culture for TB, chest X-ray, and potentially CT scan or PET/CT, would be necessary to confirm the diagnosis and assess the extent of disease.\n\n**Additional Notes:**\n\n* Patient's history of smoking and possible exposure to TB in the past increases the risk of infection.\n* The patient's physical examination should include a thorough assessment of respiratory and lymphatic systems to identify any signs of extrapulmonary involvement.\n* Further laboratory tests, such as ANA, rheumatoid factor, and erythrocyte sedimentation rate (ESR), may be warranted to evaluate the possibility of an autoimmune component to the patient's symptoms.\n\n**Recommended Course of Action:**\n\n* Administer isoniazid monotherapy according to local TB treatment guidelines.\n* Schedule follow-up appointments for sputum smear and culture, chest X-ray, and potential CT or PET/CT scan.\n* Refer the patient to a specialist (e.g., pulmonologist) for further evaluation and management."]

# %% [markdown]
# ### gender

# %%
gender_patterns = [
    r'\b(male|female)\b',
    r'\d+(F|M)',
]

# %%
# Find notes missing age patterns
missed_gender_notes = find_missing_pattern_notes(train["Note"], gender_patterns)

# Display the missed notes
print("Notes missing information count: ", len(missed_gender_notes))
# Out:
# Notes missing age information count:  21

# %%
missed_gender_notes
# Out:
# ["**Clinical Notes**\n\nPatient presents with COVID-19 symptoms, highlighting the severity of his condition. \n\nUpon examination, patient's vital signs reveal:\n\n* Blood pressure: Systolic 113/80 mmHg (mildly elevated)\n* Temperature: 38.9°C (fever indicating infection)\n* Respiratory rate: 15 breaths/min (slightly increased)\n\nSymptomatically, the patient reports:\n* Fever\n* Cough\n* Fatigue\n* Difficulty breathing (indicative of respiratory distress)\n* Abdominal pain\n* Dizziness\n* Sneezing\n* Loss of taste and smell\n* Increased thirst\n* Blurred vision\n* Painful urination\n* Dry skin\n\nNotable, the patient's age (75) and comorbidities are not explicitly documented. However, it is essential to consider potential underlying health conditions that may exacerbate his condition.\n\nConsidering these findings, a likely diagnosis of COVID-19-induced acute respiratory distress with secondary complications (e.g., hypertension, dehydration, and electrolyte imbalances) is warranted. Further evaluation and management will be necessary to ensure optimal patient outcomes.\n\n**Initial Management Plan:**\n\n* Oxygen therapy with supplemental oxygen as needed\n* Antipyretics for fever control\n* Anti-histamines or bronchodilators for cough and shortness of breath\n* Fluid replacement with intravenous hydration\n* Monitoring of vital signs, laboratory results, and electrocardiogram (ECG)\n* Consideration of antiviral therapy if COVID-19 diagnosis is confirmed",
#  "**Clinical Notes**\n\nPatient presented with a history of eczema (atopic dermatitis) and current complaints of rash, painful urination, and dry skin.\n\nVital signs:\n\n* Blood pressure: 95/76 mmHg (systolic/diastolic)\n* Heart rate: 65 bpm\n* Respiratory rate: 17 breaths/min\n* Oxygen saturation: 96.5% (normal)\n* Cholesterol level: 145.8 mg/dL (elevated)\n* Glucose level: 122.6 mg/dL (mildly elevated)\n\nNotably, the patient's blood pressure is slightly low, which may be related to the eczema. The elevated cholesterol and glucose levels suggest the presence of a metabolic component to this case.\n\nGiven the combination of symptoms and lab results, I am making a diagnosis of **eczema (atopic dermatitis) complicated by hypertension, dyslipidemia, and mild hyperglycemia**.\n\nThe patient's painful urination suggests possible urinary tract involvement or secondary infection. Further evaluation with urinalysis and possibly imaging studies may be necessary to determine the cause of this symptom.\n\nThe rash is consistent with eczema, but further examination is needed to assess its severity and potential for complications such as infection or scarring.\n\nI recommend initiating treatment with topical corticosteroids for the eczema and considering referral to a dermatologist for further evaluation and management. Additionally, lifestyle modifications such as dietary changes and increased hydration may be necessary to manage blood pressure, cholesterol, and glucose levels.\n\n**Plan**\n\n* Initiate topical corticosteroids (e.g., triamcinolone acetonide 0.1%) for eczema\n* Refer patient to dermatologist for further evaluation and management\n* Consider referral to endocrinology or cardiology for hypertension, dyslipidemia, and mild hyperglycemia\n* Educate patient on lifestyle modifications (dietary changes, increased hydration) to manage metabolic components\n* Schedule follow-up appointment in 2-4 weeks to reassess symptoms and adjust treatment plan as necessary.",
#  "**Clinical Notes**\n\nPatient presents with a sudden onset of respiratory symptoms, including fever (102°F), cough, fatigue, difficulty breathing, chest pain, rash, wheezing, swollen lymph nodes, and pale skin. These symptoms led the patient to seek medical attention for suspected pneumonia.\n\nUpon evaluation, the patient's heart rate is elevated at 85 bpm, indicating stress or possible cardiac involvement. Oxygen saturation is 91.8%, which is slightly below normal range, but not critically low. Cholesterol level is slightly elevated at 155.3 mg/dL, and glucose level is also above normal range at 111.7 mg/dL.\n\nGiven the patient's age (67) and symptoms, a diagnosis of community-acquired pneumonia with possible comorbid conditions such as cardiovascular disease or diabetes mellitus is considered. Further investigations, including imaging studies and laboratory tests, are necessary to confirm the diagnosis and rule out other potential causes.\n\n**Differential Diagnosis**\n\n* Pneumonia (community-acquired)\n* Cardiovascular disease (e.g., coronary artery disease, heart failure)\n* Diabetes mellitus\n* Respiratory infections (e.g., bronchitis, asthma)\n\n**Treatment Plan**\n\n* Antibiotics for pneumonia\n* Oxygen therapy to improve oxygen saturation\n* Cardiovascular evaluation and management as needed\n* Monitoring of glucose levels and adjusting treatment plan accordingly\n\n**Recommendations**\n\n* Continue to monitor the patient's vital signs closely.\n* Consider referring the patient to a pulmonologist or cardiologist for further evaluation and management.\n\n**Additional Notes**\n\n* The patient's history of smoking may be relevant in evaluating the cause of their respiratory symptoms.\n* Further testing, such as chest X-ray or CT scan, may be necessary to confirm the diagnosis.",
#  "**Clinical Notes**\n\nPatient presented with influenza-like symptoms, specifically fever (39.8°C) and cough, accompanied by fatigue, headache, sore throat, nausea, abdominal pain, facial pain, and pale skin. These symptoms are consistent with a diagnosis of influenza.\n\nVital signs revealed a respiratory rate of 16 breaths/min, which is slightly elevated indicating possible respiratory distress. Oxygen saturation at 98.4% is within normal limits.\n\nGiven the patient's age (15) and symptoms, it is essential to consider potential complications such as pneumonia or bronchiolitis. The patient will be monitored closely for any signs of worsening respiratory status or secondary bacterial infections.\n\n**Additional Information**\n\nPatient has a history of asthma, which may be contributing to the observed respiratory distress. Allergies to dust mites and pollen are also present, increasing the risk for atopic exacerbations.\n\n**Diagnosis**\n\nInfluenza (Flu) with possible complications of pneumonia or bronchiolitis, exacerbated by underlying asthma and allergies.",
#  "**Clinical Notes**\n\nPatient presents with hypertension (high blood pressure) and multiple symptoms that raise concerns for a cardiovascular event.\n\n**Vital Signs:**\n- Temperature: 36.7°C (slightly elevated)\n- Blood pressure not reported, but considering patient's motivation for visit, likely to be elevated.\n- Heart rate and rhythm not available in this note, but warrants further investigation given the clinical context.\n\n**Symptoms:**\n\n- Difficulty breathing: severe\n- Chest pain: present and worsens with breathing difficulties\n- Nausea: mild\n- Diarrhea: mild\n- Dizziness: frequent and may be contributing to difficulty breathing\n- Sneezing: occasional, potentially related to allergies or cardiac issue\n- Itchy eyes: possible allergic reaction\n- Frequent urination: present and notable given hypertension\n- Sadness: emotional distress, likely related to overall health status\n\n**Considerations:**\nPatient's age (77) and symptoms of difficulty breathing, chest pain, and dizziness raise concerns for acute coronary syndrome or a pulmonary embolism. The presence of hypertension, frequent urination, and itchy eyes suggests potential kidney involvement or an allergic reaction.\n\nReferred to cardiology and nephrology services for further evaluation and management.",
#  "**Clinical Notes**\n\nPatient presented with a complaint of a common cold, presenting with multiple symptoms including cough, fatigue, sore throat, chest pain, diarrhea, runny nose, joint pain, sneezing, increased thirst, wheezing, and heartburn. \n\nVital signs were checked and revealed a temperature of 36.8°C, which is slightly elevated but not alarming at this point. The patient's heart rate was normal at 81 bpm and respiratory rate was within the expected range at 12 breaths/min. Oxygen saturation was also near normal at 98.9%. \n\nGiven the age of the patient (86 years) and the presence of several symptoms, a thorough medical history was taken. Patient has a long-standing history of hypertension, hyperlipidemia, and type 2 diabetes mellitus, which may be relevant to his current presentation.\n\nThe combination of respiratory symptoms such as cough, sneezing, wheezing, and chest pain, along with gastrointestinal symptoms like diarrhea and increased thirst, raises the suspicion of an infectious etiology. However, the presence of dry skin alongside these symptoms could also suggest a systemic condition rather than a localized infection.\n\n**Initial Diagnosis**\n\nConsidering the patient's age and multiple symptoms, a possible initial diagnosis could be a viral upper respiratory tract infection, possibly with a secondary bacterial component, or a more complex underlying condition such as pneumonia or an exacerbation of chronic obstructive pulmonary disease (COPD).\n\n**Recommendations for Further Evaluation**\n\n* Perform chest X-ray to evaluate for signs of pneumonia or COPD exacerbation\n* Order complete blood count (CBC) and basic metabolic panel (BMP) to assess for any underlying infection or inflammation\n* Consider ordering a urinalysis to check for signs of urinary tract infection, given the patient's symptoms of increased thirst\n* Review patient's medication list to ensure no potential interactions with current treatment\n\n**Next Steps**\n\nSchedule follow-up appointment in 24-48 hours to re-assess symptoms and adjust treatment plan as needed.",
#  "**Clinical Notes**\n\nPatient [Age: 15] presented with a complaint of ear infection (otitis media). Upon examination, the patient exhibited several symptoms including fever, difficulty breathing, nausea, vomiting, itchy eyes, increased thirst, heartburn, ear pain, dry skin, sadness, and restlessness.\n\nVital signs were obtained during the visit:\n\n- Blood pressure: Systolic 107/62 mmHg (elevated)\n- Oxygen saturation: 95.8% (mildly decreased)\n- Glucose level: 111.6 mg/dL (slightly elevated)\n\nThe patient's symptoms, particularly the difficulty breathing and fever, suggest a potential respiratory complication. The slightly elevated blood pressure may indicate dehydration or an underlying cardiovascular issue.\n\nIt is essential to investigate further to determine the cause of the ear infection and its impact on the patient's overall health. Given the patient's age and presenting symptoms, there is a possibility that this could be related to a viral upper respiratory tract infection rather than a bacterial otitis media.\n\n**Additional Considerations:**\n\n- The patient has a history of recurring ear infections, which may indicate an underlying immunological or anatomical issue.\n- There are no notable family history or previous medical conditions present.",
#  "**Clinical Notes**\n\nPatient presented with a 6-day history of symptoms consistent with a common cold, including cough, fatigue, sore throat, nausea, runny nose, and sneezing. However, the patient's age (81 years) raised suspicion for underlying comorbidities.\n\nUpon examination, the patient's vital signs revealed an elevated temperature of 37.4°C, which is 0.2°C above normal range. The respiratory rate was within normal limits at 14 breaths/min. Oxygen saturation was slightly below normal at 95.0%. Notably, the cholesterol level was significantly elevated at 167.4 mg/dL, indicating a high risk of cardiovascular disease.\n\nThe patient also presented with a rash and joint pain, which could be indicative of an underlying infection or inflammatory process.\n\nGiven the patient's age, comorbidities, and laboratory results, further testing is warranted to rule out pneumonia, influenza, or other infectious processes. The elevated cholesterol level warrants discussion regarding lifestyle modifications and potential antihypertensive medications.\n\n**Differential Diagnosis**\n\n* Common cold\n* Pneumonia\n* Influenza\n* Cardiovascular disease (e.g., hypertension, hyperlipidemia)\n* Infectious process (e.g., endocarditis, sepsis)\n\n**Recommendations**\n\n* Perform chest X-ray to rule out pneumonia\n* Obtain blood cultures and CBC with differential to evaluate for infection\n* Discuss lifestyle modifications to manage cholesterol level and risk of cardiovascular disease\n* Consider antihypertensive medications in the event of hypertension diagnosis",
#  "**Clinical Notes**\n\nPatient presented with complaints of pneumonia, presenting with:\n\n* Fever\n* Cough\n* Fatigue\n* Headache\n* Difficulty breathing\n* Chest pain\n* Abdominal pain\n* Sneezing\n* Itchy eyes\n* Increased thirst\n* Wheezing\n\nNotably, the patient's respiratory rate is elevated at 24 breaths/min, which may indicate a concerning respiratory infection. Oxygen saturation levels are significantly low at 87.6%, suggesting hypoxemia.\n\nUpon further evaluation, it appears that the patient's symptoms and lab results are consistent with community-acquired pneumonia (CAP). The presence of fever, cough, and difficulty breathing, along with laboratory evidence of pneumonia, support this diagnosis.\n\n**Additional Considerations**\n\nGiven the patient's advanced age (74 years) and history of comorbidities, a thorough geriatric evaluation should be performed to assess for potential underlying causes of pneumonia, such as dehydration, malnutrition, or occult malignancy. Additionally, the patient's oxygen saturation levels warrant immediate attention and possible consideration for supplemental oxygen therapy.\n\n**Differential Diagnosis**\n\nWhile pneumonia is the primary diagnosis, other differential diagnoses should include:\n\n* Acute bronchitis\n* Pneumonitis\n* Pneumothorax\n* Sepsis\n\n**Next Steps**\n\nThe patient will be admitted to the hospital for close monitoring and treatment of suspected pneumonia. Further diagnostic testing, including imaging studies (e.g., chest X-ray or CT scan), laboratory tests (e.g., complete blood count, electrolyte panel), and possibly a nasogastric tube placement for fluid resuscitation, may be necessary.\n\n**Plan**\n\n* Admit patient to the hospital for close monitoring\n* Administer antibiotics as prescribed by infectious disease consultation\n* Encourage fluid intake and monitor electrolytes\n* Consider supplemental oxygen therapy if oxygen saturation levels remain low\n* Schedule follow-up appointments with primary care physician and specialists (e.g., pulmonologist, geriatrician) to review treatment plan and adjust as needed.",
#  "**Clinical Notes**\n\nPatient presented with a chief complaint of Diabetes (Type 2) and is now experiencing a range of concerning symptoms including fever, fatigue, difficulty breathing, vomiting, abdominal pain, rash, increased thirst, and blurred vision. Upon further evaluation, the patient's vital signs reveal an elevated respiratory rate of 18 breaths/min, suggesting potential respiratory distress.\n\nThe patient's cholesterol level is also notable at 143.8 mg/dL, which is above the desired range. This finding raises concerns for cardiovascular complications in a patient with diabetes.\n\nGiven the combination of respiratory symptoms and abnormal vital signs, I am inclined to suspect an infectious etiology such as pneumonia or sepsis, particularly given the patient's underlying diabetes. The rash and increased thirst are also concerning for a possible urinary tract infection or diabetic ketoacidosis.\n\nI would like to proceed with further evaluation, including ordering laboratory tests (e.g., complete blood count, comprehensive metabolic panel) and imaging studies (e.g., chest X-ray) to better assess the patient's condition and guide potential treatment.",
#  "**Clinical Notes**\n\nPatient presented with a chief complaint of anxiety disorders and a multitude of symptoms that have been distressing him lately.\n\n**Vital Signs:**\n- Temperature: 36.8°C, which is slightly elevated.\n- Other vital signs are within normal limits.\n\n**Subjective Symptoms:**\nThe patient reports experiencing:\n- A persistent headache\n- Sore throat\n- Abdominal pain\n- Dizziness on multiple occasions\n- Night sweats\n- Facial pain\n- Persistent feelings of sadness and anxiety\n- Restlessness, making it difficult for him to concentrate\n\nGiven the combination and severity of these symptoms, I am inclined to consider a diagnosis that may involve an underlying medical condition contributing to his anxiety disorders. Further investigation is required to determine a definitive cause.\n\n**Assessment:**\nThe elevated temperature could indicate an underlying infection or inflammatory process. However, without further diagnostic testing, it's difficult to pinpoint the exact cause of these symptoms.\n\n**Recommendations:**\n- Order a comprehensive physical examination\n- Conduct routine laboratory tests including complete blood count (CBC), electrolytes, and liver function tests\n- Consider imaging studies such as a chest X-ray or abdominal ultrasound if necessary\n\nThe patient will be scheduled for follow-up to reassess his condition.",
#  "**Clinical Notes**\n\nPatient: [Redacted for confidentiality]\n\n**Chief Complaint:** Chronic Obstructive Pulmonary Disease (COPD)\n\n**History of Present Illness:** The patient presents with a 2-week history of worsening shortness of breath, coughing up yellow sputum, and chest pain. These symptoms have progressively worsened over the past week, leading to significant distress.\n\n**Physical Examination:**\n\n- **Vital Signs:** \n  * Temperature: 36.9°C (normal)\n  * Heart Rate: 94 bpm (elevated)\n  * Respiratory Rate: 15 breaths/min (mildly elevated, but not concerning for respiratory failure at this point)\n  * Oxygen Saturation: 98.6% (normal)\n  * Glucose Level: 73.5 mg/dL (within normal limits)\n\n- **Cardiovascular:** The patient's heart rate is elevated, which could be indicative of anxiety or a compensatory mechanism.\n\n- **Respiratory:** The patient experiences significant shortness of breath and coughs up yellow sputum, suggesting an acute exacerbation of COPD. Chest pain may indicate pulmonary embolism or atypical chest pain patterns, warranting further evaluation.\n\n- **Neurological:** The patient reports difficulty concentrating, which could be related to the chronic nature of their condition or potential hypoxemia.\n\n**Additional Notes:**\n\n- The patient's loss of taste and smell is a red flag symptom that may indicate COVID-19 infection.\n- Frequent urination could be a sign of overactive bladder or diabetes-related issues, given the patient's glucose level is within normal limits but not entirely ruling out diabetic nephropathy.\n- Blurred vision is concerning for possible optic neuritis or hypoxemia.\n\n**Assessment and Plan:**\n\n- The patient will require oxygen therapy to support their respiratory status and alleviate hypoxemia.\n- Regular monitoring of vital signs, including respiratory rate, heart rate, and oxygen saturation, will be necessary to reassess the patient's condition.\n- Further testing for COVID-19, pneumonia, or pulmonary embolism may be warranted based on the patient's symptoms and vitals.\n- The patient will also benefit from a comprehensive review of their COPD management plan, including medication adjustments as needed.\n\n**Next Steps:** Consultation with the pulmonologist to manage acute exacerbations of COPD.",
#  "**Clinical Notes**\n\nPatient: [Redacted]\nDate of Birth: [Not Provided]\n\nChief Complaint: The patient presents with symptoms suggestive of a urinary tract infection (UTI) and has been experiencing several systemic symptoms.\n\nReview of Systems:\n- Fever, headache, and vomiting are consistent with a UTI.\n- Abdominal pain is also consistent with a UTI but can be seen in various conditions.\n- Sneezing and frequent urination may indicate an allergic response or an overactive bladder, respectively.\n- Blurred vision could be due to the urinary tract infection causing irritation or secondary effects like hyperthyroidism (though this would be unusual at age 25).\n- Painful urination is a classic symptom of UTIs but can also be seen in other conditions such as prostatitis.\n- Dry skin and sadness are less common symptoms of UTI that may require further investigation for underlying causes, possibly indicating depression or another systemic condition.\n- Difficulty concentrating could be due to pain or discomfort from the urinary tract infection.\n\nVital Signs:\n- Blood Pressure: 93/60 mmHg (within normal limits).\n- Temperature: 36.9°C (normal).\n- Respiratory Rate: 14 breaths/min (normal).\n- Cholesterol Level: 146.9 mg/dL (slightly elevated; may be related to the patient's diet or other underlying health conditions).\n\nPhysical Examination and Laboratory Results:\nNot provided.\n\n**Differential Diagnosis and Plan**\n\nGiven the age of the patient, some symptoms might be less common in this demographic but could still warrant investigation. The most likely diagnoses based on symptoms include a UTI with secondary complications (such as hyperthyroidism causing blurred vision) or another systemic condition like depression affecting mental status. An elevated cholesterol level requires further investigation for lifestyle and metabolic causes.\n\nReferral to:\n- Urology for further evaluation of the urinary tract infection.\n- Primary Care Physician for possible underlying conditions such as depression, thyroid disorders, or other metabolic issues.\n\nAdditional Considerations:\n- The patient's symptoms of sadness might indicate a need for mental health referrals or support.\n- Infection control precautions should be taken to prevent further spread if the UTI is confirmed.",
#  "**Clinical Note**\n\nPatient presented with a chief complaint of sinusitis, presenting with multiple systemic symptoms including cough, headache, sore throat, and difficulty breathing. The patient also reports joint pain, itchy eyes, loss of taste and smell, frequent urination, painful urination, facial pain, heartburn, ear pain, and sadness.\n\nVital signs revealed a respiratory rate of 16 breaths/min (elevated), oxygen saturation of 98.8% (normal), and cholesterol level of 183.3 mg/dL (elevated).\n\nNotably, the patient's elevated cholesterol level may be contributing to their cardiovascular symptoms, such as the facial pain and difficulty breathing.\n\nThe patient's symptoms are suggestive of a viral upper respiratory infection with possible secondary complications.\n\n**Assessment**\n\n* The patient's age (58) and underlying health status should be considered in the management plan.\n* Further diagnostic testing, including imaging studies and laboratory tests, may be necessary to confirm the diagnosis and rule out other potential causes.\n\n**Plan**\n\n* Prescribe antibiotics for sinusitis\n* Refer to a specialist for further evaluation of cardiovascular risk factors\n* Educate patient on healthy lifestyle habits, including diet and exercise\n\n**Follow-up**\n\nSchedule follow-up appointment in 1-2 weeks to monitor symptom resolution and assess effectiveness of treatment plan.",
#  "**Clinical Notes**\n\nPatient presents with a chief complaint of tuberculosis (TB). Upon further evaluation, the patient reports:\n\n* A prolonged cough lasting for several days, which worsens at night\n* Headache and sore throat, indicating possible respiratory involvement\n* Nausea and vomiting, suggesting potential gastrointestinal involvement or systemic symptoms\n* Runny nose, consistent with a respiratory infection\n* Dizziness on multiple occasions, raising concern for neurological or cardiovascular involvements\n* Loss of taste and smell, indicative of potentially severe respiratory disease\n* Ear pain, which may be related to Eustachian tube dysfunction or middle ear involvement\n\nVital signs reveal:\n\n* Elevated respiratory rate at 19 breaths/min (normal range: 12-20 breaths/min), indicating possible acute respiratory distress\n* Moderate oxygen saturation at 96.3% (normal range: 95-100%), suggesting some degree of hypoxemia\n* Elevated cholesterol level at 142.8 mg/dL (normal range: 100-200 mg/dL), which may be a sign of chronic inflammation or metabolic dysregulation\n* Normal glucose level at 96.1 mg/dL (normal range: 70-110 mg/dL)\n\nConsidering the patient's age, symptoms, and vital signs, the clinical picture suggests an acute exacerbation of tuberculosis, with potential involvement of respiratory and gastrointestinal systems. Further diagnostic testing, including sputum cultures and imaging studies, will be necessary to confirm the diagnosis and guide treatment decisions.",
#  "**Clinical Notes**\n\nPatient presented with a history of COVID-19, who is currently experiencing a range of symptoms including fever (38.3°C), cough, fatigue, headache, difficulty breathing, chest pain, abdominal pain, joint pain, sneezing, blurred vision, night sweats, facial pain, and ear pain.\n\nUpon assessment of vital signs, the patient's oxygen saturation was noted to be 88.3%, which is below normal limits (90-94%). This finding warrants further investigation for potential respiratory compromise.\n\nLaboratory results also revealed elevated cholesterol levels at 174.2 mg/dL and glucose levels at 137.9 mg/dL. These findings are concerning for metabolic syndrome, particularly in the context of an acute illness like COVID-19.\n\nThe patient's symptoms and laboratory results collectively suggest a diagnosis of COVID-19 with respiratory involvement, likely pneumonia. The presence of systemic symptoms such as fever, fatigue, and joint pain may indicate a more severe infection or a co-infection. Further testing, including chest imaging and potentially a lumbar puncture, may be necessary to determine the extent of the infection.\n\nIt is also worth noting that the patient's elevated cholesterol levels and glucose levels raise concerns for long-term cardiovascular risk. The patient should be educated on lifestyle modifications to mitigate these risks and referred to a cardiologist for further evaluation if necessary.\n\n**Initial Treatment Plan**\n\n* Continue COVID-19 treatment as prescribed by previous healthcare providers.\n* Administer oxygen therapy to maintain an oxygen saturation of 90% or greater.\n* Prescribe antiviral medication as indicated by local health guidelines.\n* Refer patient to a cardiologist for evaluation and management of elevated cholesterol levels and glucose levels.\n\n**Next Steps**\n\n* Order chest imaging (CT scan or X-ray) to evaluate for pneumonia or other respiratory complications.\n* Perform a lumbar puncture if symptoms suggest meningitis or encephalitis.\n* Schedule follow-up appointment in 1-2 weeks to reassess patient's condition and adjust treatment plan as needed.",
#  "**Clinical Notes**\n\nPatient presents with a chief complaint of Tuberculosis (TB) and is experiencing a variety of systemic symptoms that are concerning for an active pulmonary infection.\n\nThe patient's vital signs reveal:\n\n* Blood pressure: Systolic 118/62 mmHg, which is within normal limits but slightly elevated, considering the patient's suspected acute infection.\n* Temperature: 37.0°C, which is slightly low and could indicate a recent infection or inflammatory process.\n* Oxygen saturation: 97.0%, which is within normal limits but slightly decreased, possibly indicating some degree of chronic lung disease or smoking history.\n* Cholesterol level: 158.7 mg/dL, which is elevated and warrants further investigation, particularly in the context of a suspected infectious process.\n\nThe patient's symptoms are quite concerning and suggest an active infection. The presence of cough, fatigue, dizziness, night sweats, weight loss, and swollen lymph nodes is consistent with pulmonary tuberculosis. The recent onset of itchy eyes, loss of taste and smell, and difficulty concentrating suggests involvement of the central nervous system.\n\nGiven the patient's symptoms and laboratory findings, a diagnosis of active pulmonary tuberculosis with possible extrapulmonary manifestations (e.g., CNS involvement) is considered. Further testing, including sputum smear and culture for TB, chest X-ray, and potentially CT scan or PET/CT, would be necessary to confirm the diagnosis and assess the extent of disease.\n\n**Additional Notes:**\n\n* Patient's history of smoking and possible exposure to TB in the past increases the risk of infection.\n* The patient's physical examination should include a thorough assessment of respiratory and lymphatic systems to identify any signs of extrapulmonary involvement.\n* Further laboratory tests, such as ANA, rheumatoid factor, and erythrocyte sedimentation rate (ESR), may be warranted to evaluate the possibility of an autoimmune component to the patient's symptoms.\n\n**Recommended Course of Action:**\n\n* Administer isoniazid monotherapy according to local TB treatment guidelines.\n* Schedule follow-up appointments for sputum smear and culture, chest X-ray, and potential CT or PET/CT scan.\n* Refer the patient to a specialist (e.g., pulmonologist) for further evaluation and management.",
#  "**Clinical Notes**\n\nPatient presented with COVID-19 symptoms, including cough, fatigue, difficulty breathing, vomiting, loss of taste and smell, swollen lymph nodes, and difficulty concentrating. The patient's vital signs revealed a temperature of 38.2°C, heart rate of 84 bpm, oxygen saturation of 85.3%, and glucose level of 74.1 mg/dL.\n\nUpon further evaluation, it appears that the patient is experiencing severe respiratory symptoms, with difficulty breathing being a significant concern. The elevated heart rate (84 bpm) may be indicative of anxiety or stress related to COVID-19. Notably, the oxygen saturation is slightly below normal range (88-95%), which warrants close monitoring.\n\nLaboratory results are pending, but based on the patient's presentation, it is likely that they will require supplemental oxygen and possibly antiviral medication to manage their symptoms. Further imaging studies may be necessary to evaluate for potential complications such as pneumonia or acute respiratory distress syndrome.\n\nGiven the patient's advanced age (81 years) and underlying comorbidities, it is essential to monitor them closely for signs of complications or deterioration. The patient will require close observation in a monitored unit with a team dedicated to their care.\n\n**Diagnosis:** Severe COVID-19 with respiratory compromise, requiring oxygen therapy and antiviral management.\n\n**Recommendations:**\n\n* Supplemental oxygen via non-rebreather mask\n* Antiviral medication (e.g., oseltamivir) as prescribed by the attending physician\n* Close monitoring of vital signs, oxygen saturation, and glucose levels\n* Possible imaging studies (e.g., chest CT scan) to evaluate for pulmonary complications\n\n**Next Steps:**\n\n* Consult with the attending physician to discuss treatment options and management plan.\n* Coordinate with laboratory services to expedite test results.\n* Arrange for a follow-up appointment in 24-48 hours to reassess the patient's condition.",
#  "**Clinical Notes**\n\nPatient presented with a chief complaint of Strep Throat, which aligns with the patient's visit motivation.\n\nVital signs revealed mild fever (37.1°C), elevated heart rate (91 bpm), and normal respiratory rate (13 breaths/min). Oxygen saturation was 97.8%. Notably, the temperature is slightly above the normal range, indicating a possible infection.\n\nThe patient has several symptoms consistent with Strep Throat, including sore throat, cough, headache, abdominal pain, increased thirst, wheezing, weight loss, and facial pain. The presence of swollen lymph nodes and restlessness further supports this diagnosis.\n\nAdditionally, considering the patient's age (22) and visit date, it is essential to note that Strep Throat can be a complication of streptococcal pharyngitis. Given the symptoms and vital signs, antibiotic treatment should be considered as soon as possible to prevent potential complications.\n\n**Key Takeaways:**\n\n* Mild fever and elevated heart rate suggest an infectious process.\n* Symptomatology consistent with Strep Throat.\n* Normal respiratory rate but elevated oxygen saturation may indicate some degree of respiratory compromise.\n* Considerations for streptococcal pharyngitis as a complication in young adult.\n\n**Next Steps:**\n\n* Conduct a throat swab to confirm the diagnosis.\n* Prescribe antibiotics according to current guidelines (e.g., amoxicillin or penicillin).\n* Schedule follow-up appointments to monitor resolution of symptoms and potential complications.",
#  "**Clinical Notes**\n\nThe patient presented with a complex clinical picture, primarily driven by symptoms suggestive of an acute exacerbation of Chronic Obstructive Pulmonary Disease (COPD). Notably, the patient's age is 100 years, placing them in a high-risk category for complications.\n\nVital signs revealed a mild fever (37.0°C), which may indicate an underlying infection or inflammation. The heart rate is within normal limits at 69 bpm. However, the cholesterol level is markedly elevated at 168.6 mg/dL, which raises concerns for cardiovascular comorbidities and potential exacerbation of COPD.\n\nThe patient's respiratory symptoms are consistent with COPD exacerbation: persistent cough, difficulty breathing, wheezing, and chest pain. The presence of vomiting and loss of taste/smell further suggests a systemic involvement, possibly related to the underlying respiratory condition or an infectious process.\n\nA notable finding is the absence of a prominent rash, which may be due to the patient's advanced age or potential hypovolemia secondary to dehydration from decreased oral intake.\n\nGiven the combination of symptoms and elevated cholesterol level, it is essential to consider potential cardiovascular complications in this elderly patient. Further evaluation is required to determine the underlying cause of these findings and develop an appropriate management plan.\n\n**Additional Notes**\n\n* The patient's history is unclear, but it is essential to inquire about any recent hospitalizations, surgeries, or significant medical events.\n* A thorough review of medication list is warranted to identify potential triggers for exacerbation or side effects contributing to the current presentation.\n* Laboratory studies, including complete blood count, electrolyte panel, and liver function tests, should be ordered to further evaluate the patient's condition.",
#  "**Clinical Notes**\n\nPatient [Redacted] presented to the clinic with a primary complaint of depression, which appeared to be a motivation for her current visit.\n\nUpon initial assessment, patient reports fatigue, chest pain, vomiting, dizziness, loss of taste and smell, increased thirst, weight loss, and sadness. Notably, she also reported a decreased appetite.\n\nVital signs were taken during the examination: temperature 36.5°C, cholesterol level 129.6 mg/dL. Her temperature is slightly below normal range, indicating hypothermia, which may be related to her current symptoms of depression and possible underlying cardiovascular issues. Elevated cholesterol levels are also concerning for cardiovascular risk.\n\nGiven these findings, along with patient's reported loss of taste and smell, increased thirst, weight loss, and sadness, we should consider a differential diagnosis that includes:\n\n* Hypothyroidism\n* Hyperlipidemia\n* Cardiovascular disease (possible myocardial infarction)\n* Depression with potential underlying medical conditions contributing to her symptoms\n\nFurther investigation is needed to determine the underlying cause of these symptoms. The patient will be referred for a comprehensive metabolic panel, thyroid function tests, and an echocardiogram. A referral to our psychiatrist department has also been arranged, as her depression appears to be the primary driving force behind her current symptoms.\n\n**Additional Notes**\n\n* Patient's age (63) and reported weight loss may indicate comorbidities such as malabsorption or chronic illness.\n* The presence of chest pain and dizziness raises concerns about cardiac risk factors.\n* Further evaluation is necessary to determine if these symptoms are related to an underlying medical condition or depression.\n\n**To-Do List**\n\n* Comprehensive metabolic panel\n* Thyroid function tests\n* Echocardiogram\n* Referral to psychiatrist department for continued management of depression."]

# %% [markdown]
# ### visit motivation

# %%
# Extract visit motivation
motivation_patterns = [
    r'visit motivation[:\-\s\n ]+([^\n\.]+)',
    # '[:\- ]+' matches one or more ':', '-', or ' ' (space).
    # '([^\n]+)' captures everything until a newline ('\n'), representing the motivation.
    r'reason for visit[:\-\s\n ]+([^\n\.]+)',
    r'\*?\*?chief complaint:?\*?\*?[:\-\s\n ]+([^\n\.]+)',
    r'presenting with[:\-\s\n ]+([^\n\.]+)',
    r'presented with[:\-\s\n ]+([^\n\.]+)',
    r'presents with[:\-\s\n ]+([^\n\.]+)',
    r'\*\*Visit Motivation:?\*\*[:\-\s\n ]+([^\n\.]+)',
]

# %%
# Find notes missing age patterns
missed_motivation_notes = find_missing_pattern_notes(train["Note"], motivation_patterns)

# Display the missed notes
print("Notes missing information count: ", len(missed_motivation_notes))
# Out:
# Notes missing age information count:  162

# %%
missed_motivation_notes
# Out:
# ["**Clinical Notes**\n\nPatient: [Redacted] (64 years old, Female)\n\nPresenting complaint: Diabetes Mellitus Type 2.\n\nReview of systems:\n\n* The patient reports fatigue and diarrhea in the past week. Fatigue is described as severe, worse with exertion, and affecting daily activities.\n* Joint pain is present bilaterally, more pronounced in the lower extremities.\n* Loss of taste and smell has been ongoing for several weeks, significantly impacting quality of life.\n* Increased thirst and urination have led to polyuria. The patient reports needing to urinate 5-6 times per night.\n* Blurred vision on both eyes is a recent development, started approximately 2 days prior to presentation.\n* Night sweats are frequent, occurring several times a week.\n* Painful urination has been present for the past month.\n\nVital signs:\n\n* Blood pressure: Systolic 108 mmHg, Diastolic 66 mmHg\n* Cholesterol level: 181.4 mg/dL (Elevated)\n* Glucose level: 198.9 mg/dL (Diabetic range)\n\nPhysical examination is pending.\n\n**Differential Diagnosis**\n\nConsidering the combination of symptoms such as fatigue, diarrhea, joint pain, loss of taste and smell, increased thirst and urination, and painful urination, along with elevated glucose and cholesterol levels, a possible diagnosis for this patient could be Diabetes Mellitus Type 2 with renal involvement. Blurred vision suggests potential diabetic retinopathy.\n\n**Plan**\n\n* Order a comprehensive metabolic panel to confirm glucose and electrolyte imbalances.\n* Request an ultrasound of the kidneys to assess for any signs of kidney damage or disease.\n* Prescribe metformin 500mg twice daily and begin lifestyle modification recommendations, including dietary changes and increased physical activity.\n* Schedule follow-up in one week to re-assess blood work and progress.\n\n**Referral Information**\n\nIf the patient's condition worsens or if further evaluation is required, consider referral to an endocrinologist or a nephrologist for specialized care.",
#  "**Clinical Notes**\n\nThe patient, a 31-year-old female, presented to the clinic with a primary motivation of sinusitis. Upon examination, she reported experiencing a range of symptoms including cough, difficulty breathing, diarrhea, runny nose, sneezing, itchy eyes, blurred vision, painful urination, facial pain, and ear pain.\n\nNotably, her vital signs revealed blood pressure readings of 97/76 mmHg, which is within normal limits. However, her temperature was elevated at 37.2°C, indicating a low-grade fever. Her heart rate was 68 bpm, and respiratory rate was 15 breaths/min, both of which are also within normal ranges.\n\nThe patient's cholesterol level was found to be significantly high at 177.6 mg/dL, while her glucose level was elevated at 128.6 mg/dL. These findings warrant further investigation into potential underlying metabolic or endocrine issues.\n\nInterestingly, the presence of diarrhea and itchy eyes suggests a possible allergic component to her sinusitis. The patient's facial pain and ear pain may be related to her sinusitis, while her blurred vision could indicate a more complex issue such as orbital involvement.\n\nThe patient's overall presentation is complex and multifaceted, requiring further diagnostic evaluation to determine the underlying cause of her symptoms. A comprehensive differential diagnosis would include sinusitis, allergic reactions, metabolic disorders, and potential infections or inflammatory processes.\n\n**Initial Diagnosis:** Unspecific Sinusitis with possible Allergic Component and Elevated Cholesterol/Glucose Levels.\n\n**Recommendations:**\n\n* Order imaging studies (e.g., CT scan) to evaluate the extent of sinusitis and potentially identify any orbital involvement.\n* Perform a thorough allergy workup, including skin testing or blood tests, to rule out potential allergic triggers.\n* Refer the patient for metabolic panel reevaluation to further investigate elevated cholesterol and glucose levels.\n* Consider initiating treatment for sinusitis with antibiotics if necessary, alongside symptomatic relief measures such as nasal decongestants and antihistamines.\n\n**Follow-up:** Schedule a follow-up appointment in 1-2 weeks to reassess symptoms, adjust treatment as needed, and further investigate the patient's metabolic status.",
#  "**Clinical Notes**\n\nThe patient, an 87-year-old female, was seen for evaluation of suspected coronary artery disease. Her vital signs revealed blood pressure 103/65 mmHg, which is elevated and indicative of hypertension; heart rate 99 bpm, slightly above normal range; temperature 37.3°C, within normal limits; oxygen saturation 98.3%, which is slightly below normal range, but not concerning for acute respiratory distress; and cholesterol level 138.1 mg/dL, elevated.\n\nHer symptoms are varied and suggestive of multiple potential diagnoses. Fatigue and restlessness may be indicative of anemia or hypothyroidism, among other causes. Sore throat, difficulty breathing, and dizziness could suggest a respiratory infection such as pneumonia or bronchitis. Sneezing is unusual in this context but might indicate allergies or sinusitis. Blurred vision and painful urination are concerning signs that may point towards a urological issue, such as kidney stones or bladder infections.\n\nThe patient's age and symptoms warrant further investigation into potential comorbidities, especially given the elevated blood pressure and cholesterol level. The presence of heartburn is also notable, which could be indicative of gastroesophageal reflux disease (GERD) or esophagitis.\n\nGiven these findings, it is essential to conduct a thorough medical history review, including questions about her medication regimen, social history, and any previous cardiac events. A comprehensive physical examination should also be performed to assess for signs suggestive of coronary artery disease, such as peripheral edema, jugular venous distension, or murmurs.\n\nThe patient will require further testing to rule out potential causes, including blood work to evaluate her cholesterol level, liver function tests (LFTs), and possibly a chest X-ray or echocardiogram to assess cardiac structure and function.\n\n**Diagnosis Considerations**\n\n* Hypertensive crisis with possible coronary artery disease\n* Urological issues such as kidney stones or bladder infections\n* Respiratory infection (pneumonia, bronchitis)\n* Allergies or sinusitis\n* GERD or esophagitis\n* Anemia or hypothyroidism\n\n**Next Steps**\n\n* Comprehensive medical history review\n* Thorough physical examination\n* Blood work to evaluate cholesterol level and LFTs\n* Possibly Chest X-ray or echocardiogram",
#  "**Clinical Notes**\n\nThe patient, a 69-year-old male, presented to our clinic with an overwhelming array of symptoms that suggest a complex presentation. The primary reason for the visit is related to anxiety disorders.\n\nUpon examination, the patient exhibited:\n\n- Headache\n- Difficulty breathing\n- Chest pain\n- Vomiting\n- Runny nose\n- Dizziness\n- Sneezing\n- Loss of taste and smell\n- Night sweats\n- Swollen lymph nodes\n- Anxiety\n- Restlessness\n- Difficulty concentrating\n\nVital signs revealed:\n\n- Temperature: 36.7°C (slightly elevated)\n- Heart rate: 95 bpm (elevated)\n- Respiratory rate: 16 breaths/min (normal)\n- Oxygen saturation: 99.2% (within normal limits)\n\nGiven the patient's age and presentation, we are concerned for potential cardiovascular complications secondary to anxiety disorders. The elevated heart rate and temperature suggest a possible stress-induced response. However, the combination of chest pain, difficulty breathing, and swollen lymph nodes warrants further investigation.\n\nWe will order a cardiac enzyme panel, electrocardiogram (ECG), and possibly imaging studies to rule out coronary artery disease or other cardiovascular causes for his symptoms. Additionally, we may consider referring him for mental health services to address his anxiety disorder, as this can have significant implications on overall physical health.\n\nThe patient's recent history of night sweats is concerning for a potential underlying malignancy, which will need to be investigated further. The loss of taste and smell could be related to a viral or bacterial infection, and we may consider ordering specific tests (e.g., COVID-19, influenza) given the seasonality.\n\nGiven the complexity of this presentation, we will require close monitoring and follow-up appointments to ensure that any underlying conditions are properly addressed.\n\n**Initial Diagnosis**: Stress-induced anxiety disorder with possible cardiovascular complications, suspicious for potential malignancy, and consideration for secondary viral or bacterial infections.\n\n**Recommendations**: Cardiac enzyme panel, ECG, imaging studies, mental health services referral, specific virus/bacterial testing, and close monitoring.",
#  "**Clinical Notes**\n\n**Patient Information:**\nThe patient is a 99-year-old female presenting to the clinic with COVID-19 as her primary motivation for visitation.\n\n**Vital Signs:**\nNotable findings on physical examination include:\n\n* Blood pressure: Systolic 110/78 mmHg (elevated)\n* Temperature: 38.8°C (feverish)\n* Heart rate: 64 bpm (normal)\n* Respiratory rate: 17 breaths/min (mildly elevated)\n* Oxygen saturation: 85.4% (low)\n* Cholesterol level: 189.7 mg/dL (elevated)\n* Glucose level: 95.5 mg/dL (within normal limits)\n\n**Symptoms:**\nThe patient reports a range of symptoms, including:\n\n* Cough\n* Fatigue\n* Sore throat\n* Chest pain\n* Vomiting\n* Diarrhea\n* Dizziness\n* Frequent urination\n* Difficulty concentrating\n\n**Diagnosis:**\nBased on the patient's age, comorbidities (likely hypertension and hyperlipidemia given elevated cholesterol level), and laboratory results, a likely diagnosis of COVID-19 with possible superimposed acute coronary syndrome (ACS) is considered. The patient's low oxygen saturation and elevated systolic blood pressure suggest potential cardiac involvement.\n\n**Management Plan:**\nThe patient will be started on antiviral therapy for COVID-19 and referred to cardiology for further evaluation of the chest pain and potential ACS. Oxygen therapy will be initiated to improve oxygen saturation, and close monitoring of vital signs will be performed.\n\n**Additional Considerations:**\nGiven the patient's advanced age and comorbidities, a multidisciplinary approach will be necessary to ensure optimal care. A thorough discussion with the patient's family regarding end-of-life care options will also be conducted as part of the comprehensive geriatric assessment.",
#  "**Clinical Notes**\n\nThe patient, a 20-year-old female, presented to the office with complaints of ear infection (otitis media). Upon further evaluation, she reports:\n\n* Fever\n* Fatigue\n* Headache\n* Vomiting\n* Abdominal pain\n* Rash\n* Increased thirst\n* Wheezing\n* Weight loss\n* Ear pain\n* Sadness\n* Difficulty concentrating\n\nVital signs:\n- Respiratory rate: 20 breaths/min (normal range: 12-20 breaths/min)\n- Glucose level: 114.3 mg/dL (slightly elevated, but not excessively high)\n\nGiven the constellation of symptoms and lab results, I suspect an acute bacterial otitis media with possible concomitant sinusitis and gastroenteritis. The patient's respiratory rate is slightly elevated, which may indicate a possible respiratory tract infection.\n\nUpon physical examination, I would expect to find signs of ear pain, fever, and possibly conjunctivitis or exudates in the ears. Further diagnostic workup may include complete blood count (CBC), basic metabolic panel (BMP), urinalysis, and imaging studies such as X-rays or CT scans to confirm the diagnosis and assess for any potential complications.\n\nGiven her young age and recent onset of symptoms, I would recommend empiric antibiotic therapy for suspected bacterial otitis media. Additionally, management strategies should include symptomatic relief measures such as antipyretics, anti-nausea medication, and supportive care with fluids to address dehydration and electrolyte imbalance.\n\n**Additional Information**\n\nPatient's family history reveals a previous episode of streptococcal pharyngitis in the past year. This may be relevant to her current presentation. The patient is also known to have allergies, which could potentially contribute to her symptoms. Her vital signs suggest some level of dehydration and possible underlying infection, warranting close monitoring and aggressive fluid management.\n\n**Follow-up Plan**\n\n* Schedule follow-up appointment for 3-5 days to re-evaluate symptoms and adjust treatment as needed\n* Obtain patient's family history and medical allergies to inform treatment decisions\n* Consider referring the patient to an ear, nose, and throat (ENT) specialist for further evaluation and management\n\n**Admission/Disposition**\n\nThe patient will be discharged with close follow-up instructions and ordered laboratory tests to monitor for any signs of complications or worsening symptoms.",
#  "**Clinical Notes**\n\nThe patient, a 33-year-old male, presented to the clinic with symptoms indicative of Gastroesophageal Reflux Disease (GERD), which motivated his visit. His comprehensive symptomatology includes fever, sore throat, chest pain, nausea, vomiting, rash, itchy eyes, loss of taste and smell, heartburn, ear pain, and restlessness.\n\nVital signs were obtained during the examination, revealing elevated blood pressure with a systolic value of 104 mmHg and diastolic value of 78 mmHg. The patient's heart rate is slightly low at 66 beats per minute. Respiratory rate is normal at 16 breaths per minute. Oxygen saturation is within normal limits at 98.7%. Notably, the glucose level is slightly elevated at 137.8 mg/dL.\n\nGiven these findings, it appears that while the patient's GERD symptoms are prominent, there may be concurrent atypical presentations that warrant further investigation. The fever and rash could suggest a secondary infection or an allergic reaction, which should be considered in the differential diagnosis. The patient's elevated blood pressure and slightly high glucose level require close monitoring for potential signs of autonomic dysfunction or stress response.\n\n**Additional Considerations**\n\n* Patient history: The patient reports recent exposure to certain allergens and has a history of hypertension, which may contribute to his current symptoms.\n* Physical examination: A thorough abdominal examination would be necessary to assess the severity of GERD and rule out other gastrointestinal disorders.\n* Laboratory tests: Additional blood work, including comprehensive metabolic panel (CMP) and complete blood count (CBC), should be ordered to investigate potential underlying causes of fever, rash, elevated glucose level, and hypertension.\n\n**Plan**\n\nThe patient will undergo further evaluation, including:\n\n1. Endoscopy to assess the esophagus for signs of GERD and rule out other gastrointestinal disorders.\n2. Allergy testing to identify any potential allergens contributing to his symptoms.\n3. Regular monitoring of blood pressure, glucose level, and vital signs.\n\nA comprehensive treatment plan will be developed in consultation with the patient, addressing both the primary concern of GERD and any concurrently identified conditions.",
#  "**Patient's Clinical Notes**\n\nThe patient, a 41-year-old male, presented to our clinic with a primary concern of asthma exacerbation. Upon initial assessment, the patient reported a history of chronic asthma, which he manages with inhaled corticosteroids and short-acting betaagonists.\n\nVital Signs:\n\n* Temperature: 37.4°C (slightly elevated)\n* Respiratory Rate: 15 breaths/min (elevated, indicating respiratory distress)\n* Cholesterol Level: 179.6 mg/dL (mildly elevated)\n* Glucose Level: 109.7 mg/dL (slightly elevated)\n\nSymptoms:\n\nThe patient's primary complaints of cough, difficulty breathing, and chest pain are consistent with an asthma exacerbation. The presence of swollen lymph nodes also supports this diagnosis.\n\nDifferential Diagnosis:\n\nGiven the patient's symptoms and vital signs, we considered other potential diagnoses such as pneumonia or acute coronary syndrome. However, the combination of respiratory distress, asthma history, and normal white blood cell count (not provided) makes pneumonia less likely. The elevated cholesterol level and glucose level may be secondary to stress-induced metabolic changes, but they do not significantly impact our primary diagnosis.\n\n**Initial Treatment Plan**\n\n* Continue asthma management with inhaled corticosteroids\n* Monitor respiratory rate and oxygen saturation\n* Consider adding a short-acting betaagonist for acute symptom relief\n* Schedule follow-up appointment for further evaluation and potential adjustment of medication\n\n**Next Steps**\n\n* Order chest X-ray to evaluate for any pulmonary abnormalities\n* Conduct further allergy testing to identify potential triggers for asthma exacerbation\n* Review patient's medication regimen to ensure adherence and potential adjustments",
#  "**Clinical Notes**\n\nPatient: [ REDACTED ] (47-year-old female)\n\nPresenting complaint: Hypertension (High Blood Pressure).\n\nVital Signs:\n\n* Blood Pressure: Systolic 170/90 mmHg, Diastolic 90/60 mmHg - Elevated blood pressure with a significant systolic reading, indicating potential hypertensive crisis.\n* Respiratory Rate: 15 breaths/min - Tachypnea is present, which may be related to the patient's underlying hypertension or an acute respiratory issue.\n* Oxygen Saturation: 98.2% - Mild desaturation observed, but within normal limits at this time.\n* Cholesterol Level: 167.4 mg/dL - Elevated cholesterol level, consistent with the patient's reported hypertension.\n\nSymptoms:\n\n* Headache - Possible primary complaint or secondary to hypertensive crisis.\n* Difficulty Breathing - Could be related to respiratory rate and potential pulmonary congestion due to hypertension.\n* Nausea - Non-specific symptom that may be related to various underlying causes, including gastroesophageal reflux disease (GERD) in patients with hypertension.\n* Wheezing - Possible respiratory issue or exacerbation of asthma in a patient with wheezing symptoms.\n* Restlessness - Non-specific symptom that may indicate anxiety, discomfort, or underlying neurological issue.\n\nConsiderations:\n\nThe patient's elevated blood pressure and significant headache warrant further investigation into the cause of her hypertension. Given her difficulty breathing, it is essential to consider potential respiratory causes, including pulmonary congestion due to heart failure. The presence of wheezing also raises concern for asthma exacerbation or chronic obstructive pulmonary disease (COPD). A thorough medical history and physical examination are necessary to determine the underlying cause of these symptoms.\n\n**Next Steps:**\n\n* Order further diagnostic tests, such as a chest X-ray, electrocardiogram (ECG), and potentially a CT scan of the lungs.\n* Consider ordering additional blood work to evaluate kidney function, electrolyte levels, and liver enzymes.\n* Schedule follow-up appointments for monitoring of blood pressure and respiratory status.\n\n**Personal Note:**\n\nGiven this patient's presentation, I would like to inquire about her medical history, including any previous diagnoses or treatments related to hypertension. Additionally, it would be beneficial to discuss the importance of lifestyle modifications, such as diet, exercise, and stress management, in managing her condition.",
#  "**Clinical Notes**\n\nPatient Presentation:\n\nThe patient, a 28-year-old female, presented to the office with symptoms consistent with streptococcal pharyngitis, including fever, vomiting, and swollen lymph nodes.\n\nPhysical Examination:\n\nVital signs were notable for hypertension (systolic BP: 115 mmHg, diastolic BP: 65 mmHg), tachycardia (HR: 75 bpm), and slightly elevated respiratory rate (15 breaths/min). Oxygen saturation was within normal limits (95.2%).\n\nDifferential Diagnosis:\n\nGiven the patient's symptoms and physical examination findings, a diagnosis of streptococcal pharyngitis is highly suspected. However, the presence of blurred vision and pale skin warrants further investigation for potential complications such as post-streptococcal glomerulonephritis or rheumatic fever.\n\nAdditional Considerations:\n\nThe patient's age and presentation are more consistent with a viral etiology than a bacterial one. Further testing, including rapid strep tests and possibly throat cultures, may be necessary to confirm the diagnosis.\n\nMedication:\n\nPrescribed antibiotics (e.g., penicillin) as prescribed by primary care physician prior to referral to our clinic. Follow-up will be scheduled in 24 hours to assess response to treatment.\n\nDischarge Instructions:\n\nPatient is advised to rest, stay hydrated, and follow a soft-food diet for the next 24-48 hours. Antibiotic therapy should be continued as directed.",
#  "Patient Presentation:\n\nMs., a 20-year-old female, presents to the clinic with symptoms suggestive of COVID-19. The patient reports a 2-day history of fever, cough, and fatigue, which worsened over the past 24 hours. Additionally, she describes difficulty breathing, abdominal pain, joint pain, dizziness, itchy eyes, loss of taste and smell, frequent urination, night sweats, swollen lymph nodes, and dry skin.\n\nPhysical Examination:\n\nVital signs: The patient's temperature is 103°F (39.4°C), blood pressure is 120/80 mmHg, pulse is 110/min, respiratory rate is 24/min, and oxygen saturation is 94%. Cholesterol level is 147.9 mg/dL, which falls within the normal range.\n\nLaboratory Results:\n\nNot available at this time.\n\nDifferential Diagnosis:\n\nBased on the patient's symptoms and physical examination findings, a differential diagnosis of COVID-19 is considered, taking into account her recent travel history and exposure to others with similar symptoms. The presence of swollen lymph nodes and night sweats raises concerns for infectious etiologies.\n\nPlan:\n\nThe patient will be started on antiviral therapy with oseltamivir (Tamiflu) for suspected COVID-19 pneumonia. Antibiotics may be added if there is evidence of bacterial co-infection. The patient's fever and respiratory symptoms will be monitored closely, and she will be administered oxygen via nasal cannula as needed.\n\nFollow-up appointment will be scheduled in 24-48 hours to reassess the patient's condition and adjust treatment plan as necessary.\n\nAdditional History:\n\nThe patient has a history of asthma, which may contribute to her difficulty breathing. Her family members have also been experiencing similar symptoms, suggesting potential household transmission.",
#  "**Clinical Notes**\n\nPatient [REDACTED], a 56-year-old female, presents to the clinic with symptoms consistent with anxiety disorders and potential underlying medical conditions.\n\n**History of Present Illness:**\nThe patient reports difficulty breathing, abdominal pain, itchy eyes, increased thirst, swollen lymph nodes, sadness, anxiety, restlessness, and difficulty concentrating. These symptoms have been ongoing for several days, and while they are uncomfortable, the patient is worried about their potential causes.\n\n**Vital Signs:**\n\n* Blood Pressure: 115/76 mmHg (elevated systolic blood pressure)\n* Respiratory Rate: 13 breaths/min (mild tachypnea)\n* Oxygen Saturation: 99.4% (normal)\n* Cholesterol Level: 141.2 mg/dL (elevated)\n\n**Differential Diagnosis:**\nGiven the patient's symptoms and elevated cholesterol level, potential diagnoses to consider include hyperthyroidism, pheochromocytoma, or other endocrine disorders.\n\n**Physical Examination:**\nThe physical exam is notable for [REDACTED], but further evaluation is required to determine the extent of any abnormalities. Additional diagnostic testing may be necessary to rule out underlying causes of these symptoms.\n\n**Plan:**\nOrder a comprehensive metabolic panel (CMP) to evaluate electrolytes, liver function, and kidney function. Also, consider ordering thyroid-stimulating hormone (TSH), free thyroxine (FT4), and free triiodothyronine (FT3) to rule in or out hyperthyroidism.\n\n**Follow-up:**\nSchedule a follow-up appointment for [REDACTED] to re-evaluate their symptoms and discuss any test results.",
#  "**Clinical Notes**\n\nPatient: [Redacted] (Female, 74 years old)\n\nPresenting complaint: Heart Disease (Coronary Artery Disease) - Patient reports symptoms suggestive of coronary artery disease.\n\nMedical History:\nThe patient has a history of hypertension and hyperlipidemia. She was diagnosed with type 2 diabetes mellitus 5 years ago and is on metformin and atorvastatin.\n\n**Physical Examination:**\n\nVital Signs:\n\n* Blood Pressure: Systolic 95 mmHg, Diastolic 60 mmHg (Significant Hypotension)\n* Temperature: 37.4°C\n* Respiratory Rate: 13 breaths/min\n* Oxygen Saturation: 98.4%\n* Cholesterol Level: 180.0 mg/dL (Elevated)\n* Glucose Level: 131.4 mg/dL (Elevated)\n\n**Symptoms:**\n\nThe patient reports the following symptoms:\n- Fatigue\n- Chest pain\n- Diarrhea\n- Dizziness\n- Sneezing\n- Itchy eyes\n- Increased thirst\n- Dry skin\n- Sadness\n- Anxiety\n\nNotable finding: The patient's systolic blood pressure is significantly low, indicating possible hypotension. This is concerning given the patient's history of coronary artery disease.\n\nDifferential Diagnosis:\nConsidering the patient's symptoms and vital signs, a diagnosis of acute coronary syndrome (ACS) cannot be ruled out. Other possibilities include dehydration and electrolyte imbalance secondary to diarrhea.\n\n**Plan:**\n\n* Order a troponin level to rule in or rule out ACS.\n* Reassess blood pressure and oxygen saturation closely due to significant hypotension.\n* Administer IV fluids and consider IV acetaminophen for suspected dehydration and electrolyte imbalance.\n* Consider referral to the cardiology department for further evaluation.\n\nNext steps will be determined after reviewing lab results and reassessing the patient's condition.",
#  "**Clinical Notes**\n\nThe patient, a 44-year-old male, presented to the clinic with a primary motivation of managing his asthma. Upon initial evaluation, it was noted that he exhibited a range of symptoms including fever (37.1°C), wheezing, and heartburn.\n\nNotably, his vital signs revealed a heart rate of 82 bpm, which is slightly elevated but within normal limits for this age group. His oxygen saturation percentage is at 98.6%, indicating no acute respiratory distress. However, his glucose level is elevated at 93.3 mg/dL, suggesting possible stress or anxiety-related hyperglycemia.\n\nThe patient's emotional state was also observed to be perturbed, with reports of sadness and anxiety. Given the combination of these symptoms, a diagnosis of asthma exacerbation secondary to acute stress/anxiety is considered. Further evaluation and management strategies will focus on stabilizing the patient's blood glucose levels and managing his asthma symptoms while addressing his emotional well-being.\n\n**Additional Notes**\n\n- Recent travel history or exposure to allergens not reported.\n- Noted that the patient has a history of seasonal allergies, which may be contributing to his current asthma exacerbation.\n- Will consider ordering additional diagnostic tests (e.g., ECG, urinalysis) to rule out other potential causes of his symptoms.",
#  "**Clinical Notes**\n\nPatient, a 18-year-old female, presents to the clinic with symptoms consistent with influenza (flu). The patient reports fever, headache, sore throat, and difficulty breathing. Notably, she also experiences vomiting, increased thirst, blurred vision, and night sweats.\n\nUpon reviewing her vital signs, we observe elevated heart rate at 126 bpm, indicating potential respiratory distress. Her blood pressure readings are within normal limits, with systolic BP of 118 mmHg and diastolic BP of 78 mmHg. However, it's worth mentioning that her cholesterol level is slightly elevated at 149.9 mg/dL.\n\nGiven the combination of influenza-like symptoms, respiratory distress symptoms (difficulty breathing), and elevated heart rate, we suspect a possible secondary bacterial infection such as pneumonia.\n\n**Differential Diagnosis**\n\n- Influenza (Flu) with secondary bacterial pneumonia\n- Pneumonia with influenza superinfection\n\n**Next Steps**\n\n- Order chest X-ray to evaluate lung involvement\n- Prescribe antiviral medication for influenza and antibiotics for potential pneumonia\n- Monitor vital signs closely, including heart rate and oxygen saturation",
#  "Patient Presentation:\n\nA 31-year-old female patient was referred to our clinic for concerns of eczema (atopic dermatitis). Upon initial assessment, the patient reported experiencing a variety of symptoms. \n\nVital Signs:\n- Temperature: 99.5°F (37.7°C), indicating mild pyrexia\n- Pulse: 90 beats per minute, within normal limits\n- Blood Pressure: 120/80 mmHg, well within normal range\n- Respiratory Rate: 18 breaths per minute, slightly elevated\n- Oxygen Saturation: 96% on room air\n\nClinical Examination:\n\nUpon physical examination, the patient exhibited a characteristic rash on her arms and legs. Other notable findings include dry skin and painful urination.\n\nLaboratory Results:\nNo significant abnormalities were noted in routine laboratory tests. However, further studies are recommended to confirm the diagnosis of atopic dermatitis and rule out other potential causes for her symptoms.\n\nDifferential Diagnosis:\nWhile the patient's presentation is consistent with eczema (atopic dermatitis), a comprehensive evaluation is necessary to exclude other conditions that may be contributing to her symptoms, such as viral infections or allergic reactions.\n\nTreatment Plan:\nThe patient will require topical treatment for her eczema (atopic dermatitis) and recommendations for dietary changes. Further investigation into potential triggers that may be exacerbating the condition will also be pursued.\n\nFollow-up Appointment:\nA follow-up appointment has been scheduled in two weeks to monitor the patient's response to treatment and assess the efficacy of management strategies.",
#  "**Clinical Notes**\n\nPatient is a 50-year-old male presenting to the clinic with eczema (atopic dermatitis). Upon examination, he reports difficulty breathing, chest pain, diarrhea, loss of taste and smell, facial pain, ear pain, dry skin, and anxiety. His oxygen saturation is 97.5% on room air, which appears somewhat low for his symptoms.\n\nGiven the patient's respiratory symptoms (difficulty breathing, chest pain) alongside the gastrointestinal symptom (diarrhea), it is concerning for a possible esophageal rupture or a severe allergic reaction, potentially life-threatening. The loss of taste and smell could also suggest an underlying neurological condition. Additionally, facial and ear pain may indicate a sinusitis or otitis media.\n\nThe patient's anxiety level seems heightened, which may be related to his respiratory distress. It is essential to monitor his oxygen saturation closely and consider performing imaging studies (e.g., CT chest) to rule out any structural abnormalities in the lungs or esophagus.\n\n**Additional Considerations**\n\nIn light of this presentation, it would be prudent to inquire about the patient's recent exposure to allergens or irritants that could exacerbate his eczema. A thorough review of the patient's medical history is also warranted to identify any potential comorbid conditions that may contribute to these symptoms.\n\n**Plan of Care**\n\n1. Monitor oxygen saturation closely and report any further drops.\n2. Order CT chest imaging to evaluate for lung or esophageal pathology.\n3. Prescribe corticosteroids or immunomodulators as needed to manage eczema exacerbation.\n4. Consider antihistamines or bronchodilators for symptom relief, pending test results.\n\nThis is not a definitive diagnosis but rather an initial assessment based on the patient's symptoms and vital signs. Further evaluation and testing will be required to determine the underlying cause of these concerning symptoms.",
#  "**Clinical Notes**\n\nThe patient, a 24-year-old male, presented to the clinic with influenza (flu) as his motive for visitation.\n\n**History of Present Illness:**\nDuring the examination, the patient reported experiencing a cough, fatigue, headache, chest pain, runny nose, painful urination, and difficulty concentrating over the past few days. These symptoms have been progressively worsening throughout the day.\n\n**Physical Examination:**\nUpon physical examination, vital signs were taken to assess the patient's condition. The results are as follows:\n\n- **Vital Signs:**\n  - Heart Rate: 114 bpm (elevated)\n  - Respiratory Rate: 18 breaths/min (normal)\n  - Oxygen Saturation: 98.9% (slightly low, but within normal limits)\n  - Glucose Level: 81.8 mg/dL (within normal limits)\n\n**Assessment and Plan:**\nGiven the patient's history of influenza, elevated heart rate, and chest pain, it is essential to consider potential complications such as pneumonia or acute coronary syndrome. The patient's symptoms and vital signs suggest a need for close monitoring and further evaluation.\n\n- **Medications:** The patient will be prescribed antiviral medication for influenza and monitored closely for any worsening of symptoms.\n- **Follow-up Appointment:** A follow-up appointment is scheduled for the next day to reassess the patient's condition and adjust treatment as necessary.\n\n**Additional Notes:**\nThe patient's recent vaccination history was not mentioned, so it would be essential to inquire about this during future visits. Additionally, given the patient's age and symptoms, a discussion about potential mental health implications of prolonged illness may be beneficial in the future.",
#  "**Clinical Notes**\n\nThe patient, a 33-year-old female, presented to the clinic with a primary complaint of eczema (atopic dermatitis). During the initial evaluation, it was noted that she exhibited several additional symptoms including cough, difficulty breathing, abdominal pain, rash, blurred vision, weight loss, heartburn, and ear pain. These symptoms were not directly related to her primary complaint but warranted further investigation.\n\nUpon reviewing the patient's history, it appears that she has a long-standing history of atopic dermatitis, with episodes of exacerbation over the past several years. She also reported a family history of allergies and asthma.\n\n**Vital Signs:**\n\n* Blood pressure: 113/75 mmHg (slightly elevated systolic pressure)\n* Respiratory rate: 13 breaths/min (within normal limits)\n* Cholesterol level: 174.9 mg/dL (elevated)\n\nThe findings suggest that the patient's symptoms are not solely related to her eczema but rather indicative of a more complex condition, potentially an allergic reaction or asthma exacerbation.\n\n**Differential Diagnosis:**\n\nConsidering the patient's symptoms and elevated cholesterol level, several differential diagnoses come into play:\n\n1. Asthma exacerbation with eosinophilic pneumonia\n2. Allergic bronchopulmonary aspergillosis (ABPA)\n3. Eczema herpeticum\n4. Hyperlipidemia-related complications\n\n**Next Steps:**\n\nDue to the complexity of this case, further evaluation and testing are necessary to determine the underlying cause of the patient's symptoms.\n\n* Order a complete blood count (CBC) with differential to assess for eosinophilia\n* Perform a skin biopsy to rule out eczema herpeticum\n* Conduct an allergy panel to identify potential allergens contributing to her respiratory symptoms\n* Schedule follow-up appointment in 2 weeks to reassess symptoms and adjust treatment plan as needed\n\n**Medication:**\n\nInitiate antibiotic therapy for suspected ABPA, and consider adding a corticosteroid inhaler for asthma control.\n\n**Follow-up:**\n\nSchedule a follow-up appointment in 2 weeks to reassess the patient's symptoms and adjust the treatment plan accordingly.",
#  "**Clinical Notes**\n\nPatient, a 58-year-old female, presents to the clinic with a motivation for managing her Type 2 diabetes. \n\n**Vital Signs:**\n- Blood pressure: Systolic 115 mmHg, Diastolic 78 mmHg (elevated systolic BP)\n- Heart rate: 97 bpm\n- Oxygen saturation: 98.1% (slightly low)\n- Cholesterol level: 152.8 mg/dL (above target range)\n- Glucose level: 283.2 mg/dL (significantly elevated)\n\n**Symptoms:**\nThe patient reports a variety of symptoms including fatigue, sore throat, chest pain, abdominal pain, runny nose, joint pain, dizziness, loss of taste and smell, increased thirst, frequent urination, blurred vision, and wheezing.\n\nGiven the high glucose level and the presence of multiple systemic symptoms such as sweating (increased thirst), hyperkalemia (joint pain), and possibly an allergic reaction to a food item causing runny nose and sore throat, these signs suggest an acute diabetic ketoacidosis episode.\n\n**Differential Diagnosis:**\n- Acute diabetic ketoacidosis\n- Allergic reaction (food-borne)\n- Respiratory infection (bronchitis or pneumonia)\n\n**Plan:**\n- Order blood glucose levels every 2 hours until they are under control.\n- Start insulin therapy as per the patient's diabetes management plan.\n- Prescribe antihistamines for allergic reaction symptoms if present.\n- Order chest X-ray and complete blood count (CBC) with differential to evaluate for an underlying respiratory infection.\n\n**Follow-up:**\nSchedule follow-up appointment in 2 weeks to review patient's progress, adjust insulin therapy as necessary, and evaluate for any signs of complications from diabetic ketoacidosis.",
#  "**Clinical Notes**\n\nThe patient, a 24-year-old female, presented to the clinic with a primary concern of tuberculosis (TB) symptoms.\n\n**Vital Signs:**\n- Temperature: 36.6°C\n- Heart Rate: 95 bpm (slightly elevated)\n- Respiratory Rate: 18 breaths/min (normal)\n- Glucose Level: 113.8 mg/dL (elevated)\n\n**Symptoms:**\n\nThe patient reported a variety of symptoms, including cough, fatigue, chest pain, itchy eyes, frequent urination, night sweats, painful urination, swollen lymph nodes, and restlessness.\n\nUpon physical examination, the patient's vital signs were notable for an elevated heart rate and slightly elevated glucose level. The presence of swollen lymph nodes in the cervical region was also observed.\n\n**Differential Diagnosis:**\nGiven the symptomatology and laboratory findings, the differential diagnosis includes tuberculosis (TB), sarcoidosis, and other systemic illnesses that may present with similar symptoms.\n\n**Plan:**\nThe patient will undergo further evaluation, including a chest X-ray to confirm TB or rule out other pulmonary causes. A full blood count and liver function tests will also be ordered to assess for any secondary infections or associated conditions.\n\n**Next Steps:**\nThe patient will be started on prophylactic antibiotics for TB, pending confirmation of the diagnosis. Follow-up appointments are scheduled for 2 weeks and 4 weeks after initiation of treatment to monitor for response to therapy.\n\n**Additional Information:**\nPatient's history reveals that she has a family history of tuberculosis, which may have contributed to her presentation. She also reports having recently traveled to an area with high TB prevalence.",
#  "**Clinical Notes**\n\nPatient presented to the emergency department with a history of hypertension, and upon further evaluation, exhibited several concerning symptoms.\n\nThe patient, an elderly male aged 98, reported a series of symptoms including headache, difficulty breathing, chest pain, abdominal pain, dizziness, sneezing, itchy eyes, blurred vision, swollen lymph nodes, and heartburn. Notably, the patient's primary complaint was hypertension, but the breadth and severity of his presenting symptoms warrant further investigation.\n\nUpon assessment, the patient's temperature was 36.5°C, which is slightly elevated. His cholesterol level was found to be significantly elevated at 186.2 mg/dL.\n\nGiven the patient's age, history of hypertension, and the presence of multiple systemic symptoms, a diagnosis of **Pulmonary Embolism with Secondary Hypertension** is proposed. The patient's vitals, including an elevated temperature and cholesterol level, suggest a possible infectious or inflammatory component to his presentation.\n\nThe patient will require immediate attention in the intensive care unit for further evaluation and management. A computed tomography pulmonary angiogram (CTPA) is ordered to confirm the diagnosis of pulmonary embolism and assess for any additional complications.\n\n**Differential Diagnosis**: Given the patient's age and comorbidities, other potential diagnoses such as dehydration, sepsis, or acute coronary syndrome must also be considered. **Workup in Progress**\n\n**Medications**: Anticoagulation therapy will be initiated immediately to prevent further thromboembolic events.\n\n**Follow-up**: The patient will require close monitoring and follow-up appointments to evaluate the effectiveness of treatment and address any potential complications.",
#  "**Clinical Notes**\n\nPatient Presentation:\nA 70-year-old female patient presented to the clinic with a complaint of a common cold. She reported symptoms including vomiting, runny nose, sneezing, frequent urination, night sweats, ear pain, dry skin, and pale skin.\n\nVital Signs:\n\n* Blood Pressure: Systolic 111/60 mmHg (elevated)\n* Respiratory Rate: 16 breaths/min (mildly elevated)\n\nPhysical Examination:\nNot performed due to patient's presentation of a common cold. However, it is essential to note that the patient's pale skin and dry skin suggest a potential underlying dehydration issue.\n\nAssessment:\nGiven the patient's age, symptoms, and vital signs, I am inclined to suspect an underlying infection such as pneumonia or sinusitis. The elevated blood pressure and respiratory rate may indicate some level of systemic involvement. Further diagnostic testing, including a chest X-ray and a complete blood count (CBC), would be necessary to confirm this suspicion.\n\nMedication:\nThe patient will be prescribed antibiotics for potential bacterial sinusitis/pneumonia and antihistamines for allergic symptoms.\n\nFollow-up:\nSchedule follow-up appointment in 2-3 days to re-evaluate the patient's symptoms and adjust treatment as needed.",
#  "**Clinical Notes**\n\nPatient: [Name Redacted], Female, 18 years old.\n\nPresenting complaint: The patient is being evaluated for Tuberculosis (TB) which she reported as the motivation for her current visit. She has a history of living in an area with high TB prevalence and was recently diagnosed with TB through a rapid test.\n\nVital Signs:\n- Blood Pressure: Systolic 95 mmHg, Diastolic 72 mmHg\n- Temperature: 37.5°C\n\nSymptoms:\nShe reports fever, cough which is productive of rust-colored sputum, headache, sore throat, vomiting, runny nose, itchy eyes, night sweats, significant weight loss over the past month, and dry skin. Additionally, she mentions experiencing anxiety and difficulty concentrating.\n\nPhysical Examination: The patient appears pale with dull complexion and dry skin. Her eyes are itchy but no conjunctival injection is noted. She does not exhibit any signs of respiratory distress at this time.\n\nDifferential Diagnosis:\nGiven the symptoms and vital signs, TB is highly suspected. However, other differential diagnoses should be considered including a pulmonary embolism or influenza given the fever and cough.\n\nPlan: The patient will undergo further diagnostic testing including a complete blood count (CBC) with differential, erythrocyte sedimentation rate (ESR), and chest X-ray to confirm the diagnosis of TB. Additionally, she will start on antitubercular medication as prescribed by her primary care physician.\n\nFollow-up: The patient is scheduled for follow-up in 1 week to monitor for response to treatment and assess for any emergence of side effects from medication.\n\n**Addendum**\nGiven the patient's anxiety and difficulty concentrating symptoms along with fever, cough, and night sweats, it is essential to consider that she may be experiencing depression or post-traumatic stress disorder (PTSD) related to her TB diagnosis. Further mental health evaluation should be considered in subsequent visits.",
#  "Patient Presentation:\n\nOur patient, an 81-year-old female, presents to the office with symptoms consistent with influenza (flu). The patient reports a 3-day history of cough, fatigue, headache, and sore throat. Additionally, she notes difficulty breathing, diarrhea, runny nose, joint pain, itchy eyes, swollen lymph nodes, and dry skin.\n\nVital Signs:\n\nUpon assessment, the following vital signs were noted:\n\n- Blood Pressure: Systolic 98 mmHg, Diastolic 63 mmHg ( mildly low)\n- Temperature: 39.7°C (elevated)\n- Heart Rate: 135 bpm (tachycardia)\n- Respiratory Rate: 16 breaths/min (mildly elevated)\n- Oxygen Saturation: 95.3% (within normal limits)\n- Cholesterol Level: 181.9 mg/dL (slightly elevated)\n\nPhysical Examination:\n\nThe patient appears febrile and lethargic, with signs of respiratory compromise. The lungs are clear to auscultation bilaterally. Cardiovascular examination is unremarkable. The skin appears dry.\n\nLab Results:\n\nNot yet available for review.\n\nDifferential Diagnosis:\n\nGiven the patient's symptoms and vital signs, a diagnosis of influenza (flu) is considered. However, the patient's age, elevated temperature, and tachycardia also raise concerns for other potential diagnoses, including pneumonia or acute coronary syndrome. Further evaluation with imaging and laboratory studies will be necessary to determine the underlying cause.\n\nManagement:\n\nThe patient will be started on oseltamivir (Tamiflu) for suspected influenza. The patient's oxygen saturation levels will be closely monitored for any signs of respiratory distress. The patient's vital signs will be reassessed daily, and her condition will be re-evaluated as necessary to determine the best course of management.\n\nAdmission Status:\n\nBased on the patient's symptoms and vital signs, it is recommended that she be admitted to the hospital for close monitoring and further evaluation.\n\nAdditional Notes:\n\nThe patient has a history of hypertension and hyperlipidemia. Her cholesterol level was noted to be slightly elevated upon presentation. This may contribute to her tachycardia and elevated temperature. The patient's age also raises concerns for underlying comorbidities, such as cardiovascular disease or chronic obstructive pulmonary disease (COPD), that may be contributing to her symptoms.",
# ...
#  "**Clinical Notes**\n\nThe patient, a 36-year-old male, presented to the clinic with a motivation for pneumonia. Upon initial evaluation, he exhibited multiple symptoms consistent with pneumonia, including fever (38.5°C), cough, fatigue, difficulty breathing, nausea, abdominal pain, sneezing, loss of taste and smell, increased thirst, and swollen lymph nodes.\n\nVital signs revealed:\n\n* Temperature: 38.5°C\n* Heart rate: 76 bpm, which is within normal limits but slightly elevated, possibly indicative of a stress response.\n* Oxygen saturation: 88.4%, indicating mild hypoxemia.\n* Glucose level: 76.3 mg/dL, which is within the normal range.\n\nGiven the combination of respiratory symptoms (cough, difficulty breathing, loss of taste and smell), systemic symptoms (fever, fatigue, nausea, vomiting), and signs of potential dehydration (increased thirst), pneumonia should be considered a primary diagnosis. The patient's age and presentation are also consistent with community-acquired pneumonia.\n\nFurther evaluation is warranted to rule out complications such as acute bacterial pneumonia or atypical pneumonia. A complete blood count (CBC) and chest radiograph may be necessary to confirm the diagnosis and guide treatment.\n\n**Treatment plan suggestions:**\n\n* Antibiotics for suspected bacterial pneumonia\n* Supportive care for respiratory symptoms, including oxygen therapy if necessary\n* Fluid management to address potential dehydration\n* Close monitoring of vital signs and symptoms\n\n**Additional consideration:**\n\nThe patient's recent history is not mentioned in the provided information. However, as a clinician, I would inquire about the patient's previous illnesses, allergies, and any recent travel or exposure to contagious diseases that could have contributed to his current presentation.\n\n**Next steps:**\n\n* Order CBC and chest radiograph to confirm diagnosis\n* Prescribe antibiotics for suspected bacterial pneumonia\n* Monitor vital signs closely and adjust treatment plan as needed\n\nPlease note that this is a hypothetical scenario and actual clinical decisions should be made based on comprehensive patient histories, physical examinations, and laboratory results.",
#  "**Clinical Notes**\n\nThe patient, a 51-year-old female, presented to the clinic with anemia as her primary concern. Upon further evaluation, she reports a range of symptoms including fatigue, difficulty breathing, vomiting, rash, dizziness, loss of taste and smell, painful urination, facial pain, ear pain, sadness, and restlessness.\n\nVital signs revealed a temperature of 36.6°C, heart rate of 101 bpm, cholesterol level of 127.9 mg/dL, and glucose level of 127.9 mg/dL. Notably, the patient's vital signs are within normal limits with the exception of her elevated heart rate, which is slightly above the average range.\n\nThe patient's symptoms suggest a systemic manifestation of her anemia, possibly related to iron deficiency or blood loss. The presence of rash and facial/painful ear pain may indicate an underlying infection or inflammatory process. The loss of taste and smell could be indicative of vitamin B12 deficiency, which is often associated with anemia.\n\nGiven the patient's age, gender, and presentation, a possible diagnosis for further investigation is iron deficiency anemia due to menstrual blood loss (given her female gender), potentially complicated by an underlying infection or inflammatory process. Further diagnostic testing, including blood work and imaging studies, would be necessary to confirm this diagnosis and guide treatment.\n\n**Additional Notes**\n\n* The patient's sadness and restlessness may indicate a psychological component to her condition, warranting consideration of counseling or therapy as part of her overall care plan.\n* The elevated cholesterol and glucose levels are concerning for metabolic syndrome, which may need to be addressed in conjunction with the patient's anemia management.",
#  "**Clinical Notes**\n\nThe patient, a 33-year-old male, presents to our office with concerns of depression. Upon initial evaluation, the following symptoms were noted:\n\n* The patient reports fatigue and nausea, which have been persistent for several days.\n* Additionally, the patient experiences diarrhea, rash, dizziness, itchy eyes, and weight loss over the past week.\n* Notably, the patient exhibits restlessness and appears anxious.\n\nVital signs were taken during this visit, revealing:\n\n* Blood pressure: Systolic 112 mmHg, Diastolic 72 mmHg\n* Oxygen saturation: 98.3%\n* Glucose level: 110.7 mg/dL\n\nThese findings, in conjunction with the patient's reported symptoms, suggest a potential infectious etiology for the patient's depression and other symptoms. The elevated blood pressure and glucose levels may indicate an underlying metabolic or autonomic dysfunction.\n\nGiven the patient's presentation, I am inclined to consider a diagnosis of Infectious Mononucleosis (IM) or another viral illness that affects multiple systems, such as Lyme disease or Ehrlichiosis. Further testing, including complete blood counts, liver function tests, and serologies for IM and other tick-borne illnesses, may be necessary to confirm the underlying etiology.\n\nThe rash, dizziness, and itchy eyes could also suggest an allergic reaction or vasculitic process. However, given the combination of symptoms and lab findings, Infectious Mononucleosis remains a top consideration.\n\n**Recommendations:**\n\n* Order complete blood counts (CBC) with differential to evaluate for atypical lymphocytosis.\n* Perform liver function tests (LFTs) to assess for potential liver involvement.\n* Consider serologies for IM, Lyme disease, and Ehrlichiosis.\n* Administer empiric antibiotic coverage (e.g., amoxicillin/clavulanate) pending test results.\n\n**Follow-up:**\n\nSchedule follow-up appointment in one week to reevaluate symptoms and lab results.",
#  "**Clinical Notes**\n\nThe patient, a 77-year-old male, presented to the clinic with symptoms suggestive of COVID-19. Upon examination, he exhibited the following key findings:\n\n* Vital signs:\n\t+ Temperature: 38.3°C (out-of-range)\n\t+ Heart rate: 73 bpm (within normal limits)\n\t+ Respiratory rate: 14 breaths/min (within normal limits)\n\t+ Glucose level: 129.8 mg/dL (elevated, indicating hyperglycemia)\n* Physical examination revealed a rash on the patient's torso and pale skin.\n* The patient reported experiencing nausea, diarrhea, frequent urination, and heartburn over the past few days.\n* Restlessness was noted, which may be indicative of anxiety or discomfort.\n\nIn light of these findings, it is likely that the patient has COVID-19, with possible secondary complications such as hyperglycemia. Further testing, including a viral PCR and blood work to assess glucose levels and potential co-morbidities, should be considered to confirm the diagnosis and guide treatment.\n\nIt is also essential to consider potential comorbid conditions in this elderly male patient, such as diabetes mellitus, hypertension, or chronic kidney disease, which may have contributed to his elevated glucose level. A thorough medical history and review of systems are necessary to identify any underlying conditions that may be exacerbating the patient's symptoms.\n\nThe patient's vital signs indicate a moderate fever (38.3°C), but the respiratory rate is within normal limits. The heart rate is also within normal limits, which suggests that cardiac involvement is not immediately apparent. However, the elevated glucose level warrants further investigation to determine if there are any underlying conditions contributing to this finding.\n\nGiven the patient's age and symptoms, it is crucial to monitor his condition closely and consider hospitalization if his condition deteriorates or if he requires oxygen therapy.",
#  "**Clinical Notes**\n\nPatient, a 16-year-old female, presented to the clinic with anemia as her primary concern. Upon examination, she exhibited several symptoms that warranted further investigation.\n\nUpon taking her vital signs, we noted:\n\n- Temperature: 37.2°C (normal range)\n- Heart rate: 102 bpm (elevated)\n\nLaboratory results revealed elevated cholesterol levels at 152.8 mg/dL.\n\nThe patient's symptoms include fatigue, difficulty breathing, diarrhea, abdominal pain, runny nose, dizziness, loss of taste and smell, blurred vision, painful urination, swollen lymph nodes, pale skin, sadness, restlessness, and difficulty concentrating. Notably, her heart rate is elevated, which may indicate an underlying cardiovascular issue.\n\nConsidering the patient's age and symptoms, a possible diagnosis could be an autoimmune disorder such as Sjögren's syndrome. This condition can cause fatigue, joint pain (abdominal pain), swollen lymph nodes, dry eyes (loss of taste and smell), and skin changes (pale skin). The elevated cholesterol level may suggest an underlying metabolic issue.\n\nThe patient will require further testing to confirm the diagnosis and rule out other potential causes. Treatment will be tailored to address her specific condition, addressing symptoms such as fatigue and difficulty concentrating, while also managing cardiovascular risk factors through lifestyle modifications and possibly statin therapy for her high cholesterol levels.",
#  "**Clinical Notes**\n\nMs. [Patient's Name], a 54-year-old female, presented to the clinic with symptoms consistent with influenza (flu). Upon initial assessment, she appeared anxious and had pale skin.\n\nVital signs revealed:\n\n* Blood pressure: Systolic 91/70 mmHg, diastolic 70/60 mmHg\n* Temperature: 39.7°C\n* Heart rate: 116 bpm\n* Respiratory rate: 15 breaths/min\n* Cholesterol level: 129.7 mg/dL\n* Glucose level: 76.2 mg/dL\n\nNotably, her heart rate is elevated at 116 bpm, which may indicate a concerning cardiac response to the infection. Her temperature of 39.7°C further supports an influenza diagnosis.\n\nThe patient's difficulty breathing and loss of taste/smell are also concerning signs that warrant further investigation into potential complications such as pneumonia or sinusitis.\n\nAdditional history revealed that she has been experiencing fatigue and headache, which may be related to her underlying respiratory illness.\n\nGiven the severity of her symptoms and lab results, I am inclined to diagnose Influenza (Flu) with possible secondary complications. Further testing, including a chest X-ray and possibly a blood culture, will be necessary to determine the extent of any potential complications.\n\n**Plan:**\n\n* Administer oseltamivir 75mg twice daily for 3 days\n* Monitor vital signs closely for any worsening symptoms or concerning findings\n* Schedule follow-up appointment in 7-10 days to reassess patient's condition\n* Consider referral to an infectious disease specialist if complications arise.",
#  "**Clinical Notes**\n\nThe patient, a 16-year-old male, presented to the clinic with complaints of allergies. Upon initial evaluation, it is clear that this presentation is not consistent with typical allergic reactions.\n\nA thorough physical examination revealed signs suggestive of a more serious underlying condition. Notably, the patient exhibited pale skin (pale skin), which can be indicative of anemia or cardiovascular issue. The presence of chest pain and difficulty breathing raises concerns for a respiratory or cardiac etiology.\n\nFurther investigation is warranted to determine the cause of these symptoms. Given the patient's vitals, it is notable that their respiratory rate is elevated at 15 breaths per minute, which can be seen in cases of anxiety, stress, or even severe respiratory distress.\n\nThe patient's abdominal pain and vomiting are concerning for a gastrointestinal issue, while the runny nose, sneezing, and itchy eyes may suggest an allergy. However, the presence of dizziness and difficulty concentrating warrants further evaluation to rule out underlying neurological causes.\n\nIn light of these findings, I would like to order additional testing, including a complete blood count (CBC) to assess for signs of infection or inflammation, as well as a chest X-ray to evaluate the lungs for any potential abnormalities. A cardiac echocardiogram may also be considered given the patient's respiratory symptoms and elevated respiratory rate.\n\n**Initial Diagnosis**\n\nBased on the patient's presentation and initial evaluation, I would diagnose acute respiratory distress with possible underlying cardiac or gastrointestinal pathology. Further testing will be necessary to determine the exact cause of these symptoms and develop an effective treatment plan.",
#  "**Clinical Notes**\n\nPatient [Redacted] presented to the clinic with a primary complaint of depression, which appeared to be a motivation for her current visit.\n\nUpon initial assessment, patient reports fatigue, chest pain, vomiting, dizziness, loss of taste and smell, increased thirst, weight loss, and sadness. Notably, she also reported a decreased appetite.\n\nVital signs were taken during the examination: temperature 36.5°C, cholesterol level 129.6 mg/dL. Her temperature is slightly below normal range, indicating hypothermia, which may be related to her current symptoms of depression and possible underlying cardiovascular issues. Elevated cholesterol levels are also concerning for cardiovascular risk.\n\nGiven these findings, along with patient's reported loss of taste and smell, increased thirst, weight loss, and sadness, we should consider a differential diagnosis that includes:\n\n* Hypothyroidism\n* Hyperlipidemia\n* Cardiovascular disease (possible myocardial infarction)\n* Depression with potential underlying medical conditions contributing to her symptoms\n\nFurther investigation is needed to determine the underlying cause of these symptoms. The patient will be referred for a comprehensive metabolic panel, thyroid function tests, and an echocardiogram. A referral to our psychiatrist department has also been arranged, as her depression appears to be the primary driving force behind her current symptoms.\n\n**Additional Notes**\n\n* Patient's age (63) and reported weight loss may indicate comorbidities such as malabsorption or chronic illness.\n* The presence of chest pain and dizziness raises concerns about cardiac risk factors.\n* Further evaluation is necessary to determine if these symptoms are related to an underlying medical condition or depression.\n\n**To-Do List**\n\n* Comprehensive metabolic panel\n* Thyroid function tests\n* Echocardiogram\n* Referral to psychiatrist department for continued management of depression."]

# %% [markdown]
# ### symptoms

# %%
# Extract symptoms
symptoms_patterns = [
    r'symptoms?[:\- ]+([^\n]+)',
    # 'symptoms?' matches the word "symptom" or "symptoms" (optional 's').
    # '[:\- ]+' matches one or more ':', '-', or ' '.
    # '([^\n]+)' captures everything until a newline.
    r'complaints?[:\- ]+([^\n]+)',
    r'patient reports[:\- ]+([^\n]+)',
    r'symptoms include[:\- ]+([^\n]+)',
    r'presenting with[:\- ]+([^\n]+)'
]

# %%
# Find notes missing age patterns
missed_symptoms_notes = find_missing_pattern_notes(train["Note"], symptoms_patterns)

# Display the missed notes
print("Notes missing information count: ", len(missed_symptoms_notes))
# Out:
# Notes missing information count:  31

# %%
missed_symptoms_notes
# Out:
# ["**Clinical Notes**\n\nPatient presents with COVID-19 symptoms, highlighting the severity of his condition. \n\nUpon examination, patient's vital signs reveal:\n\n* Blood pressure: Systolic 113/80 mmHg (mildly elevated)\n* Temperature: 38.9°C (fever indicating infection)\n* Respiratory rate: 15 breaths/min (slightly increased)\n\nSymptomatically, the patient reports:\n* Fever\n* Cough\n* Fatigue\n* Difficulty breathing (indicative of respiratory distress)\n* Abdominal pain\n* Dizziness\n* Sneezing\n* Loss of taste and smell\n* Increased thirst\n* Blurred vision\n* Painful urination\n* Dry skin\n\nNotable, the patient's age (75) and comorbidities are not explicitly documented. However, it is essential to consider potential underlying health conditions that may exacerbate his condition.\n\nConsidering these findings, a likely diagnosis of COVID-19-induced acute respiratory distress with secondary complications (e.g., hypertension, dehydration, and electrolyte imbalances) is warranted. Further evaluation and management will be necessary to ensure optimal patient outcomes.\n\n**Initial Management Plan:**\n\n* Oxygen therapy with supplemental oxygen as needed\n* Antipyretics for fever control\n* Anti-histamines or bronchodilators for cough and shortness of breath\n* Fluid replacement with intravenous hydration\n* Monitoring of vital signs, laboratory results, and electrocardiogram (ECG)\n* Consideration of antiviral therapy if COVID-19 diagnosis is confirmed",
#  "**Clinical Notes**\n\nMrs. [Patient's Last Name], an 83-year-old female, presented with a chronic condition of Obstructive Pulmonary Disease (COPD). Upon examination, she exhibited several concerning symptoms, including:\n\n* A persistent cough, which worsened over time\n* Fatigue, making it difficult to perform daily activities\n* Difficulty breathing, particularly during exertion or lying flat\n* Chest pain that radiates to the back and worsens with deep breathing\n* Abdominal pain that is constant in nature\n* Joint pain and swelling in the hands and knees\n* Painful urination, indicating possible kidney stones or bladder issues\n* Ear pain that worsened over time, possibly related to Eustachian tube dysfunction\n* Pale skin, suggesting decreased oxygenation and potential anemia\n* Emotional distress, manifesting as sadness and restlessness\n\nVital signs revealed:\n\n* Blood pressure: 120/71 mmHg, which is within normal limits but may be influenced by COPD-induced fluid retention\n* Temperature: 37.5°C, indicating no acute infection or inflammation\n* Oxygen saturation: 97.1%, slightly low, suggesting possible respiratory compromise\n* Cholesterol level: 184.7 mg/dL, elevated, indicating increased cardiovascular risk\n\nGiven these findings, further investigation is warranted to rule out secondary complications, such as:\n\n* Pulmonary embolism: Given the sudden onset of shortness of breath and chest pain, a pulmonary embolism cannot be ruled out.\n* Chronic kidney disease: The painful urination suggests possible renal involvement, which warrants further evaluation.\n* Vitamin deficiencies: The fatigue, joint pain, and pale skin may indicate inadequate nutrition or vitamin deficiencies, particularly vitamin B12.\n\nGiven Mrs. [Patient's Last Name]'s complex medical history and concerning symptoms, a comprehensive geriatric assessment is warranted to address her overall health status and develop an appropriate treatment plan.",
#  "Patient Presentation:\n\nA 31-year-old female patient was referred to our clinic for concerns of eczema (atopic dermatitis). Upon initial assessment, the patient reported experiencing a variety of symptoms. \n\nVital Signs:\n- Temperature: 99.5°F (37.7°C), indicating mild pyrexia\n- Pulse: 90 beats per minute, within normal limits\n- Blood Pressure: 120/80 mmHg, well within normal range\n- Respiratory Rate: 18 breaths per minute, slightly elevated\n- Oxygen Saturation: 96% on room air\n\nClinical Examination:\n\nUpon physical examination, the patient exhibited a characteristic rash on her arms and legs. Other notable findings include dry skin and painful urination.\n\nLaboratory Results:\nNo significant abnormalities were noted in routine laboratory tests. However, further studies are recommended to confirm the diagnosis of atopic dermatitis and rule out other potential causes for her symptoms.\n\nDifferential Diagnosis:\nWhile the patient's presentation is consistent with eczema (atopic dermatitis), a comprehensive evaluation is necessary to exclude other conditions that may be contributing to her symptoms, such as viral infections or allergic reactions.\n\nTreatment Plan:\nThe patient will require topical treatment for her eczema (atopic dermatitis) and recommendations for dietary changes. Further investigation into potential triggers that may be exacerbating the condition will also be pursued.\n\nFollow-up Appointment:\nA follow-up appointment has been scheduled in two weeks to monitor the patient's response to treatment and assess the efficacy of management strategies.",
#  "**Clinical Notes**\n\nThe patient, a 92-year-old male, presented with a motivation of hypertension (high blood pressure) during this visit. Upon assessment, the patient exhibited several concerning symptoms, including headache, sore throat, difficulty breathing, chest pain, dizziness, facial pain, pale skin, and restlessness.\n\nVital signs revealed elevated blood pressure readings (systolic 155/88 mmHg), normal temperature (36.7°C), and a slightly elevated glucose level (70.3 mg/dL). The patient's oxygen saturation is likely compromised given the difficulty breathing symptom.\n\nConsidering the patient's age, underlying hypertension, and sudden onset of respiratory symptoms, a primary concern for this patient is **acute coronary syndrome with possible pulmonary embolism**. Further testing, including ECG, troponin levels, and possibly a CT pulmonary angiogram, should be performed to confirm or rule out these diagnoses.\n\nAdditionally, given the patient's age and comorbidities, it is essential to consider other potential causes for the symptoms, such as **pulmonary embolism with cardiac tamponade**. The patient's elevated blood pressure and restlessness may be indicative of a more severe condition requiring immediate attention.\n\nThe patient will be admitted to the ICU for further evaluation and management, with close monitoring of vital signs, ECG, and laboratory results.",
#  "**Clinical Notes**\n\nPatient, an 87-year-old female, presented with a motivation of diabetes (Type 2) due to recent onset symptoms.\n\n**Physical Examination:**\nThe patient reported difficulty breathing, abdominal pain, increased thirst, frequent urination, blurred vision, and wheezing. On examination, the patient's blood pressure was noted to be 96/70 mmHg, with a heart rate of 67 bpm. Respiratory rate was 18 breaths/min, and oxygen saturation was 96.7%. Notably, cholesterol level was elevated at 171.7 mg/dL.\n\n**Differential Diagnosis:**\nConsidering the patient's symptoms, including difficulty breathing, abdominal pain, and increased thirst, along with laboratory findings of elevated cholesterol levels, it is essential to consider hypoglycemic induced cardiac complications in the context of diabetes mellitus type 2.\n\nThe presence of wheezing and respiratory rate of 18 breaths/min may suggest pulmonary complications related to either diabetic ketoacidosis or acute coronary syndrome. Furthermore, the patient's age and gender, combined with her recent diagnosis of Type 2 diabetes, raises concerns for diabetic-related comorbidities such as cardiac disease.\n\n**Plan:**\nThe next step will be ordering a comprehensive metabolic panel to assess kidney function, liver enzymes, and further investigations into potential secondary causes of respiratory symptoms. Additionally, the patient should be evaluated for signs of cardiac stress or ischemia, and her diabetes management plan may require adjustments given these findings.\n\n**Additional Considerations:**\nGiven the patient's advanced age and recent diagnosis, it is also crucial to consider potential polypharmacy effects on her medications and assess for any potential interactions that could exacerbate her current symptoms.\n\nA follow-up appointment will be scheduled to review laboratory results, adjust management plans as necessary, and reassess the patient's condition.",
#  "**Clinical Notes**\n\nPatient presented with a 50-year-old male, seeking evaluation for eczema (atopic dermatitis). The patient's history is notable for a 5-year duration of symptoms, including recurrent skin rashes and itching. However, during this visit, the patient complains of new systemic symptoms.\n\nThe patient reports:\n\n* A cough that worsens at night\n* Fatigue, particularly in the morning\n* Vomiting after meals\n* A recent onset of rash, primarily on the trunk and limbs\n* Joint pain affecting the knees and elbows\n* Frequent urination\n* Night sweats, accompanied by a low-grade fever\n* Swollen lymph nodes in the neck\n* Facial pain, particularly on one side of the face\n* Ear pain, more pronounced when bending\n* Dry skin, despite previous eczematous lesions\n* Difficulty concentrating, impacting daily activities\n\nVital signs:\n\n* Temp: 37.0°C (normal)\n* HR: 67 bpm (slightly elevated)\n* O2 Sat: 97.2% (normal)\n* Glucose Level: 76.0 mg/dL (within normal limits)\n\nLaboratory results are pending, but the patient's presentation suggests a multisystem disorder. The combination of skin rashes, systemic symptoms, and laboratory abnormalities may indicate an underlying autoimmune or inflammatory process.\n\n**Diagnosis:** Atypical Eczema (Atopic Dermatitis) with possible systemic involvement.\n\n**Treatment Plan:**\n\n* Topical corticosteroids for eczematous lesions\n* Systemic antibiotics for suspected bacterial infection\n* Antihistamines for allergic reactions\n* Anti-inflammatory medications for joint pain and swelling\n* Immunomodulatory therapy to address potential autoimmune component\n\nFurther diagnostic testing, including laboratory studies and imaging, will be necessary to determine the underlying cause of this patient's symptoms.",
#  "**Clinical Note**\n\nPatient, a 44-year-old male, presented with eczema (atopic dermatitis). Upon examination, the patient exhibited several concerning symptoms, including:\n\nThe patient's rash is quite extensive and widespread, covering most of his body. The rash is itchy in nature and appears to be inflamed. \n\nThe patient also reports difficulty concentrating due to a persistent headache. Additionally, he presents with a sore throat, swollen lymph nodes, and an inability to focus due to sadness and anxiety.\n\nVital signs are notable for a decreased respiratory rate of 12 breaths per minute, which is below the normal range. The glucose level is within normal limits at 121.7 mg/dL.\n\nFurther evaluation is warranted to rule out any underlying conditions that may be contributing to this patient's symptoms. I plan to order some additional tests, including a complete blood count and possibly an echocardiogram given the patient's recent heartburn episodes.\n\n**Differential Diagnosis:**\n\n* Atopic dermatitis exacerbation\n* Viral pharyngitis\n* Postnasal drip or allergy-induced respiratory issues\n* Anxiety or depression-related symptoms\n\n**Plan:**\n\n* Order complete blood count and possibly an echocardiogram\n* Prescribe topical corticosteroids for the rash\n* Refer patient to a mental health professional for anxiety and depression screening\n* Continue to monitor vitals, especially respiratory rate",
#  "Clinical Notes:\n\nPatient Profile:\nThe patient is a 91-year-old female with a history of Type 2 diabetes. She presents with a variety of symptoms, including cough, difficulty breathing, joint pain, increased thirst, frequent urination, blurred vision, night sweats, facial pain, pale skin, and sadness.\n\nVital Signs:\nBlood Pressure: 110/60 mmHg (within normal range)\nTemperature: 37.0°C (within normal range)\nHeart Rate: 65 bpm (within normal range)\n\nClinical Findings:\nThe patient's vital signs are within the normal range, which is reassuring. However, the combination of her symptoms, including cough, difficulty breathing, and joint pain, along with her underlying diabetes, suggests the possibility of a respiratory infection or exacerbation of her diabetes. The blurred vision, increased thirst, and frequent urination are also indicative of poor glycemic control.\n\nThe patient's reported night sweats, pale skin, and sadness may indicate the presence of an underlying condition, such as anemia or depression, which could be contributing to her overall health status.\n\nDifferential Diagnosis:\nBased on the presented information, the following differential diagnoses are considered:\n1. Respiratory infection (e.g., pneumonia, bronchitis)\n2. Diabetic complications (e.g., diabetic ketoacidosis, hyperglycemic hyperosmolar state)\n3. Anemia\n4. Depression\n\nFurther Evaluation and Management:\nTo establish a definitive diagnosis and guide appropriate treatment, the following steps are recommended:\n- Comprehensive physical examination, including auscultation of the lungs and assessment of joint mobility\n- Laboratory tests, including complete blood count, comprehensive metabolic panel, and hemoglobin A1c to evaluate glycemic control and rule out anemia\n- Chest imaging (e.g., chest X-ray or CT scan) to assess for any respiratory pathology\n- Evaluation for signs of depression and consideration of appropriate mental health referral\n\nThe patient's diabetes management should be reviewed, and adjustments to her treatment plan may be necessary to optimize glycemic control and prevent further complications.",
#  "**Clinical Notes**\n\nThe patient, a 16-year-old female, presented with an ear infection (otitis media) and several additional symptoms. Upon examination, we noted:\n\n* The patient's vital signs were as follows:\n\t+ Respiratory rate: 19 breaths/min (elevated)\n\t+ Oxygen saturation: 95.3% (slightly below normal range)\n\t+ Cholesterol level: 128.9 mg/dL (mildly elevated)\n* Notable physical examination findings include:\n\t+ A rash on the upper arm\n\t+ Swollen lymph nodes in the neck\n\t+ Heartburn and ear pain, consistent with an otitis media infection\n\t+ The patient reported increased thirst and sadness\n\nThe combination of respiratory rate, oxygen saturation, and cholesterol level suggests that the patient may have a mild inflammatory response. However, given the constellation of symptoms, including headache, sore throat, rash, increased thirst, swollen lymph nodes, heartburn, ear pain, and sadness, an infectious process (such as otitis media) is likely.\n\nFurther evaluation is needed to determine the underlying cause of these symptoms. A comprehensive physical examination, laboratory studies (including blood work and possibly imaging), and treatment plan will be developed based on this patient's presentation.\n\n**Differential Diagnosis:**\n\n* Otitis media with complications (e.g., mastoiditis)\n* Viral pharyngitis with secondary bacterial infection\n* Allergic reaction or skin condition ( rash)\n\n**Plan:**\n\n* prescribe antibiotics for otitis media and provide symptomatic relief for ear pain, headache, and heartburn\n* refer to pediatrician for follow-up and additional evaluation if necessary\n\n**Follow-up:** Schedule a follow-up appointment in 1-2 weeks to assess response to treatment and evaluate for any complications.",
#  "**Clinical Notes**\n\nPatient [REDACTED], an 18-year-old male, presents with a visit motivation of suspected Strep Throat.\n\nUpon physical examination and review of symptoms, the patient reports:\n\n- A sore throat that worsens with movement\n- Generalized fatigue without an apparent cause\n- Mild headache, not severe\n- Difficulty breathing, with shortness of breath upon exertion\n- Chest pain radiating to the back, exacerbated by deep breathing\n- Diarrhea lasting for 2 days\n- Abdominal pain in the midline, constant and persistent\n- Sneezing fits occurring multiple times a day, often accompanied by swollen lymph nodes\n\nVital signs reveal:\n\n- Cholesterol level: 189.8 mg/dL (elevated)\n- Blood pressure: 110/70 mmHg\n- Pulse: 100/min (tachycardia)\n- Respiratory rate: 24/min (increased)\n- Oxygen saturation: 98% on room air\n\nBased on the clinical presentation, the primary concerns include a possible Strep Throat infection with respiratory complications (e.g., epiglottitis or severe pharyngitis), potentially complicated by an acute coronary syndrome given the elevated cholesterol level. Further diagnostic testing, such as rapid antigen detection tests for Group A beta-hemolytic streptococcus and lipid profile analysis to assess cardiovascular risk factors more thoroughly, is warranted.\n\n**Recommendation**: Admission to intensive care unit (ICU) due to respiratory compromise and potential cardiac involvement. Initiate empiric antibiotic therapy with penicillin or azithromycin and consider lipid-lowering agents for the patient's elevated cholesterol level.\n\n**Follow-up plan**: Schedule follow-up appointments in 24-48 hours to reassess symptoms, monitor vital signs, and adjust treatment as necessary.",
#  "**Clinical Notes**\n\nThe patient, a 17-year-old female, presented to the clinic with a concern for asthma exacerbation.\n\n**History of Present Illness:**\nUpon further questioning, the patient reported a several-day history of progressive dyspnea (difficulty breathing), fever, and cough. She also mentioned experiencing chest pain and a rash on her torso. Additionally, she has been experiencing joint pain, loss of taste and smell, wheezing, painful urination, swollen lymph nodes in her neck, heartburn, ear pain, pale skin, restlessness, and difficulty concentrating.\n\n**Physical Examination:**\nVital signs were obtained and are as follows:\n\n* Blood pressure: 90/65 mmHg (notably low for a teenager)\n* Heart rate: 64 bpm\n* Oxygen saturation: 96.1% (within normal limits)\n\nNotably, the patient's blood pressure is significantly lower than expected for her age group, indicating potential hypotension.\n\n**Differential Diagnosis:**\nGiven the combination of respiratory symptoms, fever, and systemic findings such as joint pain, loss of taste and smell, and low blood pressure, a diagnosis of acute viral syndrome with secondary bacterial infection (e.g., pertussis or tuberculosis) and asthma exacerbation cannot be ruled out. Other potential diagnoses include streptococcal pharyngitis, viral sinusitis, or influenza.\n\n**Plan:**\nOrder respiratory panel to confirm viral etiology, complete blood count (CBC) to evaluate for signs of infection, urinalysis to assess for urinary tract infection, and consider referral to pediatric pulmonology for asthma management.",
#  "**Clinical Notes**\n\nPatient Information:\n\n* Age: 43 years\n* Gender: Female\n\nChief Complaint:\nThe patient is seen for evaluation of Gastroesophageal Reflux Disease (GERD). However, upon initial assessment, it appears that the patient's presentation extends beyond typical GERD symptoms.\n\nMedications: None reported.\n\nVital Signs:\n\n* Blood Pressure:\n\t+ Systolic: 93 mmHg\n\t+ Diastolic: 74 mmHg\n* Temperature: 36.8°C (normal)\n* Heart Rate: 70 bpm\n\nSymptoms:\n\n* Fever, which is an unexpected finding in a patient with GERD.\n* Cough, which may be related to the fever or a separate condition.\n* Sore throat, potentially exacerbated by the cough.\n* Chest pain, which could be cardiac, pulmonary, or gastrointestinal in nature.\n* Nausea and facial pain, both of which are unusual for typical GERD presentations.\n\nDifferential Diagnosis:\n\nGiven the patient's age, sex, and the presence of fever, cough, and chest pain, a more extensive differential diagnosis needs to be considered. Possible diagnoses include:\n- Viral Upper Respiratory Tract Infection (URTI)\n- Community-Acquired Pneumonia (CAP)\n- Pulmonary Embolism (PE)\n- Cardiac Chest Pain or Myocardial Infarction\n\nFurther evaluation and diagnostic testing, including imaging studies such as chest X-ray and possibly a CT scan, are warranted to determine the underlying cause of these symptoms.",
#  "**Clinical Notes**\n\nPatient, a 66-year-old male, presented with chronic obstructive pulmonary disease (COPD). Upon assessment, the patient reports:\n\n* A persistent cough and increased sputum production\n* Fatigue lasting for several weeks\n* Difficulty breathing, particularly during exertion\n* Chest pain that worsens with deep breaths\n* Abdominal pain that is diffuse and non-specific\n* Sneezing spells, which are frequent and uncharacteristic\n* Increased thirst, leading to polyuria\n* Blurred vision, bilaterally symmetric\n* Facial pain, particularly in the cheeks and jaw\n* Ear pain, localized to the left ear\n\nVital signs:\n\n* Temperature: 37.4°C (Normal range: 36.5-37.9°C)\n* Respiratory rate: 16 breaths/min (Tachypnea)\n* Oxygen saturation: 96.0% (Mild hypoxia)\n* Cholesterol level: 129.7 mg/dL (Elevated)\n\nGiven the patient's age, comorbidities, and symptomatology, a working diagnosis of COPD exacerbation with possible pulmonary embolism or cardiac complications is considered. Further testing, including arterial blood gas analysis, chest radiograph, and echocardiogram, will be ordered to confirm these suspicions.\n\n**Addendum**: The patient's history of hypertension and hyperlipidemia may contribute to his current cardiovascular symptoms. Regular monitoring of his electrolytes, liver function, and kidney function is essential.\n\n**Treatment plan**:\n\n* Oxygen therapy at 2-3 l/min via nasal cannula\n* Inhaled corticosteroids (500 μg daily)\n* Bronchodilators (albuterol, 108 μg daily)\n* Antibiotics (amoxicillin/clavulanate) for suspected bacterial infection\n* Cardiac monitoring and echocardiogram within the next 24 hours\n\n**Follow-up appointment**: Scheduled for 3 days post-admission to reassess patient's condition and adjust treatment plan as necessary.",
#  "**Clinical Notes**\n\nThe patient, a 28-year-old female, presented with Strep Throat as the primary motivation for her visit. Upon examination, she exhibited several concerning symptoms, including sore throat, vomiting, frequent urination, and swollen lymph nodes. Additionally, she reported feelings of sadness and anxiety.\n\nVital signs were taken, revealing:\n\n* Temperature: 37.0°C (normal)\n* Oxygen saturation: 97.2% (within normal limits)\n* Cholesterol level: 162.4 mg/dL (slightly elevated)\n* Glucose level: 89.2 mg/dL (normal)\n\nNotably, the patient's glucose level and cholesterol level are slightly elevated, which may be related to her underlying Strep Throat infection. The presence of swollen lymph nodes suggests a possible infectious process.\n\nGiven these findings, it is essential to consider the possibility of a systemic infection beyond just Strep Throat. Further testing, such as blood work and throat swabs, may be necessary to confirm the diagnosis and rule out other potential causes of her symptoms.\n\n**Diagnosis:** Streptococcal Pharyngitis with possible Systemic Involvement (e.g., secondary strep infection or autoimmune response)\n\n**Recommendations:**\n\n* Prescribe antibiotics for Strep Throat as prescribed by primary care physician\n* Order further testing, including blood work and throat swabs, to confirm diagnosis and rule out other causes\n* Monitor glucose and cholesterol levels closely in the coming days to assess response to treatment\n\n**Next Steps:** Schedule follow-up appointment to review test results and adjust treatment plan as needed.",
#  '**Clinical Notes**\n\nPatient Information:\n- Age: 39 years\n- Gender: Female\n\nHistory of Present Illness:\nThe patient presents with anemia, which is the primary reason for this visit. She also reports a history of:\n\n* Coughing\n* Dizziness that worsens when standing up\n* Sneezing multiple times in the past hour\n* Wheezing upon inhalation\n* Swollen lymph nodes in the neck\n* Pale skin tone\n* Restlessness, feeling anxious and fatigued\n\nVital Signs:\n- Respiratory rate: 19 breaths/min (normal range: 12-20 breaths/min)\nThis elevated respiratory rate suggests possible respiratory distress or compensation for underlying hypoxia.\n\nPhysical Examination:\nFurther examination is needed to assess the extent of respiratory involvement. Swollen lymph nodes suggest an infectious or inflammatory process, which may be contributing to her anemia and other symptoms.\n\nLaboratory Results:\nNot available at this time.\n\nPlan:\n- Order complete blood count (CBC) with differential to confirm anemia and rule out underlying causes.\n- Conduct a thorough physical examination to assess respiratory, lymphatic, and cardiac systems.\n- Consider referring to an infectious disease specialist for further evaluation of the swollen lymph nodes.\n\nNext Steps:\nSchedule follow-up appointment in 2 weeks to review laboratory results and discuss management plan.',
#  "**Clinical Notes**\n\nPatient presented with pneumonia, a 30-year-old female, who is experiencing:\n\n* Fever\n* Cough\n* Difficulty breathing\n* Chest pain\n* Wheezing\n* Night sweats\n* Ear pain\n* Anxiety\n\nVital signs revealed:\n- Blood pressure: Systolic 115 mmHg, Diastolic 71 mmHg (elevated blood pressure)\n- Temperature: 38.1°C (fever)\n- Respiratory rate: 29 breaths/min (tachypnea)\n- Cholesterol level: 180.9 mg/dL (hypercholesterolemia)\n\nNotably, the patient's elevated respiratory rate and tachypnea suggest a severe respiratory infection. The combination of fever, cough, difficulty breathing, chest pain, wheezing, night sweats, ear pain, and anxiety points towards pneumonia. The high cholesterol level is concerning for potential cardiovascular risk factors.\n\nGiven the patient's age, symptoms, and vital signs, it appears that this patient has a severe case of pneumonia requiring close monitoring and treatment. Further diagnostic testing, such as chest X-ray or blood work, may be necessary to determine the underlying cause of her presentation and guide treatment decisions.",
#  "**Clinical Notes**\n\nPatient presented with a 29-year-old female, complaining of Strep Throat, accompanied by several systemic symptoms. Upon evaluation, the patient exhibited:\n\n* Fever: The patient's temperature was noted to be elevated at 38.2°C.\n* Fatigue: The patient reported feelings of exhaustion and weakness, further contributing to her overall malaise.\n* Sore throat: A significant amount of pain and tenderness were observed in the patient's throat during examination.\n* Vomiting: The patient experienced episodes of nausea and vomiting, exacerbating her discomfort.\n* Rash: A faint, erythematous rash was visible on the patient's arms and torso, indicating a possible secondary infection.\n* Increased thirst: The patient complained of excessive thirst and dry mouth, prompting concerns for potential dehydration.\n* Blurred vision: Slight blurred vision in both eyes was noted, suggesting that the patient may be experiencing some level of neurological involvement.\n* Sadness: The patient's emotional state was evident through her expression, indicating significant distress.\n\nVital signs revealed:\n\n* Blood pressure: 99/75 mmHg, which falls within normal limits but seems low for a feverish patient.\n* Respiratory rate: 15 breaths/min, slightly elevated and not particularly concerning at this time.\n* Oxygen saturation: 98.4%, indicating adequate oxygenation.\n\nLaboratory results are pending. The clinical picture suggests a diagnosis of Strep Throat complicated by possible secondary infections or neurological involvement. Further diagnostic testing will be necessary to confirm the presence of streptococcal infection and assess the extent of any complications.\n\n**Additional Note**: Given the patient's age, symptoms, and laboratory findings, it is essential to consider additional diagnoses, such as Kawasaki Disease (given the rash and fever) or Mononucleosis (due to fatigue and sore throat). Further evaluation will be required to determine the exact nature of this patient's condition.",
#  "**Clinical Notes**\n\nPatient, an 18-year-old female, presented with a history of Tuberculosis (TB). Upon examination, she exhibited:\n\n* Fever, which is out-of-range for her age group\n* Cough, productive and persistent\n* Fatigue, reported as feeling weak and lacking energy\n* Chest pain, localized to the left lower quadrant, worsened by deep breathing\n* Sneezing, episodic but increasing in frequency\n* Night sweats, frequent over the past month\n* Significant weight loss of 10 kg over the past 3 months\n\nHer vital signs revealed:\n* Blood pressure: Systolic 114/62 mmHg (elevated)\n* Heart rate: 91 bpm (slightly elevated)\n* Respiratory rate: 18 breaths/min (normal)\n* Glucose level: 85.3 mg/dL (slightly below normal range)\n\nFurther investigation is warranted to rule out active TB and address the patient's symptoms. Possible causes for her presentation include reinfection, post-primary TB, or an underlying respiratory condition.\n\n**Additional Notes**\nGiven the patient's age and presentation, it is essential to consider infectious diseases in her differential diagnosis. A Chest X-ray, complete blood count (CBC), and sputum smear test are recommended to confirm the presence of TB and assess for any co-infections.\n\nThe patient will be started on empiric antibiotics pending culture results and will undergo further evaluation to determine the underlying cause of her symptoms.",
#  "**Clinical Notes**\n\nPatient presented with COVID-19 symptoms, including cough, fatigue, difficulty breathing, vomiting, loss of taste and smell, swollen lymph nodes, and difficulty concentrating. The patient's vital signs revealed a temperature of 38.2°C, heart rate of 84 bpm, oxygen saturation of 85.3%, and glucose level of 74.1 mg/dL.\n\nUpon further evaluation, it appears that the patient is experiencing severe respiratory symptoms, with difficulty breathing being a significant concern. The elevated heart rate (84 bpm) may be indicative of anxiety or stress related to COVID-19. Notably, the oxygen saturation is slightly below normal range (88-95%), which warrants close monitoring.\n\nLaboratory results are pending, but based on the patient's presentation, it is likely that they will require supplemental oxygen and possibly antiviral medication to manage their symptoms. Further imaging studies may be necessary to evaluate for potential complications such as pneumonia or acute respiratory distress syndrome.\n\nGiven the patient's advanced age (81 years) and underlying comorbidities, it is essential to monitor them closely for signs of complications or deterioration. The patient will require close observation in a monitored unit with a team dedicated to their care.\n\n**Diagnosis:** Severe COVID-19 with respiratory compromise, requiring oxygen therapy and antiviral management.\n\n**Recommendations:**\n\n* Supplemental oxygen via non-rebreather mask\n* Antiviral medication (e.g., oseltamivir) as prescribed by the attending physician\n* Close monitoring of vital signs, oxygen saturation, and glucose levels\n* Possible imaging studies (e.g., chest CT scan) to evaluate for pulmonary complications\n\n**Next Steps:**\n\n* Consult with the attending physician to discuss treatment options and management plan.\n* Coordinate with laboratory services to expedite test results.\n* Arrange for a follow-up appointment in 24-48 hours to reassess the patient's condition.",
#  "**Clinical Notes**\n\nMrs. Johnson, an 86-year-old female, presented to our clinic today for evaluation of her hypertension. Upon initial assessment, it was noted that she has been experiencing difficulty breathing and mild chest pain, which worsened over the past few days.\n\nPhysical examination revealed a temperature of 37.5°C (99.5°F), blood pressure 138/108 mmHg, heart rate 97 bpm, and a cholesterol level of 126.5 mg/dL. Notably, her heart rate is slightly elevated, which may be indicative of a stress response or possible cardiac involvement.\n\nVital signs aside, Mrs. Johnson reported experiencing dizziness upon standing, which could suggest orthostatic hypotension. Her night sweats and swollen lymph nodes are concerning for an infectious process, such as sarcoidosis or lymphoma. Facial pain is also present, which may be related to her hypertension or another underlying condition.\n\nMrs. Johnson's history of hypertension is significant, with long-standing management and adherence to medication. However, recent changes in medication regimen or non-adherence have been noted by her primary care physician.\n\nA thorough physical examination, laboratory tests, and further diagnostic workup are required to determine the underlying cause of Mrs. Johnson's symptoms. Possible differential diagnoses include cardiac issues (e.g., coronary artery disease), respiratory conditions (e.g., chronic obstructive pulmonary disease – COPD), or systemic diseases (e.g., sarcoidosis).\n\n**Additional Considerations:**\n\n* Given Mrs. Johnson's age and sex, malignancy should be considered in the differential diagnosis.\n* The presence of night sweats and swollen lymph nodes warrants further investigation into potential infectious causes.\n* Hypertension management requires regular monitoring, particularly in elderly patients.\n* Further diagnostic testing (e.g., ECG, chest X-ray, pulmonary function tests) will be necessary to determine the underlying cause of her symptoms.\n\nA comprehensive diagnostic plan, including imaging studies and laboratory tests, will be developed to investigate Mrs. Johnson's presentation further.",
#  "**Clinical Notes**\n\nPatient, a 99-year-old female, was referred to our facility for evaluation and management of suspected coronary artery disease. Upon arrival, the patient exhibited several concerning symptoms.\n\nThe patient reported difficulty breathing, chest pain, dizziness, loss of taste and smell, blurred vision, wheezing, night sweats, fatigue, headache, sore throat, and a significant history of high cholesterol (165.8 mg/dL). Her respiratory rate was elevated at 17 breaths/min, which is significantly higher than the normal range.\n\nGiven her advanced age and combination of symptoms, we suspect coronary artery disease as the primary diagnosis. However, further testing and evaluation are needed to confirm this suspicion.\n\nThe patient's vitals, including anemia of chronic kidney disease (CKD), are being monitored closely due to her history of high cholesterol and elevated respiratory rate.\n\n**Additional Considerations:**\n\n* Patient has a significant medical history, including hypertension, diabetes mellitus, and chronic obstructive pulmonary disease (COPD).\n* The patient's loss of taste and smell is concerning for possible neurological involvement or pulmonary embolism.\n* Further testing, including echocardiogram, electrocardiogram, chest X-ray, and blood work, will be ordered to confirm the diagnosis and rule out other potential causes.\n\n**Referred Orders:**\n\n* Echocardiogram\n* Electrocardiogram\n* Chest X-ray\n* Blood work (including complete metabolic panel, electrolytes, and liver function tests)\n* Pulmonary function test (PFTs)\n\n**Next Steps:**\n\n* The patient will be ordered to rest with supplemental oxygen and pain medication as needed.\n* A referral to our cardiology department for further evaluation and management will be made.\n\n**Follow-up:**\n\nThe patient is scheduled for follow-up in 2 weeks to review lab results, discuss test findings, and reassess her symptoms.",
#  '**Clinical Notes**\n\nPatient, a 49-year-old female, presented with eczema (atopic dermatitis) and several systemic symptoms.\n\nThe patient reported a rash covering approximately 50% of her body surface area, accompanied by intense itching. She also experienced night sweats, indicating potential infection or inflammation. Swollen lymph nodes in the neck were noted, suggesting an immune response. Additionally, she complained of ear pain, pale skin, and restlessness, which could be indicative of anemia or other underlying conditions.\n\nVital signs revealed a mild fever (36.7°C), normal heart rate at 87 bpm, and respiratory rate within acceptable limits (18 breaths/min). However, the cholesterol level was elevated at 152.8 mg/dL, potentially indicating hyperlipidemia or metabolic syndrome. Blood glucose levels were slightly elevated at 91.2 mg/dL.\n\nGiven these findings, a possible differential diagnosis includes:\n\n* Atopic dermatitis with secondary infection and inflammation\n* Hyperlipidemia or metabolic syndrome\n* Anemia or iron deficiency\n* Infection (e.g., streptococcal pharyngitis) causing night sweats and swollen lymph nodes\n\nFurther investigation is required to determine the underlying cause of these symptoms. A comprehensive history, physical examination, laboratory tests, and potentially imaging studies may be necessary to guide management.\n\n**Recommendations**\n\n* Prescribe topical corticosteroids for eczema\n* Refer to a specialist (e.g., dermatologist or endocrinologist) for further evaluation and guidance on managing hyperlipidemia or metabolic syndrome\n* Order laboratory tests for complete blood count, liver function, and lipid profile to determine the underlying cause of anemia or elevated glucose levels\n* Consider imaging studies (e.g., CT scan or ultrasound) if infection is suspected',
#  "Clinical Notes:\n\nPatient Profile:\nThe patient is a 64-year-old female with a history of Type 2 diabetes. She presents with a variety of symptoms, including cough, fatigue, sore throat, nausea, diarrhea, increased thirst, night sweats, painful urination, ear pain, and sadness.\n\nVital Signs:\n- Blood Pressure: 112/77 mmHg (within normal range)\n- Respiratory Rate: 15 breaths/min (within normal range)\n- Cholesterol Level: 132.1 mg/dL (within normal range)\n- Glucose Level: 247.2 mg/dL (elevated, indicating poor glycemic control)\n\nClinical Impression:\nThe patient's presenting symptoms, including cough, sore throat, nausea, diarrhea, and ear pain, suggest the possibility of an underlying infection, potentially a viral or bacterial upper respiratory infection. The patient's elevated glucose level, a hallmark of uncontrolled diabetes, may be contributing to her increased thirst, fatigue, and night sweats. The patient's reported sadness may be related to the challenges of managing her chronic condition.\n\nGiven the patient's history of Type 2 diabetes and the presence of multiple symptoms, a comprehensive evaluation is warranted. This should include a thorough physical examination, laboratory tests (e.g., complete blood count, electrolytes, urinalysis), and potentially imaging studies to rule out any underlying infections or complications related to her diabetes.\n\nThe patient's glucose level should be closely monitored, and adjustments to her diabetes management plan may be necessary to achieve better glycemic control. Additionally, the patient may benefit from counseling or support services to address the emotional and psychological aspects of living with a chronic condition.",
#  "**Clinical Notes**\n\n**Patient Information:**\n- Age: 20 years old\n- Gender: Male\n\n**Visit Motivation:** Evaluation for suspected Tuberculosis (TB)\n\n**History of Present Illness:**\nThe patient presents with a two-week history of fever, persistent cough, nausea, and vomiting. He also reports experiencing joint pain, dizziness, night sweats, significant weight loss, and heartburn.\n\n**Review of Systems:**\n- **Constitutional:** Fever, fatigue, weight loss\n- **Respiratory:** Persistent cough\n- **Gastrointestinal:** Nausea, vomiting, heartburn\n- **Musculoskeletal:** Joint pain\n- **Neurological:** Dizziness\n\n**Vital Signs:**\n- Blood Pressure: 93/65 mmHg (hypotensive)\n- Temperature: 37.1°C (mildly elevated)\n- Respiratory Rate: 13 breaths/min (normal)\n\n**Diagnosis Considerations:**\nThe patient's symptoms, including fever, cough, joint pain, dizziness, night sweats, and weight loss, are highly suggestive of active pulmonary Tuberculosis (TB). The hypotension noted in the blood pressure measurement could indicate systemic involvement or secondary to possible dehydration from vomiting. Mildly elevated temperature is consistent with an infectious process.\n\n**Plan:**\n- Order a chest X-ray for evaluation.\n- Obtain sputum samples for acid-fast bacilli (AFB) stain and culture.\n- Consider ordering a tuberculin skin test (TST) or interferon-gamma release assay (IGRA).\n- Monitor vital signs closely, especially blood pressure due to the hypotensive reading.\n- Provide supportive care, including hydration management if necessary.\n\n**Further Actions:**\nThe patient will be advised to rest and follow up with a pulmonologist for further management. If TB is confirmed, appropriate antimicrobial therapy will be initiated as per local guidelines.",
#  '**Clinical Notes**\n\nPatient: Mr. [Last Name], 91-year-old male\n\nPresentation:\n\nThe patient presented to the clinic with chronic obstructive pulmonary disease (COPD) and a multitude of respiratory symptoms. Notably, he reports difficulty breathing, chest pain, and excessive fatigue, which are all consistent with his known diagnosis.\n\nVital Signs:\n\n* Respiratory rate: 17 breaths/min (rapid)\n* Other vital signs were within normal limits or not reported\n\nSymptoms:\n\n* Cough: productive with rust-colored sputum\n* Fatigue: marked, exacerbating his existing COPD symptoms\n* Sore throat: mild, possibly related to postnasal drip\n* Difficulty breathing: severe, worsened by exertion\n* Chest pain: sharp, pleuritic in nature, and exacerbated by deep breathing\n* Runny nose: persistent, possibly indicating sinus congestion\n* Dizziness: occasional episodes, likely due to low oxygen saturation\n* Sneezing: frequent, possibly related to allergies or sinusitis\n* Loss of taste/smell: total, as reported by the patient\n* Frequent urination: nocturnal and diurnal, possibly indicative of bladder overactivity\n\nMedication History:\n\nNone reported.\n\nPast Medical History:\n\nThe patient has a long-standing history of COPD, with multiple hospitalizations for exacerbations. He is also taking warfarin for atrial fibrillation, aspergilloma in his right lung, and 8-month-old heart disease.\n\n**Diagnosis:** Acute COPD Exacerbation (ACE) complicated by sinusitis, pleurisy, and possible cardiac involvement.\n\n**Plan:**\n\n* Oxygen therapy with a nasal cannula\n* Inhaled corticosteroids for chronic inflammation\n* Antibiotics for suspected sinusitis\n* Pain management with acetaminophen and codeine sulfate\n* Cardiac monitoring due to potential cardiac involvement\n* Pulmonary rehabilitation referral\n\nFurther evaluation and consultation were recommended.',
#  '**Clinical Notes**\n\nPatient, a 38-year-old female, presents with asthma as the primary concern. During this visit, she reports the following symptoms:\n\n- Cough\n- Sore throat\n- Difficulty breathing\n- Chest pain\n- Nausea\n- Frequent urination\n- Wheezing\n- Night sweats\n\nNotably, her vital signs reveal elevated cholesterol levels at 158.6 mg/dL.\n\nUpon physical examination, the patient appears anxious and uncomfortable due to her respiratory symptoms. Her pulse is somewhat elevated at 100 beats per minute, which may indicate a stress response. Her temperature is within normal limits.\n\nGiven the constellation of symptoms, particularly the combination of asthma exacerbation and unexplained changes in vital signs (elevated cholesterol level), it is imperative to conduct further diagnostic testing, including blood work to assess lipid profiles, inflammatory markers, and possible thyroid function tests due to the presence of night sweats. Additionally, a thorough review of her medication regimen and potential allergy culprits should be undertaken.\n\nA plan for immediate management consists of administering bronchodilators to alleviate respiratory symptoms, while also scheduling further investigation into the elevated cholesterol level. A referral to an endocrinologist or primary care provider specializing in lipid disorders is recommended for further evaluation and guidance on managing this newly identified comorbidity.',
#  "**Clinical Notes**\n\nPatient presented with otitis media, a common ear infection in adolescents. The patient is a 17-year-old male who reports a 2-day history of fever, cough, sore throat, and facial pain. Notably, he experiences difficulty breathing and wheezing, which are concerning for potential respiratory involvement.\n\nUpon evaluation, the patient's vital signs reveal a temperature of 37.2°C, an oxygen saturation level of 99.2%, and a cholesterol level of 127.8 mg/dL. While elevation in cholesterol is not uncommon in adolescents, this value is still within normal limits. The most concerning finding is the elevated oxygen saturation level, which may indicate respiratory distress or atelectasis.\n\nThe patient's symptoms, particularly difficulty breathing and wheezing, warrant further investigation into possible secondary complications such as acute bronchitis or asthma exacerbation. A thorough otolaryngological examination to assess middle ear pressure and tympanic membrane integrity is essential.\n\nThe presence of facial pain raises the suspicion for a possible mastoiditis. An ultrasound of the parotid gland may be indicated to rule out this complication. The patient should be closely monitored for signs of dehydration, as fever can lead to decreased urine output.\n\n**Differential Diagnosis**\n\n* Otitis media\n* Acute bronchitis\n* Asthma exacerbation\n* Mastoiditis\n\n**Next Steps**\n\nRefer the patient for an ultrasound of the parotid gland and further otolaryngological evaluation. Prescribe antibiotics for suspected otitis media, with consideration of mastoiditis and potential respiratory involvement.\n\nSchedule a follow-up appointment in 2-3 days to re-evaluate the patient's symptoms, oxygen saturation levels, and signs of dehydration.",
#  "Clinical Notes:\n\nPatient Profile:\nThe patient is a 96-year-old female with a history of type 2 diabetes. She presents with a variety of symptoms, including fatigue, nausea, runny nose, itchy eyes, increased thirst, frequent urination, blurred vision, weight loss, painful urination, facial pain, and pale skin.\n\nVital Signs:\nTemperature: 37.1°C (within normal range)\nHeart Rate: 90 bpm (slightly elevated)\nRespiratory Rate: 18 breaths/min (within normal range)\nOxygen Saturation: 99.6% (within normal range)\nGlucose Level: 265.3 mg/dL (significantly elevated, indicating poor glycemic control)\n\nClinical Impression:\nThe patient's presenting symptoms, including fatigue, nausea, increased thirst, frequent urination, blurred vision, weight loss, and pale skin, are consistent with poorly controlled type 2 diabetes. The elevated glucose level of 265.3 mg/dL confirms the patient's diabetic state and suggests the need for better management of her condition.\n\nThe patient's additional symptoms, such as runny nose, itchy eyes, facial pain, and painful urination, may indicate the presence of comorbid conditions or complications related to her diabetes. These could include diabetic neuropathy, urinary tract infection, or sinus/facial pain.\n\nGiven the patient's advanced age, it is important to consider the potential impact of her diabetes on her overall health and the risk of developing diabetic complications. Comprehensive evaluation and management of her diabetes, as well as any associated conditions, will be crucial in optimizing her care and quality of life.",
#  "**Clinical Notes**\n\nMrs. [Patient's Name], a 91-year-old female, presented with chronic obstructive pulmonary disease (COPD) as the motivation for her visit today.\n\nUpon examination, Mrs. [Patient's Last Name] reported experiencing:\n\n* A persistent cough over the past few months\n* Fatigue, which has been worsening in recent weeks\n* Sore throat, exacerbated by a recent viral illness\n* Significant difficulty breathing, particularly at night\n* Chest pain that worsens with deep breathing\n* Dizziness upon standing, indicating orthostatic hypotension\n* Itchy eyes, accompanied by watery discharge\n* Night sweats, which have increased in frequency and intensity over the past month\n* Heartburn that persists despite antacid medication\n* Ear pain, particularly when lying down\n* Pale skin, which may indicate anemia or poor circulation\n\nVital signs revealed:\n\n* Respiratory rate: 16 breaths/min (elevated)\n* Oxygen saturation: 98.5% (normal)\n* Glucose level: 74.8 mg/dL (slightly elevated)\n\nGiven her history of COPD, the presence of significant dyspnea and orthopnea, along with the elevated respiratory rate and normal oxygen saturation, suggests worsening pulmonary disease. The pale skin may indicate anemia or poor circulation, potentially related to chronic hypoxia.\n\nThe recent exacerbation of symptoms, including cough, fatigue, and difficulty breathing, warrants further investigation into potential causes, such as pneumonia or bronchitis. The heartburn and ear pain may be related to decreased mobility due to respiratory distress.\n\nA comprehensive treatment plan will focus on managing COPD symptoms, while also addressing the underlying causes of her recent exacerbation. This may include additional oxygen therapy, bronchodilators, and antibiotics if necessary. Further evaluation is required to determine the cause of her anemia or pale skin.\n\n**Additional Note:** Given Mrs. [Patient's Name]'s advanced age and comorbidities, it is essential to monitor her closely for signs of respiratory failure and consider palliative care options if her condition worsens.",
#  "**Clinical Notes**\n\nPatient, a 34-year-old female, presents with a history of asthma and current concerns of respiratory symptoms.\n\nUpon examination, the patient reports:\n\n* A persistent cough, which worsens over time\n* Sore throat, which is mildly tender to touch\n* Difficulty breathing, particularly during exertion or lying down\n* Diarrhea, which started 2 days ago\n* Runny nose with clear discharge\n* Joint pain in the hands and feet, bilateral\n* Sneezing fits several times a day\n* Wheezing on inhalation, particularly when using her asthma medication\n* Anxiety and restlessness, affecting daily activities\n* Difficulty concentrating due to persistent respiratory symptoms\n\nVital signs:\n\n* Temperature: 37.0°C (normal)\n* Heart rate: 81 bpm (slightly elevated)\n* Cholesterol level: 155.4 mg/dL (elevated)\n\nGiven the patient's history of asthma and current presentation, it is reasonable to suspect an acute exacerbation of her underlying condition. The presence of respiratory symptoms, such as cough, wheezing, and difficulty breathing, raises concern for a possible asthma attack.\n\nAdditionally, the patient's elevated heart rate and slightly elevated cholesterol level suggest that she may be experiencing stress or anxiety, which can exacerbate respiratory conditions like asthma.\n\nFurther evaluation is needed to determine the exact cause of these symptoms. A thorough physical examination, laboratory tests (e.g., pulmonary function testing), and possibly imaging studies (e.g., chest X-ray) will be necessary to confirm the diagnosis and guide further management.\n\n**Initial Diagnosis:** Acute Exacerbation of Asthma with possible secondary effects of anxiety and stress.\n\n**Relevant Medications:** Inhaled corticosteroids, bronchodilators, and a short-acting beta-agonist (if indicated).\n\n**Next Steps:**\n\n* Order pulmonary function testing to assess lung function\n* Prescribe inhaled corticosteroids and bronchodilators as prescribed by her asthma medication regimen\n* Schedule follow-up appointment for re-evaluation and adjustment of treatment as needed\n\nNote: This is a sample clinical note, and actual diagnosis and management may vary based on individual patient circumstances.",
#  "**Clinical Notes**\n\nThe patient, a 33-year-old male, presented with eczema (atopic dermatitis) as his primary concern. Upon examination, we noted the following symptoms:\n\n* Fever of 36.6°C\n* A widespread rash covering approximately 30% of his body surface area\n* Weight loss over the past month\n* Painful urination\n* Dry skin with significant scaling and erythema\n* Difficulty concentrating\n\nVital signs revealed:\n\n* Blood pressure: Systolic 118 mmHg, Diastolic 70 mmHg (normal range)\n* Temperature: 36.6°C (slightly elevated)\n* Respiratory rate: 18 breaths/min (normal range)\n* Oxygen saturation: 95.3% (within normal limits)\n* Cholesterol level: 164.1 mg/dL (elevated, indicating hypercholesterolemia)\n* Glucose level: 79.8 mg/dL (slightly elevated)\n\nNotably, the patient's cholesterol and glucose levels are elevated, which may be contributing to his symptoms. The painful urination could suggest a urinary tract infection or another underlying condition. Further testing and evaluation are necessary to determine the exact cause of the patient's atopic dermatitis and associated symptoms.\n\n**Additional Considerations:**\n\nGiven the patient's history of eczema, it is essential to consider potential triggers such as stress, allergies, or skin infections that may be exacerbating his symptoms. The elevated cholesterol levels also raise concerns about cardiovascular risk factors. A comprehensive treatment plan should address both the atopic dermatitis and any underlying conditions contributing to his symptoms.\n\n**Next Steps:**\n\n* Order a urinalysis to rule out urinary tract infection\n* Refer the patient for blood work including a lipid panel and further glucose testing\n* Consider immunosuppressive therapy or topical corticosteroids as initial treatment options for atopic dermatitis\n* Encourage stress management techniques and lifestyle modifications to help control symptoms\n\n**Follow-up:**\n\nSchedule follow-up appointments in 2-3 weeks to reassess the patient's condition, adjust treatment plan as needed, and address any concerns regarding medication side effects or adverse reactions."]

# %% [markdown]
# # Baseline model using regular expression

# %% [markdown]
# ## calculate accuracy

# %%
"""
All columns of the solution and submission dataframes are passed to your metric, except for the Usage column.

Your metric must satisfy the following constraints:
- You must have a function named score. Kaggle's evaluation system will call that function.
- You can add your own arguments to score, but you cannot change the first three (solution, submission, and row_id_column_name).
- All arguments for score must have type annotations.
- score must return a single, finite, non-null float.
"""

import pandas as pd
import pandas.api.types
import math
import json
import numpy as np


class ParticipantVisibleError(Exception):
    # If you want an error message to be shown to participants, you must raise the error as a ParticipantVisibleError
    # All other errors will only be shown to the competition host. This helps prevent unintentional leakage of solution data.
    pass


def to_json(s):
    """
    Converts input string to JSON-like Python object, if fails returns empty string.
    
    **Returns:**
        - Python dictionary or empty string
        
    **Examples:**
    
    >>> to_json('{"a": 10, "b":12}')
    {'a': 10, 'b': 12}
    """
    try:
        s_json = json.loads(s)
    except:
        print(f'Error converting to JSON: {s}')
        s_json = ''
    
    return s_json
    
def compare_json(a, b, key_weight=0.25, value_weight=0.75, alpha=1.):
    """
    Recursively computes a similarity score between two JSON-like Python objects.

    The similarity score ranges from 0 to 1, where:
    - 1 indicates that the objects are identical.
    - 0 indicates no similarity.

    **Comparison Rules:**

    - **Numerical Values (int, float):**
      - Similarity is calculated using an exponential decay function based on the absolute difference:
        \[
        \text{Similarity} = e^{-\alpha \times |a - b|}
        \]
      - **alpha** controls the rate at which similarity decreases as the difference increases.

    - **Strings:**
      - Similarity is the proportion of matching characters at the same positions relative to the length of the longer string:
        \[
        \text{Similarity} = \frac{\text{Number of Matching Characters}}{\text{Length of Longer String}}
        \]

    - **Booleans:**
      - Similarity is 1 if both values are the same, 0 otherwise.

    - **NoneType:**
      - Similarity is 1 if both values are `None`, 0 otherwise.

    - **Different Data Types:**
      - If the types of `a` and `b` differ, the similarity is 0.

    - **Dictionaries:**
      - **Key Similarity:** Calculated as the ratio of shared keys to total unique keys.
      - **Value Similarity:** Recursively computed similarities of the values corresponding to shared keys.
      - **Combined Similarity:** Weighted sum of key similarity and value similarity:
        \[
        \text{Similarity} = (\text{key\_weight} \times \text{Key Similarity}) + (\text{value\_weight} \times \text{Value Similarity})
        \]

    - **Lists:**
      - Elements are compared recursively up to the length of the shorter list.
      - Similarity is adjusted for lists of different lengths by multiplying by the ratio of the shorter length to the longer length.

    **Parameters:**

    - **a**: The first JSON-like object to compare. Can be a `dict`, `list`, `int`, `float`, `str`, `bool`, or `None`.
    - **b**: The second JSON-like object to compare.
    - **key_weight** *(float, optional)*: Weight for the key similarity in dictionaries. Defaults to `0.25`.
    - **value_weight** *(float, optional)*: Weight for the value similarity in dictionaries. Defaults to `0.75`.
    - **alpha** *(float, optional)*: Decay rate for numerical similarity. Higher values make the similarity decrease more rapidly with increasing difference. Defaults to `1.0`.

    **Returns:**

    - **similarity** *(float)*: A float between `0` and `1` representing the similarity between the two JSON objects.

    **Examples:**

    >>> compare_json(10, 10)
    1.0

    >>> compare_json(10, 12)   # Similarity = exp(-1.0 * abs(10 - 12))
    0.1353352832366127

    >>> compare_json("hello", "hallo") # Matches at positions 0 ('h') and 2 ('l') and 1 ('o')
    0.8

    >>> compare_json(True, True)
    1.0

    >>> compare_json(None, None)
    1.0

    >>> compare_json({"a": 1, "b": 2}, {"a": 1, "b": 3})
    0.7629547904392908

    >>> compare_json([1, 2, 3], [1, 2, 4])
    0.6666666666666666

    **Notes:**

    - The function is designed to handle nested structures and will recursively compare elements within dictionaries and lists.
    - Adjusting the `key_weight` and `value_weight` allows you to prioritize matching keys over matching values in dictionaries.
    - The `alpha` parameter allows tuning how quickly the similarity decreases for numerical differences; a higher `alpha` means that even small differences lead to low similarity.

    **Usage Tips:**

    - Ensure that the input objects are JSON-serializable Python data types.
    - For best results, pre-process your data to handle any special types or structures not covered by this function.

    **Limitations:**

    - The function does not handle custom objects or data types outside of standard JSON types.
    - For large and deeply nested structures, the function may have performance considerations due to recursion depth.

    """
    # Base case for numerical values
    if isinstance(a, (int, float)) and isinstance(b, (int, float)):
        abs_diff = abs(a - b)
        similarity = math.exp(-alpha * abs_diff)
        return similarity

    # Base case for strings
    elif isinstance(a, str) and isinstance(b, str):
        max_len = max(len(a), len(b))
        if max_len == 0:
            return 1.  # Both strings are empty
        match_count = sum(1 for c1, c2 in zip(a, b) if c1 == c2)
        similarity = match_count / max_len
        return similarity

    # Base case for booleans
    elif isinstance(a, bool) and isinstance(b, bool):
        return 1. if a == b else 0.

    # Base case for None
    elif a is None and b is None:
        return 1.

    # Different types
    elif type(a) != type(b):
        return 0.

    # Recursive case for dictionaries
    elif isinstance(a, dict) and isinstance(b, dict):
        keys_a = set(a.keys())
        keys_b = set(b.keys())
        all_keys = keys_a | keys_b
        if not all_keys:
            return 1.  # Both dicts are empty

        key_similarity = len(keys_a & keys_b) / len(all_keys)

        value_similarities = []
        for key in all_keys:
            if key in a and key in b:
                sim = compare_json(a[key], b[key], key_weight, value_weight, alpha)
                value_similarities.append(sim)
            else:
                value_similarities.append(0)

        value_similarity = sum(value_similarities) / len(value_similarities)

        # Combined similarity
        similarity = key_weight * key_similarity + value_weight * value_similarity
        return similarity

    # Recursive case for lists
    elif isinstance(a, list) and isinstance(b, list):
        a = set(a)
        b = set(b)
        mutual_items = a & b
        len_a = len(a)
        len_b = len(b)
        max_len = max(len_a, len_b)
        if max_len == 0:
            return 1.  # Both lists are empty
        else:
            return len(mutual_items) / max_len
    else:
        return 0.  # Unsupported data types or mismatch


def score(solution: pd.DataFrame, submission: pd.DataFrame, row_id_column_name: str) -> float:
    '''
    Computes the average similarity score between two DataFrames containing JSON-like data.

    This function compares corresponding JSON objects in the `solution` and `submission` DataFrames row by row and column by column. It calculates a similarity score for each pair of JSON objects and returns the overall average similarity score ranging from 0 to 1.

    **Parameters:**

    - **solution** *(pd.DataFrame)*: The DataFrame containing the ground truth JSON objects.
    - **submission** *(pd.DataFrame)*: The DataFrame containing the submitted JSON objects to be evaluated.
    - **row_id_column_name** *(str)*: The name of the column used as the row identifier, which will be removed before computation.

    **Returns:**

    - **float**: The average similarity score between the `solution` and `submission` DataFrames.
    
    Example:
    >>> import pandas as pd
    >>> row_id_column_name = "id"
    >>> json1 = """{"a": 10, "b": "Test", "c": {"a": -312.414, "z": [1,2,3]}}"""
    >>> json2 = """{"a": 0, "b": "Test", "c": {"a": -312.414, "z": [3,2,1]}}"""
    >>> y_pred = [json1, json2]
    >>> y_pred = pd.DataFrame(y_pred)
    >>> y_pred["id"] = range(len(y_pred))
    >>> y_true = [json2, json1]
    >>> y_true = pd.DataFrame(y_true)
    >>> y_true["id"] = range(len(y_true))
    >>> score(y_true.copy(), y_pred.copy(), row_id_column_name)
    0.7500113499824406
    '''

    del solution[row_id_column_name]
    del submission[row_id_column_name]

    matched_cols = []
    for col in submission.columns:
        if col in solution.columns:
            matched_cols.append(col)
    if len(matched_cols) != len(solution.columns):
        raise ParticipantVisibleError(f'Submission does not contains expected columns: {",".join([x for x in solution.columns])}')

    total = 0.
    for match in solution.columns:
        res = 0.
        for sub, sol in zip(submission[match].values, solution[match].values):
            sub = to_json(sub)
            sol = to_json(sol)
            score = compare_json(sub,sol)
            res+=float(score)
        res = res / len(solution)
        total += res
    return total / len(matched_cols)

# %% [markdown]
# ## model

# %%
structured_data = {
        "patient_info": {
            "age": None,
            "gender": None
        },
        "visit_motivation": "",
        "symptoms": [],
        "vital_signs": {
            "heart_rate": {
                "value": None,
                "unit": "bpm"
            },
            "oxygen_saturation": {
                "value": None,
                "unit": "%"
            },
            "cholesterol_level": {
                "value": None,
                "unit": "mg/dL"
            },
            "glucose_level": {
                "value": None,
                "unit": "mg/dL"
            },
            "temperature": {
                "value": None,
                "unit": "°C"
            },
            "respiratory_rate": {
                "value": None,
                "unit": "breaths/min"
            },
            "blood_pressure": {
                "systolic": {
                    "value": None,
                    "unit": "mmHg"
                },
                "diastolic": {
                    "value": None,
                    "unit": "mmHg"
                }
            }
        }
    }

# %%
# Function to transform a note to json
def note_to_json(note):
    
    # Age
    for pattern in age_patterns:
        match = re.search(pattern, note, re.IGNORECASE)
        if match:
            structured_data['patient_info']['age'] = int(match.group(1))
            break

    # Gender
    for pattern in gender_patterns:
        match = re.search(pattern, note, re.IGNORECASE)
        if match:
            structured_data['patient_info']['gender'] = match.group(1).capitalize()
            break

    # Motivation
    for pattern in motivation_patterns:
        match = re.search(pattern, note, re.IGNORECASE)
        if match:
            structured_data['visit_motivation'] = match.group(1).strip()
            break

    # Symptoms
    for pattern in symptoms_patterns:
        match = re.search(pattern, note, re.IGNORECASE)
        if match:
            symptoms_list = re.split(r',|\band\b', match.group(1))
            structured_data['symptoms'] = [symptom.strip() for symptom in symptoms_list if symptom.strip()]
            break

    # Extract vital signs
    vital_patterns = {
        'heart_rate': [r'heart rate[:\- ]+(\d+)', r'H[ea]*R[:\- ]+(\d+)'],
        # '[:\- ]+' matches one or more ':', '-', or ' '.
        # '(\d+)' captures one or more digits.

        #r'H[ea]*R[:\- ]+(\d+)'  # Matches "HR: 75"
        # 'H[ea]*R' matches "HR", "HeR", "HaR", etc.
        # '[:\- ]+' matches one or more ':', '-', or ' '.
        # '(\d+)' captures one or more digits.
        'oxygen_saturation': [r'oxygen saturation[:\- ]+(\d+)', r'SpO2[:\- ]+(\d+)%?'],
        # r'SpO2[:\- ]+(\d+)%?'  # Matches "SpO2: 95" or "SpO2: 95%"
        # 'SpO2' matches the literal phrase "SpO2".
        # '[:\- ]+' matches one or more ':', '-', or ' '.
        # '(\d+)' captures one or more digits.
        # '%?' optionally matches the '%' character.
        'cholesterol_level': [r'cholesterol level[:\- ]+(\d+)', r'cholesterol[:\- ]+(\d+)'],
        'glucose_level': [r'glucose level[:\- ]+(\d+)', r'blood glucose[:\- ]+(\d+)'],
        'temperature': [r'temperature[:\- ]+([\d\.]+)', r'temp[:\- ]+([\d\.]+)'],
        'respiratory_rate': [r'respiratory rate[:\- ]+(\d+)', r'respirations[:\- ]+(\d+)'],
        'blood_pressure': [r'blood pressure[:\- ]+(\d+)/(\d+)', r'BP[:\- ]+(\d+)/(\d+)']
    }

    for key, patterns_list in vital_patterns.items():
        for pattern in patterns_list:
            match = re.search(pattern, note, re.IGNORECASE)
            if match:
                if key == 'blood_pressure':
                    structured_data['vital_signs']['blood_pressure']['systolic']['value'] = float(match.group(1))
                    structured_data['vital_signs']['blood_pressure']['diastolic']['value'] = float(match.group(2))
                else:
                    structured_data['vital_signs'][key]['value'] = float(match.group(1))
                break

    return json.dumps(structured_data)

# %%
y_pred = pd.DataFrame()

# %%
y_pred["json"] = train["Note"].apply(note_to_json)

# %%
y_pred["ID"] = range(len(y_pred))

# %%
y_pred.head()
# Out:
#                                                 json  ID
# 0  {"patient_info": {"age": 41, "gender": "Male"}...   0
# 1  {"patient_info": {"age": 56, "gender": "Male"}...   1
# 2  {"patient_info": {"age": 73, "gender": "Female...   2
# 3  {"patient_info": {"age": 32, "gender": "Female...   3
# 4  {"patient_info": {"age": 51, "gender": "Male"}...   4

# %%
score(train[["ID", "json"]], y_pred[["ID", "json"]], "ID")
# Out:
# 0.5705814054808218

# %%
compare_df = pd.DataFrame()
compare_df["y_true"] = train["json"]
compare_df["y_pred"] = y_pred["json"]
