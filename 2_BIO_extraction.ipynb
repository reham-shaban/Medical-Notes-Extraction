# %% [markdown]
# # Preparing

# %%
import pandas as pd
import json, re

# %% [markdown]
# # Loading data

# %%
train = pd.read_csv("data/train.csv")

# %%
train.head()
# Out:
#    ID                                               Note  \
# 0   1  **Clinical Notes**\n\n**Patient Information:**...
# 1   2  Clinical Notes:\n\nPatient: 56-year-old male\n...
# 2   3  Clinical Notes:\n\nPatient: 73-year-old female...
# 3   4  **Clinical Notes**\n\n**Patient Information:**...
# 4   5  **Clinical Notes**\n\n**Patient:** Male, age 5...
#
#                                                 json
# 0  {"patient_info": {"age": 41, "gender": "Male"}...
# 1  {"patient_info": {"age": 56, "gender": "Male"}...
# 2  {"patient_info": {"age": 73, "gender": "Female...
# 3  {"patient_info": {"age": 32, "gender": "Female...
# 4  {"patient_info": {"age": 51, "gender": "Male"}...

# %% [markdown]
# # Pre-Processing

# %% [markdown]
# ## tokenization

# %%
def tokenize_text(text : str):
    """
    Tokenizes text while keeping patterns like 112/79, 39.4°C, and mg/dL intact,
    and separates numbers from hyphenated words.

    Args:
        text (str): The input text to tokenize.

    Returns:
        list: List of tokens.
    """
    # Remove '*' and lowercase the text
    text = text.replace('\n\n', '.')
    text = text.replace('*', '').lower()
    text = text.replace('-', ' ').lower()

    # regex to handle units and complex tokens
    tokens = re.findall(r'°c|\w+/\w+|\d+\.\d+|\d+/\d+|\d+|\w+|[^\w\s]', text)

    return tokens

# %%
train["Note"][0]
# Out:
# '**Clinical Notes**\n\n**Patient Information:**\n- Age: 41 years old\n- Gender: Male\n\n**Visit Motivation:** Anemia evaluation\n\n**Chief Complaints and Symptoms:**\nThe patient presents with complaints of anemia, fever, fatigue, difficulty breathing (dyspnea), vomiting, dizziness, blurred vision, wheezing, and pale skin. The patient reports that these symptoms have been progressively worsening over the past few weeks.\n\n**History of Present Illness:**\n- **Fever**: Intermittent low-grade fevers for approximately 2 weeks.\n- **Fatigue**: Persistent and severe fatigue affecting daily activities.\n- **Difficulty Breathing (Dyspnea)**: Experiencing shortness of breath, particularly with exertion. No history of chronic respiratory conditions.\n- **Vomiting**: Occasional episodes of non-bilious vomiting for the past week.\n- **Dizziness**: Episodes of dizziness, especially upon standing, which can be severe enough to cause near-fainting spells.\n- **Blurred Vision**: New onset of blurred vision, with occasional transient visual disturbances.\n- **Wheezing**: Recent history of wheezing noted by the patient during exertion or when lying down.\n\n**Review of Systems:**\n- Constitutional: Fatigue, fever\n- Respiratory: Dyspnea, wheezing\n- Gastrointestinal: Vomiting\n- Cardiovascular: Palpitations (not specifically reported but heart rate is elevated)\n- Neurological: Dizziness, blurred vision\n\n**Physical Examination:**\n- General Appearance: Patient appears pale and fatigued.\n- Vital Signs:\n  - Heart Rate: 114 bpm (tachycardia)\n  - Oxygen Saturation: 98.4% on room air\n  - Blood Pressure: BP not provided but should be assessed.\n  - Temperature: Not provided, but given the history of fever, elevated temperature should be considered.\n\n**Laboratory Findings and Vital Signs:**\n- **Hemoglobin**: Not directly measured in this note but anemia is noted as the visit motivation. Further workup for hemoglobin levels is necessary.\n- Cholesterol Level: 132.8 mg/dL (within normal range)\n- Glucose Level: 110.6 mg/dL (normal)\n\n**Assessment and Plan:**\nThe patient presents with a constellation of symptoms including fever, fatigue, dyspnea, vomiting, dizziness, blurred vision, wheezing, and pale skin, all of which may be related to anemia or other underlying conditions. The elevated heart rate could be secondary to the anemia and/or inflammatory response.\n\n**Diagnosis Considerations:**\n1. **Anemia**: Given the presentation of fatigue, dyspnea, and pale skin.\n2. **Infectious Process**: Potential infectious etiology contributing to fever and tachycardia.\n3. **Respiratory Issues**: Possible exacerbation of underlying respiratory conditions or secondary to anemia.\n4. **Gastrointestinal Disturbances**: Vomiting may indicate gastrointestinal involvement.\n\n**Plan:**\n1. Order complete blood count (CBC) with differential, reticulocyte count, and ferritin levels to assess the type and severity of anemia.\n2. Consider ordering chest X-ray and pulmonary function tests if respiratory symptoms are prominent.\n3. Monitor for signs of infection, including a CBC, CRP, and possibly cultures if clinically indicated.\n4. Address gastrointestinal symptoms with further evaluation if necessary (e.g., stool studies, abdominal imaging).\n5. Follow-up in 1-2 weeks or sooner based on the patient’s response to treatment and clinical status.\n\n**Nursing Care:**\nMonitor for signs of worsening anemia, dehydration from vomiting, and respiratory distress. Ensure adequate hydration and nutrition support as needed.'

# %%
# Example Usage
tokens = tokenize_text(train["Note"][0])
print(tokens)
# Out:
# ['clinical', 'notes', '.', 'patient', 'information', ':', 'age', ':', '41', 'years', 'old', 'gender', ':', 'male', '.', 'visit', 'motivation', ':', 'anemia', 'evaluation', '.', 'chief', 'complaints', 'and', 'symptoms', ':', 'the', 'patient', 'presents', 'with', 'complaints', 'of', 'anemia', ',', 'fever', ',', 'fatigue', ',', 'difficulty', 'breathing', '(', 'dyspnea', ')', ',', 'vomiting', ',', 'dizziness', ',', 'blurred', 'vision', ',', 'wheezing', ',', 'and', 'pale', 'skin', '.', 'the', 'patient', 'reports', 'that', 'these', 'symptoms', 'have', 'been', 'progressively', 'worsening', 'over', 'the', 'past', 'few', 'weeks', '.', '.', 'history', 'of', 'present', 'illness', ':', 'fever', ':', 'intermittent', 'low', 'grade', 'fevers', 'for', 'approximately', '2', 'weeks', '.', 'fatigue', ':', 'persistent', 'and', 'severe', 'fatigue', 'affecting', 'daily', 'activities', '.', 'difficulty', 'breathing', '(', 'dyspnea', ')', ':', 'experiencing', 'shortness', 'of', 'breath', ',', 'particularly', 'with', 'exertion', '.', 'no', 'history', 'of', 'chronic', 'respiratory', 'conditions', '.', 'vomiting', ':', 'occasional', 'episodes', 'of', 'non', 'bilious', 'vomiting', 'for', 'the', 'past', 'week', '.', 'dizziness', ':', 'episodes', 'of', 'dizziness', ',', 'especially', 'upon', 'standing', ',', 'which', 'can', 'be', 'severe', 'enough', 'to', 'cause', 'near', 'fainting', 'spells', '.', 'blurred', 'vision', ':', 'new', 'onset', 'of', 'blurred', 'vision', ',', 'with', 'occasional', 'transient', 'visual', 'disturbances', '.', 'wheezing', ':', 'recent', 'history', 'of', 'wheezing', 'noted', 'by', 'the', 'patient', 'during', 'exertion', 'or', 'when', 'lying', 'down', '.', '.', 'review', 'of', 'systems', ':', 'constitutional', ':', 'fatigue', ',', 'fever', 'respiratory', ':', 'dyspnea', ',', 'wheezing', 'gastrointestinal', ':', 'vomiting', 'cardiovascular', ':', 'palpitations', '(', 'not', 'specifically', 'reported', 'but', 'heart', 'rate', 'is', 'elevated', ')', 'neurological', ':', 'dizziness', ',', 'blurred', 'vision', '.', 'physical', 'examination', ':', 'general', 'appearance', ':', 'patient', 'appears', 'pale', 'and', 'fatigued', '.', 'vital', 'signs', ':', 'heart', 'rate', ':', '114', 'bpm', '(', 'tachycardia', ')', 'oxygen', 'saturation', ':', '98.4', '%', 'on', 'room', 'air', 'blood', 'pressure', ':', 'bp', 'not', 'provided', 'but', 'should', 'be', 'assessed', '.', 'temperature', ':', 'not', 'provided', ',', 'but', 'given', 'the', 'history', 'of', 'fever', ',', 'elevated', 'temperature', 'should', 'be', 'considered', '.', '.', 'laboratory', 'findings', 'and', 'vital', 'signs', ':', 'hemoglobin', ':', 'not', 'directly', 'measured', 'in', 'this', 'note', 'but', 'anemia', 'is', 'noted', 'as', 'the', 'visit', 'motivation', '.', 'further', 'workup', 'for', 'hemoglobin', 'levels', 'is', 'necessary', '.', 'cholesterol', 'level', ':', '132.8', 'mg/dl', '(', 'within', 'normal', 'range', ')', 'glucose', 'level', ':', '110.6', 'mg/dl', '(', 'normal', ')', '.', 'assessment', 'and', 'plan', ':', 'the', 'patient', 'presents', 'with', 'a', 'constellation', 'of', 'symptoms', 'including', 'fever', ',', 'fatigue', ',', 'dyspnea', ',', 'vomiting', ',', 'dizziness', ',', 'blurred', 'vision', ',', 'wheezing', ',', 'and', 'pale', 'skin', ',', 'all', 'of', 'which', 'may', 'be', 'related', 'to', 'anemia', 'or', 'other', 'underlying', 'conditions', '.', 'the', 'elevated', 'heart', 'rate', 'could', 'be', 'secondary', 'to', 'the', 'anemia', 'and/or', 'inflammatory', 'response', '.', '.', 'diagnosis', 'considerations', ':', '1', '.', 'anemia', ':', 'given', 'the', 'presentation', 'of', 'fatigue', ',', 'dyspnea', ',', 'and', 'pale', 'skin', '.', '2', '.', 'infectious', 'process', ':', 'potential', 'infectious', 'etiology', 'contributing', 'to', 'fever', 'and', 'tachycardia', '.', '3', '.', 'respiratory', 'issues', ':', 'possible', 'exacerbation', 'of', 'underlying', 'respiratory', 'conditions', 'or', 'secondary', 'to', 'anemia', '.', '4', '.', 'gastrointestinal', 'dist ...

# %% [markdown]
# ## extract entities

# %%
def extract_entities_from_json(json_data):
    """
    Extract entities from the given JSON into a dictionary for annotation.

    Args:
        json_data (dict): The JSON containing patient information, symptoms, vital signs, etc.

    Returns:
        dict: A dictionary of entities categorized by type without repetitions.
    """

    entities = {
        "AGE": [str(json_data["patient_info"]["age"])],
        "GENDER": [json_data["patient_info"]["gender"].lower()],
        "VISIT_MOTIVATION": [json_data["visit_motivation"].replace('-', ' ').lower()],
        "SYMPTOM": [symptom.replace("_", " ").lower() for symptom in json_data["symptoms"]],
        "BODY_MEASURE": [],
        "VALUE": [],
        "UNIT": [],
    }

    # Extract vital signs
    vital_signs = json_data.get("vital_signs", {})
    for measure, details in vital_signs.items():
        if measure == "blood_pressure" and isinstance(details, dict):  # Special handling for blood pressure
            systolic = details.get("systolic", {})
            diastolic = details.get("diastolic", {})
            if systolic and diastolic:  # Combine systolic and diastolic
                entities["BODY_MEASURE"].append("blood pressure")
                entities["VALUE"].append(f"{systolic['value']}/{diastolic['value']}")
                if systolic.get("unit") == diastolic.get("unit"):  # Add unit only once if the same
                    entities["UNIT"].append(systolic["unit"].lower())
        elif isinstance(details, dict) and "value" in details:  # Handle simple vital signs
            measure_name = measure.replace("_", " ").lower()
            value = str(details["value"]).lower()
            unit = details.get("unit", "").lower()

            if measure_name not in entities["BODY_MEASURE"]:
                entities["BODY_MEASURE"].append(measure_name)
            if value not in entities["VALUE"]:
                entities["VALUE"].append(value)
            if unit not in entities["UNIT"]:
                entities["UNIT"].append(unit)

    return entities

# %%
# Example Usage
entities = extract_entities_from_json(json.loads(train["json"][0]))
for key, value in entities.items():
    print(f"{key}: {value}")
# Out:
# AGE: ['41']
# GENDER: ['male']
# VISIT_MOTIVATION: ['anemia']
# SYMPTOM: ['fever', 'fatigue', 'difficulty breathing', 'vomiting', 'dizziness', 'blurred vision', 'wheezing', 'pale skin']
# BODY_MEASURE: ['heart rate', 'oxygen saturation', 'cholesterol level', 'glucose level']
# VALUE: ['114', '98.4', '132.8', '110.6']
# UNIT: ['bpm', '%', 'mg/dl']

# %% [markdown]
# ## covert json to entities

# %%
def annotate_text(tokens, entities):
    """
    Annotate tokens with BIO tags based on the provided entities and collect missed entities.

    Args:
        tokens (list of str): The tokenized text.
        entities (dict): Dictionary of entity types and their corresponding values.

    Returns:
        list of tuple: List of (token, tag) tuples representing the BIO-annotated tokens.
        dict: Dictionary of missed entities that did not find a match in the text.
    """
    bio_tags = []
  
    # Iterate over tokens
    for i in range(len(tokens)):
        matched = False
        # Check each entity type
        for entity_type, entity_values in entities.items():
            # Check each entity value
            for entity in entity_values:
                entity_tokens = tokenize_text(entity)  # Tokenize the entity value

                # Loop through words in entity
                for e_token in entity_tokens:
                    # Check if there's a word match
                    if tokens[i] == e_token:
                        # Check if first
                        if e_token == entity_tokens[0]:
                            bio_tags.append((tokens[i], f"B-{entity_type}"))
                            # Mark as matched
                            matched = True
                            break
                        elif i != 0 and (bio_tags[i-1][1] == f"B-{entity_type}" or bio_tags[i-1][1] == f"I-{entity_type}"):
                            bio_tags.append((tokens[i], f"I-{entity_type}"))
                            # Mark as matched
                            matched = True
                            break

                if matched:
                    break  # Stop checking further entity values for this token
            if matched:
                break  # Stop checking further entity types

        if not matched:
            bio_tags.append((tokens[i], "O"))  # Outside any entity

    return bio_tags

# %% [markdown]
# ## test

# %%
j = 10708
tokens = tokenize_text(train["Note"][j])
entities = extract_entities_from_json(json.loads(train["json"][j]))
bio_tags = annotate_text(tokens, entities)

# %%
bio_tags
# Out:
# [('clinical', 'O'),
#  ('notes', 'O'),
#  (':', 'O'),
#  ('.', 'O'),
#  ('patient', 'O'),
#  ('profile', 'O'),
#  (':', 'O'),
#  ('the', 'O'),
#  ('patient', 'O'),
#  ('is', 'O'),
#  ('a', 'O'),
#  ('31', 'B-AGE'),
#  ('year', 'O'),
#  ('old', 'O'),
#  ('female', 'B-GENDER'),
#  ('presenting', 'O'),
#  ('with', 'O'),
#  ('a', 'O'),
#  ('chief', 'O'),
#  ('complaint', 'O'),
#  ('of', 'O'),
#  ('anxiety', 'B-VISIT_MOTIVATION'),
#  ('disorders', 'I-VISIT_MOTIVATION'),
#  ('.', 'O'),
#  ('.', 'O'),
#  ('history', 'O'),
#  ('of', 'O'),
#  ('present', 'O'),
#  ('illness', 'O'),
#  (':', 'O'),
#  ('the', 'O'),
#  ('patient', 'O'),
#  ('reports', 'O'),
#  ('experiencing', 'O'),
#  ('a', 'O'),
#  ('variety', 'O'),
#  ('of', 'O'),
#  ('concerning', 'O'),
#  ('symptoms', 'O'),
#  (',', 'O'),
#  ('including', 'O'),
#  ('cough', 'B-SYMPTOM'),
#  (',', 'O'),
#  ('difficulty', 'B-SYMPTOM'),
#  ('breathing', 'I-SYMPTOM'),
#  (',', 'O'),
#  ('diarrhea', 'B-SYMPTOM'),
#  (',', 'O'),
#  ('runny', 'B-SYMPTOM'),
#  ('nose', 'I-SYMPTOM'),
#  (',', 'O'),
#  ('rash', 'B-SYMPTOM'),
#  (',', 'O'),
#  ('joint', 'B-SYMPTOM'),
#  ('pain', 'I-SYMPTOM'),
#  (',', 'O'),
#  ('sneezing', 'B-SYMPTOM'),
#  (',', 'O'),
#  ('blurred', 'B-SYMPTOM'),
#  ('vision', 'I-SYMPTOM'),
#  (',', 'O'),
#  ('painful', 'B-SYMPTOM'),
#  ('urination', 'I-SYMPTOM'),
#  (',', 'O'),
#  ('dry', 'B-SYMPTOM'),
#  ('skin', 'I-SYMPTOM'),
#  (',', 'O'),
#  ('pale', 'B-SYMPTOM'),
#  ('skin', 'I-SYMPTOM'),
#  (',', 'O'),
#  ('anxiety', 'B-VISIT_MOTIVATION'),
#  (',', 'O'),
#  ('restlessness', 'B-SYMPTOM'),
#  (',', 'O'),
#  ('and', 'O'),
#  ('difficulty', 'B-SYMPTOM'),
#  ('concentrating', 'I-SYMPTOM'),
#  ('.', 'O'),
#  ('the', 'O'),
#  ('onset', 'O'),
#  ('and', 'O'),
#  ('duration', 'O'),
#  ('of', 'O'),
#  ('these', 'O'),
#  ('symptoms', 'O'),
#  ('are', 'O'),
#  ('not', 'O'),
#  ('clearly', 'O'),
#  ('specified', 'O'),
#  ('.', 'O'),
#  ('.', 'O'),
#  ('review', 'O'),
#  ('of', 'O'),
#  ('systems', 'O'),
#  (':', 'O'),
#  ('respiratory', 'B-BODY_MEASURE'),
#  (':', 'O'),
#  ('cough', 'B-SYMPTOM'),
#  ('and', 'O'),
#  ('difficulty', 'B-SYMPTOM'),
#  ('breathing', 'I-SYMPTOM'),
#  ('gastrointestinal', 'O'),
#  (':', 'O'),
#  ('diarrhea', 'B-SYMPTOM'),
#  ('skin', 'I-SYMPTOM'),
#  (':', 'O'),
#  ('rash', 'B-SYMPTOM'),
#  (',', 'O'),
#  ('dry', 'B-SYMPTOM'),
#  ('skin', 'I-SYMPTOM'),
#  (',', 'O'),
#  ('pale', 'B-SYMPTOM'),
#  ('skin', 'I-SYMPTOM'),
#  ('musculoskeletal', 'O'),
#  (':', 'O'),
#  ('joint', 'B-SYMPTOM'),
#  ('pain', 'I-SYMPTOM'),
#  ('neurological', 'O'),
#  (':', 'O'),
#  ('blurred', 'B-SYMPTOM'),
#  ('vision', 'I-SYMPTOM'),
#  (',', 'O'),
#  ('anxiety', 'B-VISIT_MOTIVATION'),
#  (',', 'O'),
#  ('restlessness', 'B-SYMPTOM'),
#  (',', 'O'),
#  ('difficulty', 'B-SYMPTOM'),
#  ('concentrating', 'I-SYMPTOM'),
#  ('genitourinary', 'O'),
#  (':', 'O'),
#  ('painful', 'B-SYMPTOM'),
#  ('urination', 'I-SYMPTOM'),
#  ('.', 'O'),
#  ('vital', 'O'),
#  ('signs', 'O'),
#  (':', 'O'),
#  ('heart', 'B-BODY_MEASURE'),
#  ('rate', 'I-BODY_MEASURE'),
#  (':', 'O'),
#  ('75', 'B-VALUE'),
#  ('bpm', 'B-UNIT'),
#  ('(', 'O'),
#  ('within', 'O'),
#  ('normal', 'O'),
#  ('range', 'O'),
#  (')', 'O'),
#  ('respiratory', 'B-BODY_MEASURE'),
#  ('rate', 'I-BODY_MEASURE'),
#  (':', 'O'),
#  ('14', 'B-VALUE'),
#  ('breaths/min', 'B-UNIT'),
#  ('(', 'O'),
#  ('within', 'O'),
#  ('normal', 'O'),
#  ('range', 'O'),
#  (')', 'O'),
#  ('.', 'O'),
#  ('physical', 'O'),
#  ('examination', 'O'),
#  (':', 'O'),
#  ('a', 'O'),
#  ('comprehensive', 'O'),
#  ('physical', 'O'),
#  ('examination', 'O'),
#  ('was', 'O'),
#  ('not', 'O'),
#  ('performed', 'O'),
#  (',', 'O'),
#  ('but', 'O'),
#  ('the', 'O'),
#  ('patient', 'O'),
#  ("'", 'O'),
#  ('s', 'O'),
#  ('reported', 'O'),
#  ('symptoms', 'O'),
#  (',', 'O'),
#  ('including', 'O'),
#  ('the', 'O'),
#  ('rash', 'B-SYMPTOM'),
#  (',', 'O'),
#  ('joint', 'B-SYMPTOM'),
#  ('pain', 'I-SYMPTOM'),
#  (',', 'O'),
#  ('and', 'O'),
#  ('blurred', 'B-SYMPTOM'),
#  ('vision', 'I-SYMPTOM'),
#  (',', 'O'),
#  ('suggest', 'O'),
#  ('potential', 'O'),
#  ('underlying', 'O'),
#  ('medical', 'O'),
#  ('conditions', 'O'),
#  ('that', 'O'),
#  ('require', 'O'),
#  ('further', 'O'),
#  ('evaluation', 'O'),
#  ('.', 'O'),
#  ('.', 'O'),
#  ('differential', 'O'),
#  ('diagnosis', 'O'),
#  (':', 'O'),
#  ('based', 'O'),
#  ('on', 'O'),
#  ('the', 'O'),
#  ('patient', 'O'),
#  ("'", 'O'),
#  ('s', 'O'),
#  ('presenting', 'O'),
#  ('symptoms', 'O'),
#  (',', 'O'),
#  ('the', 'O'),
#  ('following', 'O'),
#  ('differential', 'O'),
#  ('diagnoses', 'O'),
#  ('are', 'O'),
#  ('considered', 'O'),
#  (':', 'O'),
#  ('1', 'O'),
#  ('.', 'O'),
#  ('viral', 'O'),
#  ('infection', 'O'),
#  ('(', 'O'),
#  ('e', 'O'),
#  ('.', 'O'),
#  ('g', 'O'),
#  ('.', 'O'),
#  (',', 'O'),
#  ('influenza', 'O'),
#  (',', 'O'),
#  ('covid', 'O'),
#  ('19', 'O'),
#  (',', 'O'),
#  ('common', 'O'),
#  ('cold', 'O'),
#  (')', 'O'),
#  ('2', 'O'),
#  ('.', 'O'),
#  ('autoimmune', 'O'),
#  ('disorder', 'O'),
#  ('(', 'O'),
#  ('e', 'O'),
#  ('.', 'O'),
#  ('g', 'O'),
#  ('.', 'O'),
#  (',', 'O'),
#  ('rheumatoid', 'O'),
#  ('arthritis', 'O'),
#  (',', 'O'),
#  ('lupus', 'O'),
#  (')', 'O'),
#  ('3', 'O'),
#  ('.', 'O'),
#  ('urinary', 'O'),
#  ('tract', 'O'),
#  ('infection', 'O'),
#  ('4', 'O'),
#  ('.', 'O'),
#  ('anxiety', 'B-VISIT_MOTIVATION'),
#  ('disorder', 'O'),
#  ('.', 'O'),
#  ('diagnostic', 'O'),
#  ('plan', 'O'),
#  (':', 'O'),
#  ('obtain', 'O'),
#  ('laboratory', 'O'),
#  ('tests', 'O'),
#  ('(', 'O'),
#  ('complete', 'O'),
#  ('blood', 'O'),
#  ('count', 'O'),
#  (',', 'O'),
#  ('comprehensive', 'O'),
#  ('metabolic', 'O'),
#  ('panel', 'O'),
#  (',', 'O'),
#  ('urinalysis', 'O'),
#  (')', 'O'),
#  ('consider', 'O'),
#  ('imaging', 'O'),
#  ('studies', 'O'),
#  ('(', 'O'),
#  ('chest', 'O'),
#  ('x', 'O'),
#  ('ray', 'O'),
#  (',', 'O'),
#  ('joint', 'B-SYMPTOM'),
#  ('x', 'O'),
#  ('rays', 'O'),
#  (')', 'O'),
#  ('refer', 'O'),
#  ('the', 'O'),
#  ('patient', 'O'),
#  ('to', 'O'),
#  ('a', 'O'),
#  ('mental', 'O'),
#  ('health', 'O'),
#  ('professional', 'O'),
#  ('for', 'O'),
#  ('a', 'O'),
#  ('comprehensive', 'O'),
#  ('evaluation', 'O'),
#  ('of', 'O'),
#  ('the', 'O'),
#  ('anxiety', 'B-VISIT_MOTIVATION'),
#  ('disorder', 'O'),
#  ('.', 'O'),
#  ('treatment', 'O'),
#  ('plan', 'O'),
#  (':', 'O'),
#  ('provide', 'O'),
#  ('symptomatic', 'O'),
#  ('relief', 'O'),
#  ('for', 'O'),
#  ('the', 'O'),
#  ('patient', 'O'),
#  ("'", 'O'),
#  ('s', 'O'),
#  ('reported', 'O'),
#  ('symptoms', 'O'),
#  ('(', 'O'),
#  ('e', 'O'),
#  ('.', 'O'),
#  ('g', 'O'),
#  ('.', 'O'),
#  (',', 'O'),
#  ('cough', 'B-SYMPTOM'),
#  (',', 'O'),
#  ('diarrhea', 'B-SYMPTOM'),
#  (',', 'O'),
#  ('joint', 'B-SYMPTOM'),
#  ('pain', 'I-SYMPTOM'),
#  (')', 'O'),
#  ('initiate', 'O'),
#  ('appropriate', 'O'),
#  ('treatment', 'O'),
#  ('for', 'O'),
#  ('the', 'O'),
#  ('underlying', 'O'),
#  ('condition', 'O'),
#  ('(', 'O'),
#  ('s', 'O'),
#  (')', 'O'),
#  ('based', 'O'),
#  ('on', 'O'),
#  ('the', 'O'),
#  ('diagnostic', 'O'),
#  ('findings', 'O'),
#  ('coordinate', 'O'),
#  ('care', 'O'),
#  ('with', 'O'),
#  ('a', 'O'),
#  ('mental', 'O'),
#  ('health', 'O'),
#  ('professional', 'O'),
#  ('for', 'O'),
#  ('the', 'O'),
#  ('management', 'O'),
#  ('of', 'O'),
#  ('the', 'O'),
#  ('patient', 'O'),
#  ("'", 'O'),
#  ('s', 'O'),
#  ('anxiety', 'B-VISIT_MOTIVATION'),
#  ('disorder', 'O'),
#  ('.', 'O'),
#  ('the', 'O'),
#  ('patient', 'O'),
#  ("'", 'O'),
#  ('s', 'O'),
#  ('overall', 'O'),
#  ('presentation', 'O'),
#  ('and', 'O'),
#  ('reported', 'O'),
#  ('symptoms', 'O'),
#  ('warrant', 'O'),
#  ('a', 'O'),
#  ('thorough', 'O'),
#  ('evaluation', 'O'),
#  ('to', 'O'),
#  ('identify', 'O'),
#  ('the', 'O'),
#  ('underlying', 'O'),
#  ('cause', 'O'),
#  ('(', 'O'),
#  ('s', 'O'),
#  (')', 'O'),
#  ('and', 'O'),
#  ('provide', 'O'),
#  ('appropriate', 'O'),
#  ('treatment', 'O'),
#  ('.', 'O'),
#  ('close', 'O'),
#  ('monitoring', 'O'),
#  ('and', 'O'),
#  ('follow', 'O'),
#  ('up', 'O'),
#  ('will', 'O'),
#  ('be', 'O'),
#  ('essential', 'O'),
#  ('to', 'O'),
#  ('ensure', 'O'),
#  ('the', 'O'),
#  ('patient', 'O'),
#  ("'", 'O'),
#  ('s', 'O'),
#  ('well', 'O'),
#  ('being', 'O'),
#  ('and', 'O'),
#  ('address', 'O'),
#  ('any', 'O'),
#  ('emerging', 'O'),
#  ('concerns', 'O'),
#  ('.', 'O')]

# %%
# bio_tags is a list of (token, tag) tuples
filtered_bio_tags = [tag for tag in bio_tags if tag[1] != 'O']

# Print the filtered bio tags
for tag in filtered_bio_tags:
    print(tag)
# Out:
# ('31', 'B-AGE')
# ('female', 'B-GENDER')
# ('anxiety', 'B-VISIT_MOTIVATION')
# ('disorders', 'I-VISIT_MOTIVATION')
# ('cough', 'B-SYMPTOM')
# ('difficulty', 'B-SYMPTOM')
# ('breathing', 'I-SYMPTOM')
# ('diarrhea', 'B-SYMPTOM')
# ('runny', 'B-SYMPTOM')
# ('nose', 'I-SYMPTOM')
# ('rash', 'B-SYMPTOM')
# ('joint', 'B-SYMPTOM')
# ('pain', 'I-SYMPTOM')
# ('sneezing', 'B-SYMPTOM')
# ('blurred', 'B-SYMPTOM')
# ('vision', 'I-SYMPTOM')
# ('painful', 'B-SYMPTOM')
# ('urination', 'I-SYMPTOM')
# ('dry', 'B-SYMPTOM')
# ('skin', 'I-SYMPTOM')
# ('pale', 'B-SYMPTOM')
# ('skin', 'I-SYMPTOM')
# ('anxiety', 'B-VISIT_MOTIVATION')
# ('restlessness', 'B-SYMPTOM')
# ('difficulty', 'B-SYMPTOM')
# ('concentrating', 'I-SYMPTOM')
# ('respiratory', 'B-BODY_MEASURE')
# ('cough', 'B-SYMPTOM')
# ('difficulty', 'B-SYMPTOM')
# ('breathing', 'I-SYMPTOM')
# ('diarrhea', 'B-SYMPTOM')
# ('skin', 'I-SYMPTOM')
# ('rash', 'B-SYMPTOM')
# ('dry', 'B-SYMPTOM')
# ('skin', 'I-SYMPTOM')
# ('pale', 'B-SYMPTOM')
# ('skin', 'I-SYMPTOM')
# ('joint', 'B-SYMPTOM')
# ('pain', 'I-SYMPTOM')
# ('blurred', 'B-SYMPTOM')
# ('vision', 'I-SYMPTOM')
# ('anxiety', 'B-VISIT_MOTIVATION')
# ('restlessness', 'B-SYMPTOM')
# ('difficulty', 'B-SYMPTOM')
# ('concentrating', 'I-SYMPTOM')
# ('painful', 'B-SYMPTOM')
# ('urination', 'I-SYMPTOM')
# ('heart', 'B-BODY_MEASURE')
# ('rate', 'I-BODY_MEASURE')
# ('75', 'B-VALUE')
# ('bpm', 'B-UNIT')
# ('respiratory', 'B-BODY_MEASURE')
# ('rate', 'I-BODY_MEASURE')
# ('14', 'B-VALUE')
# ('breaths/min', 'B-UNIT')
# ('rash', 'B-SYMPTOM')
# ('joint', 'B-SYMPTOM')
# ('pain', 'I-SYMPTOM')
# ('blurred', 'B-SYMPTOM')
# ('vision', 'I-SYMPTOM')
# ('anxiety', 'B-VISIT_MOTIVATION')
# ('joint', 'B-SYMPTOM')
# ('anxiety', 'B-VISIT_MOTIVATION')
# ('cough', 'B-SYMPTOM')
# ('diarrhea', 'B-SYMPTOM')
# ('joint', 'B-SYMPTOM')
# ('pain', 'I-SYMPTOM')
# ('anxiety', 'B-VISIT_MOTIVATION')

# %% [markdown]
# <div dir="rtl">
# ملاحظات
#
# لما تنكتب كلمة بالنص غير بالجسون متل:
#
# - Temp: 36.6°C
#
# جسون:
#
# - "temperature": {"value": 36.6, "unit": "\\u00b0C"}
#
# مابينعملا تعليق
# </div>

# %% [markdown]
# # Convert to BIO

# %% [markdown]
# ## bio file

# %%
def write_bio_file(bio_tags, file_path):
    """
    Write BIO tags to a file.

    Args:
        bio_tags (list of tuple): List of (token, tag) tuples from the `annotate_text` function.
        file_path (str): Path to the output BIO file.

    Returns:
        None
    """
    with open(file_path, "w", encoding="utf-8") as bio_file:
        for token, tag in bio_tags:
            if token == "\n":  # Treat "\n" as a sentence separator
                bio_file.write("\n")
            else:
                bio_file.write(f"{token} {tag}\n")
        # Ensure the file ends with a blank line
        bio_file.write("\n")

# %%
j = 10708
tokens = tokenize_text(train["Note"][j])
entities = extract_entities_from_json(json.loads(train["json"][j]))
bio_tags = annotate_text(tokens, entities)
write_bio_file(bio_tags, "output.bio")

# %% [markdown]
# ## html visualization

# %%
from pathlib import Path

def bio_to_html(bio_tags, output_file="visualization.html"):
    """
    Convert BIO-tagged data into a colorful HTML visualization using the Open Sans font.
    
    Args:
        bio_tags (list of tuple): List of (token, tag) tuples.
        output_file (str): Filepath to save the HTML visualization.

    Returns:
        None
    """
    # Predefined colors for entities
    predefined_colors = ["#bde0fe", "#f6d5e5", "#c5b4e3", "#e2f0cb", "#fde2e4", "#fcb045", "#70dbcd"]
    entity_colors = {}  # Dictionary to store colors for each entity type
    color_index = 0

    html_content = [
        '<html>',
        '<head>',
        '<link href="https://fonts.googleapis.com/css2?family=Open+Sans:wght@400;700&display=swap" rel="stylesheet">',
        '</head>',
        '<body style="font-family: \'Open Sans\', sans-serif; line-height: 1.6;">'
    ]
    html_content.append('<h1 style="font-weight: 700;">BIO File Visualization</h1>')

    for token, tag in bio_tags:
        if tag == "O":  # Outside entity
            html_content.append(f'<span style="margin: 2px;">{token}</span>')
        else:
            entity_type = tag.split("-")[-1]  # Extract entity type
            if entity_type not in entity_colors:
                # Assign predefined colors in order
                entity_colors[entity_type] = predefined_colors[color_index % len(predefined_colors)]
                color_index += 1
            color = entity_colors[entity_type]
            html_content.append(
                f'<span style="background-color: {color}; margin: 2px; padding: 2px; border-radius: 4px;">'
                f'{token} <b>{entity_type}</b></span>'
            )
        html_content.append(" ")  # Add space between tokens
    
    html_content.append("</body></html>")

    # Write the HTML content to the output file
    Path(output_file).write_text("\n".join(html_content), encoding="utf-8")
    # print(f"Visualization saved to {output_file}")

# %% [markdown]
# ## convert dataset

# %%
train["ID"][0]
# Out:
# 1

# %%
def convert_df_to_bio(df):
    for i in range(len(df)):
        print(f"Processing Note {i} ========")
        tokens = tokenize_text(df["Note"][i])
        entities = extract_entities_from_json(json.loads(df["json"][i]))
        bio_tags = annotate_text(tokens, entities)
        write_bio_file(bio_tags, f"bio/note_{df['ID'][i]}.bio")
        bio_to_html(bio_tags, f"html/note_{df['ID'][i]}.html")

# %%
convert_df_to_bio(train)
# Out:
# Processing Note 0 ========
# Processing Note 1 ========
# Processing Note 2 ========
# Processing Note 3 ========
# Processing Note 4 ========
# Processing Note 5 ========
# Processing Note 6 ========
# Processing Note 7 ========
# Processing Note 8 ========
# Processing Note 9 ========
# Processing Note 10 ========
# Processing Note 11 ========
# Processing Note 12 ========
# Processing Note 13 ========
# Processing Note 14 ========
# Processing Note 15 ========
# Processing Note 16 ========
# Processing Note 17 ========
# Processing Note 18 ========
# Processing Note 19 ========
# Processing Note 20 ========
# Processing Note 21 ========
# Processing Note 22 ========
# Processing Note 23 ========
# Processing Note 24 ========
# Processing Note 25 ========
# Processing Note 26 ========
# Processing Note 27 ========
# Processing Note 28 ========
# Processing Note 29 ========
# Processing Note 30 ========
# Processing Note 31 ========
# Processing Note 32 ========
# Processing Note 33 ========
# Processing Note 34 ========
# Processing Note 35 ========
# Processing Note 36 ========
# Processing Note 37 ========
# Processing Note 38 ========
# Processing Note 39 ========
# Processing Note 40 ========
# Processing Note 41 ========
# Processing Note 42 ========
# Processing Note 43 ========
# Processing Note 44 ========
# Processing Note 45 ========
# Processing Note 46 ========
# Processing Note 47 ========
# Processing Note 48 ========
# Processing Note 49 ========
# Processing Note 50 ========
# Processing Note 51 ========
# Processing Note 52 ========
# Processing Note 53 ========
# Processing Note 54 ========
# Processing Note 55 ========
# Processing Note 56 ========
# Processing Note 57 ========
# Processing Note 58 ========
# Processing Note 59 ========
# Processing Note 60 ========
# Processing Note 61 ========
# Processing Note 62 ========
# Processing Note 63 ========
# Processing Note 64 ========
# Processing Note 65 ========
# Processing Note 965 ========
# Processing Note 966 ========
# Processing Note 967 ========
# Processing Note 968 ========
# Processing Note 969 ========
# Processing Note 970 ========
# Processing Note 971 ========
# Processing Note 972 ========
# Processing Note 973 ========
# Processing Note 974 ========
# Processing Note 975 ========
# Processing Note 976 ========
# Processing Note 977 ========
# Processing Note 978 ========
# Processing Note 979 ========
# Processing Note 980 ========
# Processing Note 981 ========
# Processing Note 982 ========
# Processing Note 983 ========
# Processing Note 984 ========
# Processing Note 985 ========
# Processing Note 986 ========
# Processing Note 987 ========
# Processing Note 988 ========
# Processing Note 989 ========
# Processing Note 990 ========
# Processing Note 991 ========
# Processing Note 992 ========
# Processing Note 993 ========
# Processing Note 994 ========
# Processing Note 995 ========
# Processing Note 996 ========
# Processing Note 997 ========
# Processing Note 998 ========
# Processing Note 999 ========
# Processing Note 1000 ========
# Processing Note 1001 ========
# Processing Note 1002 ========
# Processing Note 1003 ========
# Processing Note 1004 ========
# Processing Note 1005 ========
# Processing Note 1006 ========
# Processing Note 1007 ========
# Processing Note 1008 ========
# Processing Note 1009 ========
# Processing Note 1010 ========
# Processing Note 1011 ========
# Processing Note 1012 ========
# Processing Note 1013 ========
# Processing Note 1014 ========
# Processing Note 1015 ========
# Processing Note 1016 ========
# Processing Note 1017 ========
# Processing Note 1018 ========
# Processing Note 1019 ========
# Processing Note 1020 ========
# Processing Note 1021 ========
# Processing Note 1022 ========
# Processing Note 1023 ========
# Processing Note 1024 ========
# Processing Note 1025 ========
# Processing Note 1026 ========
# Processing Note 1027 ========
# Processing Note 1028 ========
# Processing Note 1029 ========
# Processing Note 1030 ========
# Processing Note 1031 ========
# Processing Note 1032 ========
# Processing Note 1033 ========
# Processing Note 1034 ========
# Processing Note 1035 ========
# Processing Note 1036 ========
# Processing Note 1037 ========
# Processing Note 1038 ========
# Processing Note 1039 ========
# Processing Note 1040 ========
# Processing Note 1041 ========
# Processing Note 1042 ========
# Processing Note 1043 ========
# Processing Note 1044 ========
# Processing Note 1045 ========
# Processing Note 1046 ========
# Processing Note 1047 ========
# Processing Note 1048 ========
# Processing Note 1049 ========
# Processing Note 1050 ========
# Processing Note 1051 ========
# Processing Note 1052 ========
# Processing Note 1053 ========
# Processing Note 1054 ========
# Processing Note 1055 ========
# Processing Note 1056 ========
# Processing Note 1057 ========
# Processing Note 1058 ========
# Processing Note 1059 ========
# Processing Note 1060 ========
# Processing Note 1061 ========
# Processing Note 1062 ========
# Processing Note 1063 ========
# Processing Note 1064 ========
# Processing Note 1065 ========
# Processing Note 1066 ========
# Processing Note 1067 ========
# Processing Note 1068 ========
# Processing Note 1069 ========
# Processing Note 1070 ========
# Processing Note 1071 ========
# Processing Note 1072 ========
# Processing Note 1073 ========
# Processing Note 1074 ========
# Processing Note 1075 ========
# Processing Note 1076 ========
# Processing Note 1077 ========
# Processing Note 1078 ========
# Processing Note 1079 ========
# Processing Note 1080 ========
# Processing Note 1081 ========
# Processing Note 1082 ========
# Processing Note 1083 ========
# Processing Note 1084 ========
# Processing Note 1085 ========
# Processing Note 1086 ========
# Processing Note 1087 ========
# Processing Note 1088 ========
# Processing Note 1089 ========
# Processing Note 1090 ========
# Processing Note 1091 ========
# Processing Note 1092 ========
# Processing Note 1093 ========
# Processing Note 1094 ========
# Processing Note 1095 ========
# Processing Note 1096 ========
# Processing Note 1097 ========
# Processing Note 1098 ========
# Processing Note 1099 ========
# Processing Note 1100 ========
# Processing Note 1101 ========
# Processing Note 1102 ========
# Processing Note 1103 ========
# Processing Note 1104 ========
# Processing Note 1105 ========
# Processing Note 1106 ========
# Processing Note 1107 ========
# Processing Note 1108 ========
# Processing Note 1109 ========
# Processing Note 1110 ========
# Processing Note 1111 ========
# Processing Note 1112 ========
# Processing Note 1113 ========
# Processing Note 1114 ========
# Processing Note 1115 ========
# Processing Note 1116 ========
# Processing Note 1117 ========
# Processing Note 1118 ========
# Processing Note 1119 ========
# Processing Note 1120 ========
# Processing Note 1121 ========
# Processing Note 1122 ========
# Processing Note 1123 ========
# Processing Note 1124 ========
# Processing Note 1125 ========
# Processing Note 1126 ========
# Processing Note 1127 ========
# Processing Note 1128 ========
# Processing Note 1129 ========
# Processing Note 1130 ========
# Processing Note 1131 ========
# Processing Note 1132 ========
# Processing Note 1133 ========
# Processing Note 1134 ========
# Processing Note 1135 ========
# Processing Note 1136 ========
# Processing Note 1137 ========
# Processing Note 1138 ========
# Processing Note 1139 ========
# Processing Note 1140 ========
# Processing Note 1141 ========
# Processing Note 1142 ========
# Processing Note 1143 ========
# Processing Note 1144 ========
# Processing Note 1145 ========
# Processing Note 1146 ========
# Processing Note 1147 ========
# Processing Note 1148 ========
# Processing Note 1149 ========
# Processing Note 1150 ========
# Processing Note 1151 ========
# Processing Note 1152 ========
# Processing Note 1153 ========
# Processing Note 1154 ========
# Processing Note 1155 ========
# Processing Note 1156 ========
# Processing Note 1157 ========
# Processing Note 1158 ========
# Processing Note 1159 ========
# Processing Note 1160 ========
# Processing Note 1161 ========
# Processing Note 1162 ========
# Processing Note 1163 ========
# Processing Note 1164 ========
# Processing Note 1165 ========
# Processing Note 1166 ========
# Processing Note 1167 ========
# Processing Note 1168 ========
# Processing Note 1169 ========
# Processing Note 1170 ========
# Processing Note 1171 ========
# Processing Note 1172 ========
# Processing Note 1173 ========
# Processing Note 1174 ========
# Processing Note 1175 ========
# Processing Note 1176 ========
# Processing Note 1177 ========
# Processing Note 1178 ========
# Processing Note 1179 ========
# Processing Note 1180 ========
# Processing Note 1181 ========
# Processing Note 1182 ========
# Processing Note 1183 ========
# Processing Note 1184 ========
# Processing Note 1185 ========
# Processing Note 1186 ========
# Processing Note 1187 ========
# Processing Note 1188 ========
# Processing Note 1189 ========
# Processing Note 1190 ========
# Processing Note 1191 ========
# Processing Note 1192 ========
# Processing Note 1193 ========
# Processing Note 1194 ========
# Processing Note 1195 ========
# Processing Note 1196 ========
# Processing Note 1197 ========
# Processing Note 1198 ========
# Processing Note 1199 ========
# Processing Note 1200 ========
# Processing Note 1201 ========
# Processing Note 1202 ========
# Processing Note 1203 ========
# Processing Note 1204 ========
# Processing Note 1205 ========
# Processing Note 1206 ========
# Processing Note 1207 ========
# Processing Note 1208 ========
# Processing Note 1209 ========
# Processing Note 1210 ========
# Processing Note 1211 ========
# Processing Note 1212 ========
# Processing Note 1213 ========
# Processing Note 1214 ========
# Processing Note 1215 ========
# Processing Note 1216 ========
# Processing Note 1217 ========
# Processing Note 1218 ========
# Processing Note 1219 ========
# Processing Note 1220 ========
# Processing Note 1221 ========
# Processing Note 1222 ========
# Processing Note 1223 ========
# Processing Note 1224 ========
# Processing Note 1225 ========
# Processing Note 1226 ========
# Processing Note 1227 ========
# Processing Note 1228 ========
# Processing Note 1229 ========
# Processing Note 1230 ========
# Processing Note 1231 ========
# Processing Note 1232 ========
# Processing Note 1233 ========
# Processing Note 1234 ========
# Processing Note 1235 ========
# Processing Note 1236 ========
# Processing Note 1237 ========
# Processing Note 1238 ========
# Processing Note 1239 ========
# Processing Note 1240 ========
# Processing Note 1241 ========
# Processing Note 1242 ========
# Processing Note 1243 ========
# Processing Note 1244 ========
# Processing Note 1245 ========
# Processing Note 1246 ========
# Processing Note 1247 ========
# Processing Note 1248 ========
# Processing Note 1249 ========
# Processing Note 1250 ========
# Processing Note 1251 ========
# Processing Note 1252 ========
# Processing Note 1253 ========
# Processing Note 1254 ========
# Processing Note 1255 ========
# Processing Note 1256 ========
# Processing Note 1257 ========
# Processing Note 1258 ========
# Processing Note 1259 ========
# Processing Note 1260 ========
# Processing Note 1261 ========
# Processing Note 1262 ========
# Processing Note 1263 ========
# Processing Note 1264 ========
# Processing Note 1265 ========
# Processing Note 1266 ========
# Processing Note 1267 ========
# Processing Note 1268 ========
# Processing Note 1269 ========
# Processing Note 1270 ========
# Processing Note 1271 ========
# Processing Note 1272 ========
# Processing Note 1273 ========
# Processing Note 1274 ========
# Processing Note 1275 ========
# Processing Note 1276 ========
# Processing Note 1277 ========
# Processing Note 1278 ========
# Processing Note 1279 ========
# Processing Note 1280 ========
# Processing Note 1281 ========
# Processing Note 1282 ========
# Processing Note 1283 ========
# Processing Note 1284 ========
# Processing Note 1285 ========
# Processing Note 1286 ========
# Processing Note 1287 ========
# Processing Note 1288 ========
# Processing Note 1289 ========
# Processing Note 1290 ========
# Processing Note 1291 ========
# Processing Note 1292 ========
# Processing Note 1293 ========
# Processing Note 1294 ========
# Processing Note 1295 ========
# Processing Note 1296 ========
# Processing Note 1297 ========
# Processing Note 1298 ========
# Processing Note 1299 ========
# Processing Note 1300 ========
# Processing Note 1301 ========
# Processing Note 1302 ========
# Processing Note 1303 ========
# Processing Note 1304 ========
# Processing Note 1305 ========
# Processing Note 1306 ========
# Processing Note 1307 ========
# Processing Note 1308 ========
# Processing Note 1309 ========
# Processing Note 1310 ========
# Processing Note 1311 ========
# Processing Note 1312 ========
# Processing Note 1313 ========
# Processing Note 1314 ========
# Processing Note 1315 ========
# Processing Note 1316 ========
# Processing Note 1317 ========
# Processing Note 1318 ========
# Processing Note 1319 ========
# Processing Note 1320 ========
# Processing Note 1321 ========
# Processing Note 1322 ========
# Processing Note 1323 ========
# Processing Note 1324 ========
# Processing Note 1325 ========
# Processing Note 1326 ========
# Processing Note 1327 ========
# Processing Note 1328 ========
# Processing Note 1329 ========
# Processing Note 1330 ========
# Processing Note 1331 ========
# Processing Note 1332 ========
# Processing Note 1333 ========
# Processing Note 1334 ========
# Processing Note 1335 ========
# Processing Note 1336 ========
# Processing Note 1337 ========
# Processing Note 1338 ========
# Processing Note 1339 ========
# Processing Note 1340 ========
# Processing Note 1341 ========
# Processing Note 1342 ========
# Processing Note 1343 ========
# Processing Note 1344 ========
# Processing Note 1345 ========
# Processing Note 1346 ========
# Processing Note 1347 ========
# Processing Note 1348 ========
# Processing Note 1349 ========
# Processing Note 1350 ========
# Processing Note 1351 ========
# Processing Note 1352 ========
# Processing Note 1353 ========
# Processing Note 1354 ========
# Processing Note 1355 ========
# Processing Note 1356 ========
# Processing Note 1357 ========
# Processing Note 1358 ========
# Processing Note 1359 ========
# Processing Note 1360 ========
# Processing Note 1361 ========
# Processing Note 1362 ========
# Processing Note 1363 ========
# Processing Note 1364 ========
# Processing Note 1365 ========
# Processing Note 1366 ========
# Processing Note 1367 ========
# Processing Note 1368 ========
# Processing Note 1369 ========
# Processing Note 1370 ========
# Processing Note 1371 ========
# Processing Note 1372 ========
# Processing Note 1373 ========
# Processing Note 1374 ========
# Processing Note 1375 ========
# Processing Note 1376 ========
# Processing Note 1377 ========
# Processing Note 1378 ========
# Processing Note 1379 ========
# Processing Note 1380 ========
# Processing Note 1381 ========
# Processing Note 1382 ========
# Processing Note 1383 ========
# Processing Note 1384 ========
# Processing Note 1385 ========
# Processing Note 1386 ========
# Processing Note 1387 ========
# Processing Note 1388 ========
# Processing Note 1389 ========
# Processing Note 1390 ========
# Processing Note 1391 ========
# Processing Note 1392 ========
# Processing Note 1393 ========
# Processing Note 1394 ========
# Processing Note 1395 ========
# Processing Note 1396 ========
# Processing Note 1397 ========
# Processing Note 1398 ========
# Processing Note 1399 ========
# Processing Note 1400 ========
# Processing Note 1401 ========
# Processing Note 1402 ========
# Processing Note 1403 ========
# Processing Note 1404 ========
# Processing Note 1405 ========
# Processing Note 1406 ========
# Processing Note 1407 ========
# Processing Note 1408 ========
# Processing Note 1409 ========
# Processing Note 1410 ========
# Processing Note 1411 ========
# Processing Note 1412 ========
# Processing Note 1413 ========
# Processing Note 1414 ========
# Processing Note 1415 ========
# Processing Note 1416 ========
# Processing Note 1417 ========
# Processing Note 1418 ========
# Processing Note 1419 ========
# Processing Note 1420 ========
# Processing Note 1421 ========
# Processing Note 1422 ========
# Processing Note 1423 ========
# Processing Note 1424 ========
# Processing Note 1425 ========
# Processing Note 1426 ========
# Processing Note 1427 ========
# Processing Note 1428 ========
# Processing Note 1429 ========
# Processing Note 1430 ========
# Processing Note 1431 ========
# Processing Note 1432 ========
# Processing Note 1433 ========
# Processing Note 1434 ========
# Processing Note 1435 ========
# Processing Note 1436 ========
# Processing Note 1437 ========
# Processing Note 1438 ========
# Processing Note 1439 ========
# Processing Note 1440 ========
# Processing Note 1441 ========
# Processing Note 1442 ========
# Processing Note 1443 ========
# Processing Note 1444 ========
# Processing Note 1445 ========
# Processing Note 1446 ========
# Processing Note 1447 ========
# Processing Note 1448 ========
# Processing Note 1449 ========
# Processing Note 1450 ========
# Processing Note 1451 ========
# Processing Note 1452 ========
# Processing Note 1453 ========
# Processing Note 1454 ========
# Processing Note 1455 ========
# Processing Note 1456 ========
# Processing Note 1457 ========
# Processing Note 1458 ========
# Processing Note 1459 ========
# Processing Note 1460 ========
# Processing Note 1461 ========
# Processing Note 1462 ========
# Processing Note 1463 ========
# Processing Note 1464 ========
# Processing Note 1465 ========
# Processing Note 1466 ========
# Processing Note 1467 ========
# Processing Note 1468 ========
# Processing Note 1469 ========
# Processing Note 1470 ========
# Processing Note 1471 ========
# Processing Note 1472 ========
# Processing Note 1473 ========
# Processing Note 1474 ========
# Processing Note 1475 ========
# Processing Note 1476 ========
# Processing Note 1477 ========
# Processing Note 1478 ========
# Processing Note 1479 ========
# Processing Note 1480 ========
# Processing Note 1481 ========
# Processing Note 1482 ========
# Processing Note 1483 ========
# Processing Note 1484 ========
# Processing Note 1485 ========
# Processing Note 1486 ========
# Processing Note 1487 ========
# Processing Note 1488 ========
# Processing Note 1489 ========
# Processing Note 1490 ========
# Processing Note 1491 ========
# Processing Note 1492 ========
# Processing Note 1493 ========
# Processing Note 1494 ========
# Processing Note 1495 ========
# Processing Note 1496 ========
# Processing Note 1497 ========
# Processing Note 1498 ========
# Processing Note 1499 ========
# Processing Note 1500 ========
# Processing Note 1501 ========
# Processing Note 1502 ========
# Processing Note 1503 ========
# Processing Note 1504 ========
# Processing Note 1505 ========
# Processing Note 1506 ========
# Processing Note 1507 ========
# Processing Note 1508 ========
# Processing Note 1509 ========
# Processing Note 1510 ========
# Processing Note 1511 ========
# Processing Note 1512 ========
# Processing Note 1513 ========
# Processing Note 1514 ========
# Processing Note 1515 ========
# Processing Note 1516 ========
# Processing Note 1517 ========
# Processing Note 1518 ========
# Processing Note 1519 ========
# Processing Note 1520 ========
# Processing Note 1521 ========
# Processing Note 1522 ========
# Processing Note 1523 ========
# Processing Note 1524 ========
# Processing Note 1525 ========
# Processing Note 1526 ========
# Processing Note 1527 ========
# Processing Note 1528 ========
# Processing Note 1529 ========
# Processing Note 1530 ========
# Processing Note 1531 ========
# Processing Note 1532 ========
# Processing Note 1533 ========
# Processing Note 1534 ========
# Processing Note 1535 ========
# Processing Note 1536 ========
# Processing Note 1537 ========
# Processing Note 1538 ========
# Processing Note 1539 ========
# Processing Note 1540 ========
# Processing Note 1541 ========
# Processing Note 1542 ========
# Processing Note 1543 ========
# Processing Note 1544 ========
# Processing Note 1545 ========
# Processing Note 1546 ========
# Processing Note 1547 ========
# Processing Note 1548 ========
# Processing Note 1549 ========
# Processing Note 1550 ========
# Processing Note 1551 ========
# Processing Note 1552 ========
# Processing Note 1553 ========
# Processing Note 1554 ========
# Processing Note 1555 ========
# Processing Note 1556 ========
# Processing Note 1557 ========
# Processing Note 1558 ========
# Processing Note 1559 ========
# Processing Note 1560 ========
# Processing Note 1561 ========
# Processing Note 1562 ========
# Processing Note 1563 ========
# Processing Note 1564 ========
# Processing Note 1565 ========
# Processing Note 1566 ========
# Processing Note 1567 ========
# Processing Note 1568 ========
# Processing Note 1569 ========
# Processing Note 1570 ========
# Processing Note 1571 ========
# Processing Note 1572 ========
# Processing Note 1573 ========
# Processing Note 1574 ========
# Processing Note 1575 ========
# Processing Note 1576 ========
# Processing Note 1577 ========
# Processing Note 1578 ========
# Processing Note 1579 ========
# Processing Note 1580 ========
# Processing Note 1581 ========
# Processing Note 1582 ========
# Processing Note 1583 ========
# Processing Note 1584 ========
# Processing Note 1585 ========
# Processing Note 1586 ========
# Processing Note 1587 ========
# Processing Note 1588 ========
# Processing Note 1589 ========
# Processing Note 1590 ========
# Processing Note 1591 ========
# Processing Note 1592 ========
# Processing Note 1593 ========
# Processing Note 1594 ========
# Processing Note 1595 ========
# Processing Note 1596 ========
# Processing Note 1597 ========
# Processing Note 1598 ========
# Processing Note 1599 ========
# Processing Note 1600 ========
# Processing Note 1601 ========
# Processing Note 1602 ========
# Processing Note 1603 ========
# Processing Note 1604 ========
# Processing Note 1605 ========
# Processing Note 1606 ========
# Processing Note 1607 ========
# Processing Note 1608 ========
# Processing Note 1609 ========
# Processing Note 1610 ========
# Processing Note 1611 ========
# Processing Note 1612 ========
# Processing Note 1613 ========
# Processing Note 1614 ========
# Processing Note 1615 ========
# Processing Note 1616 ========
# Processing Note 1617 ========
# Processing Note 1618 ========
# Processing Note 1619 ========
# Processing Note 1620 ========
# Processing Note 1621 ========
# Processing Note 1622 ========
# Processing Note 1623 ========
# Processing Note 1624 ========
# Processing Note 1625 ========
# Processing Note 1626 ========
# Processing Note 1627 ========
# Processing Note 1628 ========
# Processing Note 1629 ========
# Processing Note 1630 ========
# Processing Note 1631 ========
# Processing Note 1632 ========
# Processing Note 1633 ========
# Processing Note 1634 ========
# Processing Note 1635 ========
# Processing Note 1636 ========
# ...
# Processing Note 10306 ========
# Processing Note 10307 ========
# Processing Note 10308 ========
# Processing Note 10309 ========
# Processing Note 10310 ========
# Processing Note 10311 ========
# Processing Note 10312 ========
# Processing Note 10313 ========
# Processing Note 10314 ========
# Processing Note 10315 ========
# Processing Note 10316 ========
# Processing Note 10317 ========
# Processing Note 10318 ========
# Processing Note 10319 ========
# Processing Note 10320 ========
# Processing Note 10321 ========
# Processing Note 10322 ========
# Processing Note 10323 ========
# Processing Note 10324 ========
# Processing Note 10325 ========
# Processing Note 10326 ========
# Processing Note 10327 ========
# Processing Note 10328 ========
# Processing Note 10329 ========
# Processing Note 10330 ========
# Processing Note 10331 ========
# Processing Note 10332 ========
# Processing Note 10333 ========
# Processing Note 10334 ========
# Processing Note 10335 ========
# Processing Note 10336 ========
# Processing Note 10337 ========
# Processing Note 10338 ========
# Processing Note 10339 ========
# Processing Note 10340 ========
# Processing Note 10341 ========
# Processing Note 10342 ========
# Processing Note 10343 ========
# Processing Note 10344 ========
# Processing Note 10345 ========
# Processing Note 10346 ========
# Processing Note 10347 ========
