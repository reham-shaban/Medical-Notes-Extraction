# %% [markdown]
# # Preparing

# %%
import pandas as pd
import json, re

# %% [markdown]
# # Loading data

# %%
train = pd.read_csv("data/train.csv")

# %%
train.head()
# Out:
#    ID                                               Note  \
# 0   1  **Clinical Notes**\n\n**Patient Information:**...
# 1   2  Clinical Notes:\n\nPatient: 56-year-old male\n...
# 2   3  Clinical Notes:\n\nPatient: 73-year-old female...
# 3   4  **Clinical Notes**\n\n**Patient Information:**...
# 4   5  **Clinical Notes**\n\n**Patient:** Male, age 5...
#
#                                                 json
# 0  {"patient_info": {"age": 41, "gender": "Male"}...
# 1  {"patient_info": {"age": 56, "gender": "Male"}...
# 2  {"patient_info": {"age": 73, "gender": "Female...
# 3  {"patient_info": {"age": 32, "gender": "Female...
# 4  {"patient_info": {"age": 51, "gender": "Male"}...

# %% [markdown]
# # Pre-Processing

# %% [markdown]
# ## tokenization

# %%
def tokenize_text(text : str):
    """
    Tokenizes text while keeping patterns like 112/79, 39.4°C, and mg/dL intact,
    and separates numbers from hyphenated words.

    Args:
        text (str): The input text to tokenize.

    Returns:
        list: List of tokens.
    """
    # Remove '*' and lowercase the text
    text = text.replace('*', '').lower()
    text = text.replace('-', ' ').lower()

    # regex to handle units and complex tokens
    tokens = re.findall(r'°c|\w+/\w+|\d+\.\d+|\d+/\d+|\d+|\w+|[^\w\s]', text)

    return tokens

# %%
# Example Usage
tokens = tokenize_text(train["Note"][0])
print(tokens)
# Out:
# ['clinical', 'notes', 'patient', 'information', ':', 'age', ':', '41', 'years', 'old', 'gender', ':', 'male', 'visit', 'motivation', ':', 'anemia', 'evaluation', 'chief', 'complaints', 'and', 'symptoms', ':', 'the', 'patient', 'presents', 'with', 'complaints', 'of', 'anemia', ',', 'fever', ',', 'fatigue', ',', 'difficulty', 'breathing', '(', 'dyspnea', ')', ',', 'vomiting', ',', 'dizziness', ',', 'blurred', 'vision', ',', 'wheezing', ',', 'and', 'pale', 'skin', '.', 'the', 'patient', 'reports', 'that', 'these', 'symptoms', 'have', 'been', 'progressively', 'worsening', 'over', 'the', 'past', 'few', 'weeks', '.', 'history', 'of', 'present', 'illness', ':', 'fever', ':', 'intermittent', 'low', 'grade', 'fevers', 'for', 'approximately', '2', 'weeks', '.', 'fatigue', ':', 'persistent', 'and', 'severe', 'fatigue', 'affecting', 'daily', 'activities', '.', 'difficulty', 'breathing', '(', 'dyspnea', ')', ':', 'experiencing', 'shortness', 'of', 'breath', ',', 'particularly', 'with', 'exertion', '.', 'no', 'history', 'of', 'chronic', 'respiratory', 'conditions', '.', 'vomiting', ':', 'occasional', 'episodes', 'of', 'non', 'bilious', 'vomiting', 'for', 'the', 'past', 'week', '.', 'dizziness', ':', 'episodes', 'of', 'dizziness', ',', 'especially', 'upon', 'standing', ',', 'which', 'can', 'be', 'severe', 'enough', 'to', 'cause', 'near', 'fainting', 'spells', '.', 'blurred', 'vision', ':', 'new', 'onset', 'of', 'blurred', 'vision', ',', 'with', 'occasional', 'transient', 'visual', 'disturbances', '.', 'wheezing', ':', 'recent', 'history', 'of', 'wheezing', 'noted', 'by', 'the', 'patient', 'during', 'exertion', 'or', 'when', 'lying', 'down', '.', 'review', 'of', 'systems', ':', 'constitutional', ':', 'fatigue', ',', 'fever', 'respiratory', ':', 'dyspnea', ',', 'wheezing', 'gastrointestinal', ':', 'vomiting', 'cardiovascular', ':', 'palpitations', '(', 'not', 'specifically', 'reported', 'but', 'heart', 'rate', 'is', 'elevated', ')', 'neurological', ':', 'dizziness', ',', 'blurred', 'vision', 'physical', 'examination', ':', 'general', 'appearance', ':', 'patient', 'appears', 'pale', 'and', 'fatigued', '.', 'vital', 'signs', ':', 'heart', 'rate', ':', '114', 'bpm', '(', 'tachycardia', ')', 'oxygen', 'saturation', ':', '98.4', '%', 'on', 'room', 'air', 'blood', 'pressure', ':', 'bp', 'not', 'provided', 'but', 'should', 'be', 'assessed', '.', 'temperature', ':', 'not', 'provided', ',', 'but', 'given', 'the', 'history', 'of', 'fever', ',', 'elevated', 'temperature', 'should', 'be', 'considered', '.', 'laboratory', 'findings', 'and', 'vital', 'signs', ':', 'hemoglobin', ':', 'not', 'directly', 'measured', 'in', 'this', 'note', 'but', 'anemia', 'is', 'noted', 'as', 'the', 'visit', 'motivation', '.', 'further', 'workup', 'for', 'hemoglobin', 'levels', 'is', 'necessary', '.', 'cholesterol', 'level', ':', '132.8', 'mg/dl', '(', 'within', 'normal', 'range', ')', 'glucose', 'level', ':', '110.6', 'mg/dl', '(', 'normal', ')', 'assessment', 'and', 'plan', ':', 'the', 'patient', 'presents', 'with', 'a', 'constellation', 'of', 'symptoms', 'including', 'fever', ',', 'fatigue', ',', 'dyspnea', ',', 'vomiting', ',', 'dizziness', ',', 'blurred', 'vision', ',', 'wheezing', ',', 'and', 'pale', 'skin', ',', 'all', 'of', 'which', 'may', 'be', 'related', 'to', 'anemia', 'or', 'other', 'underlying', 'conditions', '.', 'the', 'elevated', 'heart', 'rate', 'could', 'be', 'secondary', 'to', 'the', 'anemia', 'and/or', 'inflammatory', 'response', '.', 'diagnosis', 'considerations', ':', '1', '.', 'anemia', ':', 'given', 'the', 'presentation', 'of', 'fatigue', ',', 'dyspnea', ',', 'and', 'pale', 'skin', '.', '2', '.', 'infectious', 'process', ':', 'potential', 'infectious', 'etiology', 'contributing', 'to', 'fever', 'and', 'tachycardia', '.', '3', '.', 'respiratory', 'issues', ':', 'possible', 'exacerbation', 'of', 'underlying', 'respiratory', 'conditions', 'or', 'secondary', 'to', 'anemia', '.', '4', '.', 'gastrointestinal', 'disturbances', ':', 'vomiting', 'may', 'indicate' ...

# %% [markdown]
# ## extract entities

# %%
def extract_entities_from_json(json_data):
    """
    Extract entities from the given JSON into a dictionary for annotation.

    Args:
        json_data (dict): The JSON containing patient information, symptoms, vital signs, etc.

    Returns:
        dict: A dictionary of entities categorized by type without repetitions.
    """

    entities = {
        "AGE": [str(json_data["patient_info"]["age"])],
        "GENDER": [json_data["patient_info"]["gender"].lower()],
        "VISIT_MOTIVATION": [json_data["visit_motivation"].replace('-', ' ').lower()],
        "SYMPTOM": [symptom.replace("_", " ").lower() for symptom in json_data["symptoms"]],
        "BODY_MEASURE": [],
        "VALUE": [],
        "UNIT": [],
    }

    # Extract vital signs
    vital_signs = json_data.get("vital_signs", {})
    for measure, details in vital_signs.items():
        if measure == "blood_pressure" and isinstance(details, dict):  # Special handling for blood pressure
            systolic = details.get("systolic", {})
            diastolic = details.get("diastolic", {})
            if systolic and diastolic:  # Combine systolic and diastolic
                entities["BODY_MEASURE"].append("blood pressure")
                entities["VALUE"].append(f"{systolic['value']}/{diastolic['value']}")
                if systolic.get("unit") == diastolic.get("unit"):  # Add unit only once if the same
                    entities["UNIT"].append(systolic["unit"].lower())
        elif isinstance(details, dict) and "value" in details:  # Handle simple vital signs
            measure_name = measure.replace("_", " ").lower()
            value = str(details["value"]).lower()
            unit = details.get("unit", "").lower()

            if measure_name not in entities["BODY_MEASURE"]:
                entities["BODY_MEASURE"].append(measure_name)
            if value not in entities["VALUE"]:
                entities["VALUE"].append(value)
            if unit not in entities["UNIT"]:
                entities["UNIT"].append(unit)

    return entities

# %%
# Example Usage
entities = extract_entities_from_json(json.loads(train["json"][0]))
for key, value in entities.items():
    print(f"{key}: {value}")
# Out:
# AGE: ['41']
# GENDER: ['male']
# VISIT_MOTIVATION: ['anemia']
# SYMPTOM: ['fever', 'fatigue', 'difficulty breathing', 'vomiting', 'dizziness', 'blurred vision', 'wheezing', 'pale skin']
# BODY_MEASURE: ['heart rate', 'oxygen saturation', 'cholesterol level', 'glucose level']
# VALUE: ['114', '98.4', '132.8', '110.6']
# UNIT: ['bpm', '%', 'mg/dl']

# %% [markdown]
# ## covert json to entities

# %%
def annotate_text(tokens, entities):
    """
    Annotate tokens with BIO tags based on the provided entities and collect missed entities.

    Args:
        tokens (list of str): The tokenized text.
        entities (dict): Dictionary of entity types and their corresponding values.

    Returns:
        list of tuple: List of (token, tag) tuples representing the BIO-annotated tokens.
        dict: Dictionary of missed entities that did not find a match in the text.
    """
    bio_tags = []
  
    # Iterate over tokens
    for i in range(len(tokens)):
        matched = False
        # Check each entity type
        for entity_type, entity_values in entities.items():
            # Check each entity value
            for entity in entity_values:
                entity_tokens = tokenize_text(entity)  # Tokenize the entity value

                # Loop through words in entity
                for e_token in entity_tokens:
                    # Check if there's a word match
                    if tokens[i] == e_token:
                        # Check if first
                        if e_token == entity_tokens[0]:
                            bio_tags.append((tokens[i], f"B-{entity_type}"))
                            # Mark as matched
                            matched = True
                            break
                        elif i != 0 and (bio_tags[i-1][1] == f"B-{entity_type}" or bio_tags[i-1][1] == f"I-{entity_type}"):
                            bio_tags.append((tokens[i], f"I-{entity_type}"))
                            # Mark as matched
                            matched = True
                            break

                if matched:
                    break  # Stop checking further entity values for this token
            if matched:
                break  # Stop checking further entity types

        if not matched:
            bio_tags.append((tokens[i], "O"))  # Outside any entity

    return bio_tags

# %% [markdown]
# ## test

# %%
j = 10708
tokens = tokenize_text(train["Note"][j])
entities = extract_entities_from_json(json.loads(train["json"][j]))
bio_tags = annotate_text(tokens, entities)

# %%
# bio_tags is a list of (token, tag) tuples
filtered_bio_tags = [tag for tag in bio_tags if tag[1] != 'O']

# Print the filtered bio tags
for tag in filtered_bio_tags:
    print(tag)
# Out:
# ('31', 'B-AGE')
# ('female', 'B-GENDER')
# ('anxiety', 'B-VISIT_MOTIVATION')
# ('disorders', 'I-VISIT_MOTIVATION')
# ('cough', 'B-SYMPTOM')
# ('difficulty', 'B-SYMPTOM')
# ('breathing', 'I-SYMPTOM')
# ('diarrhea', 'B-SYMPTOM')
# ('runny', 'B-SYMPTOM')
# ('nose', 'I-SYMPTOM')
# ('rash', 'B-SYMPTOM')
# ('joint', 'B-SYMPTOM')
# ('pain', 'I-SYMPTOM')
# ('sneezing', 'B-SYMPTOM')
# ('blurred', 'B-SYMPTOM')
# ('vision', 'I-SYMPTOM')
# ('painful', 'B-SYMPTOM')
# ('urination', 'I-SYMPTOM')
# ('dry', 'B-SYMPTOM')
# ('skin', 'I-SYMPTOM')
# ('pale', 'B-SYMPTOM')
# ('skin', 'I-SYMPTOM')
# ('anxiety', 'B-VISIT_MOTIVATION')
# ('restlessness', 'B-SYMPTOM')
# ('difficulty', 'B-SYMPTOM')
# ('concentrating', 'I-SYMPTOM')
# ('respiratory', 'B-BODY_MEASURE')
# ('cough', 'B-SYMPTOM')
# ('difficulty', 'B-SYMPTOM')
# ('breathing', 'I-SYMPTOM')
# ('diarrhea', 'B-SYMPTOM')
# ('skin', 'I-SYMPTOM')
# ('rash', 'B-SYMPTOM')
# ('dry', 'B-SYMPTOM')
# ('skin', 'I-SYMPTOM')
# ('pale', 'B-SYMPTOM')
# ('skin', 'I-SYMPTOM')
# ('joint', 'B-SYMPTOM')
# ('pain', 'I-SYMPTOM')
# ('blurred', 'B-SYMPTOM')
# ('vision', 'I-SYMPTOM')
# ('anxiety', 'B-VISIT_MOTIVATION')
# ('restlessness', 'B-SYMPTOM')
# ('difficulty', 'B-SYMPTOM')
# ('concentrating', 'I-SYMPTOM')
# ('painful', 'B-SYMPTOM')
# ('urination', 'I-SYMPTOM')
# ('heart', 'B-BODY_MEASURE')
# ('rate', 'I-BODY_MEASURE')
# ('75', 'B-VALUE')
# ('bpm', 'B-UNIT')
# ('respiratory', 'B-BODY_MEASURE')
# ('rate', 'I-BODY_MEASURE')
# ('14', 'B-VALUE')
# ('breaths/min', 'B-UNIT')
# ('rash', 'B-SYMPTOM')
# ('joint', 'B-SYMPTOM')
# ('pain', 'I-SYMPTOM')
# ('blurred', 'B-SYMPTOM')
# ('vision', 'I-SYMPTOM')
# ('anxiety', 'B-VISIT_MOTIVATION')
# ('joint', 'B-SYMPTOM')
# ('anxiety', 'B-VISIT_MOTIVATION')
# ('cough', 'B-SYMPTOM')
# ('diarrhea', 'B-SYMPTOM')
# ('joint', 'B-SYMPTOM')
# ('pain', 'I-SYMPTOM')
# ('anxiety', 'B-VISIT_MOTIVATION')

# %% [markdown]
# <div dir="rtl">
# ملاحظات
#
# لما تنكتب كلمة بالنص غير بالجسون متل:
#
# - Temp: 36.6°C
#
# جسون:
#
# - "temperature": {"value": 36.6, "unit": "\\u00b0C"}
#
# مابينعملا تعليق
# </div>

# %% [markdown]
# # Convert to BIO

# %% [markdown]
# ## bio file

# %%
def write_bio_file(bio_tags, file_path):
    """
    Write BIO tags to a file.

    Args:
        bio_tags (list of tuple): List of (token, tag) tuples from the `annotate_text` function.
        file_path (str): Path to the output BIO file.

    Returns:
        None
    """
    with open(file_path, "w", encoding="utf-8") as bio_file:
        for token, tag in bio_tags:
            if token == "\n":  # Treat "\n" as a sentence separator
                bio_file.write("\n")
            else:
                bio_file.write(f"{token} {tag}\n")
        # Ensure the file ends with a blank line
        bio_file.write("\n")

# %%
j = 10708
tokens = tokenize_text(train["Note"][j])
entities = extract_entities_from_json(json.loads(train["json"][j]))
bio_tags = annotate_text(tokens, entities)
write_bio_file(bio_tags, "output.bio")

# %% [markdown]
# ## html visualization

# %%
from pathlib import Path

def bio_to_html(bio_tags, output_file="visualization.html"):
    """
    Convert BIO-tagged data into a colorful HTML visualization using the Open Sans font.
    
    Args:
        bio_tags (list of tuple): List of (token, tag) tuples.
        output_file (str): Filepath to save the HTML visualization.

    Returns:
        None
    """
    # Predefined colors for entities
    predefined_colors = ["#bde0fe", "#f6d5e5", "#c5b4e3", "#e2f0cb", "#fde2e4", "#fcb045", "#70dbcd"]
    entity_colors = {}  # Dictionary to store colors for each entity type
    color_index = 0

    html_content = [
        '<html>',
        '<head>',
        '<link href="https://fonts.googleapis.com/css2?family=Open+Sans:wght@400;700&display=swap" rel="stylesheet">',
        '</head>',
        '<body style="font-family: \'Open Sans\', sans-serif; line-height: 1.6;">'
    ]
    html_content.append('<h1 style="font-weight: 700;">BIO File Visualization</h1>')

    for token, tag in bio_tags:
        if tag == "O":  # Outside entity
            html_content.append(f'<span style="margin: 2px;">{token}</span>')
        else:
            entity_type = tag.split("-")[-1]  # Extract entity type
            if entity_type not in entity_colors:
                # Assign predefined colors in order
                entity_colors[entity_type] = predefined_colors[color_index % len(predefined_colors)]
                color_index += 1
            color = entity_colors[entity_type]
            html_content.append(
                f'<span style="background-color: {color}; margin: 2px; padding: 2px; border-radius: 4px;">'
                f'{token} <b>{entity_type}</b></span>'
            )
        html_content.append(" ")  # Add space between tokens
    
    html_content.append("</body></html>")

    # Write the HTML content to the output file
    Path(output_file).write_text("\n".join(html_content), encoding="utf-8")
    print(f"Visualization saved to {output_file}")

# %%
j = 10708
tokens = tokenize_text(train["Note"][j])
entities = extract_entities_from_json(json.loads(train["json"][j]))
bio_tags = annotate_text(tokens, entities)
bio_to_html(bio_tags, "output3.html")
# Out:
# Visualization saved to output3.html

# %% [markdown]
# ## convert dataset

# %%
def convert_df_to_bio(df):
    for i in range(len(df)):
        print(f"Processing Note {i} ========")
        tokens = tokenize_text(df["Note"][i])
        entities = extract_entities_from_json(json.loads(df["json"][i]))
        bio_tags = annotate_text(tokens, entities)
        write_bio_file(bio_tags, f"bio/note_{i}.bio")
        bio_to_html(bio_tags, f"html/note_{i}.html")

# %%
convert_df_to_bio(train)
# Out:
# Processing Note 0 ========
# Visualization saved to html/note_0.html
# Processing Note 1 ========
# Visualization saved to html/note_1.html
# Processing Note 2 ========
# Visualization saved to html/note_2.html
# Processing Note 3 ========
# Visualization saved to html/note_3.html
# Processing Note 4 ========
# Visualization saved to html/note_4.html
# Processing Note 5 ========
# Visualization saved to html/note_5.html
# Processing Note 6 ========
# Visualization saved to html/note_6.html
# Processing Note 7 ========
# Visualization saved to html/note_7.html
# Processing Note 8 ========
# Visualization saved to html/note_8.html
# Processing Note 9 ========
# Visualization saved to html/note_9.html
# Processing Note 10 ========
# Visualization saved to html/note_10.html
# Processing Note 11 ========
# Visualization saved to html/note_11.html
# Processing Note 12 ========
# Visualization saved to html/note_12.html
# Processing Note 13 ========
# Visualization saved to html/note_13.html
# Processing Note 14 ========
# Visualization saved to html/note_14.html
# Processing Note 15 ========
# Visualization saved to html/note_15.html
# Processing Note 16 ========
# Visualization saved to html/note_16.html
# Processing Note 17 ========
# Visualization saved to html/note_17.html
# Processing Note 18 ========
# Visualization saved to html/note_18.html
# Processing Note 19 ========
# Visualization saved to html/note_19.html
# Processing Note 20 ========
# Visualization saved to html/note_20.html
# Processing Note 21 ========
# Visualization saved to html/note_21.html
# Processing Note 22 ========
# Visualization saved to html/note_22.html
# Processing Note 23 ========
# Visualization saved to html/note_23.html
# Processing Note 24 ========
# Visualization saved to html/note_24.html
# Processing Note 25 ========
# Visualization saved to html/note_25.html
# Processing Note 26 ========
# Visualization saved to html/note_26.html
# Processing Note 27 ========
# Visualization saved to html/note_27.html
# Processing Note 28 ========
# Visualization saved to html/note_28.html
# Processing Note 29 ========
# Visualization saved to html/note_29.html
# Processing Note 30 ========
# Visualization saved to html/note_30.html
# Processing Note 31 ========
# Visualization saved to html/note_31.html
# Processing Note 32 ========
# Visualization saved to html/note_32.html
# Processing Note 33 ========
# Visualization saved to html/note_33.html
# Processing Note 34 ========
# Visualization saved to html/note_34.html
# Processing Note 35 ========
# Visualization saved to html/note_35.html
# Processing Note 36 ========
# Visualization saved to html/note_36.html
# Processing Note 37 ========
# Visualization saved to html/note_37.html
# Processing Note 38 ========
# Visualization saved to html/note_38.html
# Processing Note 39 ========
# Visualization saved to html/note_39.html
# Processing Note 40 ========
# Visualization saved to html/note_40.html
# Processing Note 41 ========
# Visualization saved to html/note_41.html
# Processing Note 42 ========
# Visualization saved to html/note_42.html
# Processing Note 43 ========
# Visualization saved to html/note_43.html
# Processing Note 44 ========
# Visualization saved to html/note_44.html
# Processing Note 45 ========
# Visualization saved to html/note_45.html
# Processing Note 46 ========
# Visualization saved to html/note_46.html
# Processing Note 47 ========
# Visualization saved to html/note_47.html
# Processing Note 48 ========
# Visualization saved to html/note_48.html
# Processing Note 49 ========
# Visualization saved to html/note_49.html
# Processing Note 50 ========
# Visualization saved to html/note_50.html
# Processing Note 51 ========
# Visualization saved to html/note_51.html
# Processing Note 52 ========
# Visualization saved to html/note_52.html
# Processing Note 53 ========
# Visualization saved to html/note_53.html
# Processing Note 54 ========
# Visualization saved to html/note_54.html
# Processing Note 55 ========
# Visualization saved to html/note_55.html
# Processing Note 56 ========
# Visualization saved to html/note_56.html
# Processing Note 57 ========
# Visualization saved to html/note_57.html
# Processing Note 58 ========
# Visualization saved to html/note_58.html
# Processing Note 59 ========
# Visualization saved to html/note_59.html
# Processing Note 60 ========
# Visualization saved to html/note_60.html
# Processing Note 61 ========
# Visualization saved to html/note_61.html
# Processing Note 62 ========
# Visualization saved to html/note_62.html
# Processing Note 63 ========
# Visualization saved to html/note_63.html
# Processing Note 64 ========
# Visualization saved to html/note_64.html
# Processing Note 65 ========
# Visualization saved to html/note_65.html
# Processing Note 66 ========
# Visualization saved to html/note_66.html
# Processing Note 67 ========
# Visualization saved to html/note_67.html
# Processing Note 68 ========
# Visualization saved to html/note_68.html
# Processing Note 69 ========
# Visualization saved to html/note_69.html
# Processing Note 70 ========
# Visualization saved to html/note_70.html
# Processing Note 71 ========
# Visualization saved to html/note_71.html
# Processing Note 72 ========
# Visualization saved to html/note_72.html
# Processing Note 73 ========
# Visualization saved to html/note_73.html
# Processing Note 74 ========
# Visualization saved to html/note_74.html
# Processing Note 75 ========
# Visualization saved to html/note_75.html
# Processing Note 76 ========
# Visualization saved to html/note_76.html
# Processing Note 77 ========
# Visualization saved to html/note_77.html
# Processing Note 78 ========
# Visualization saved to html/note_78.html
# Processing Note 79 ========
# Visualization saved to html/note_79.html
# Processing Note 80 ========
# Visualization saved to html/note_80.html
# Processing Note 81 ========
# Visualization saved to html/note_81.html
# Processing Note 82 ========
# Visualization saved to html/note_82.html
# Processing Note 83 ========
# Visualization saved to html/note_83.html
# Processing Note 84 ========
# Visualization saved to html/note_84.html
# Processing Note 85 ========
# Visualization saved to html/note_85.html
# Processing Note 86 ========
# Visualization saved to html/note_86.html
# Processing Note 87 ========
# Visualization saved to html/note_87.html
# Processing Note 88 ========
# Visualization saved to html/note_88.html
# Processing Note 89 ========
# Visualization saved to html/note_89.html
# Processing Note 90 ========
# Visualization saved to html/note_90.html
# Processing Note 91 ========
# Visualization saved to html/note_91.html
# Processing Note 92 ========
# Visualization saved to html/note_92.html
# Processing Note 93 ========
# Visualization saved to html/note_93.html
# Processing Note 94 ========
# Visualization saved to html/note_94.html
# Processing Note 95 ========
# Visualization saved to html/note_95.html
# Processing Note 96 ========
# Visualization saved to html/note_96.html
# Processing Note 97 ========
# Visualization saved to html/note_97.html
# Processing Note 98 ========
# Visualization saved to html/note_98.html
# Processing Note 99 ========
# Visualization saved to html/note_99.html
# Processing Note 100 ========
# Visualization saved to html/note_100.html
# Processing Note 101 ========
# Visualization saved to html/note_101.html
# Processing Note 102 ========
# Visualization saved to html/note_102.html
# Processing Note 103 ========
# Visualization saved to html/note_103.html
# Processing Note 104 ========
# Visualization saved to html/note_104.html
# Processing Note 105 ========
# Visualization saved to html/note_105.html
# Processing Note 106 ========
# Visualization saved to html/note_106.html
# Processing Note 107 ========
# Visualization saved to html/note_107.html
# Processing Note 108 ========
# Visualization saved to html/note_108.html
# Processing Note 109 ========
# Visualization saved to html/note_109.html
# Processing Note 110 ========
# Visualization saved to html/note_110.html
# Processing Note 111 ========
# Visualization saved to html/note_111.html
# Processing Note 112 ========
# Visualization saved to html/note_112.html
# Processing Note 113 ========
# Visualization saved to html/note_113.html
# Processing Note 114 ========
# Visualization saved to html/note_114.html
# Processing Note 115 ========
# Visualization saved to html/note_115.html
# Processing Note 116 ========
# Visualization saved to html/note_116.html
# Processing Note 117 ========
# Visualization saved to html/note_117.html
# Processing Note 118 ========
# Visualization saved to html/note_118.html
# Processing Note 119 ========
# Visualization saved to html/note_119.html
# Processing Note 120 ========
# Visualization saved to html/note_120.html
# Processing Note 121 ========
# Visualization saved to html/note_121.html
# Processing Note 122 ========
# Visualization saved to html/note_122.html
# Processing Note 123 ========
# Visualization saved to html/note_123.html
# Processing Note 124 ========
# Visualization saved to html/note_124.html
# Processing Note 125 ========
# Visualization saved to html/note_125.html
# Processing Note 126 ========
# Visualization saved to html/note_126.html
# Processing Note 127 ========
# Visualization saved to html/note_127.html
# Processing Note 128 ========
# Visualization saved to html/note_128.html
# Processing Note 129 ========
# Visualization saved to html/note_129.html
# Processing Note 130 ========
# Visualization saved to html/note_130.html
# Processing Note 131 ========
# Visualization saved to html/note_131.html
# Processing Note 132 ========
# Visualization saved to html/note_132.html
# Processing Note 133 ========
# Visualization saved to html/note_133.html
# Processing Note 134 ========
# Visualization saved to html/note_134.html
# Processing Note 135 ========
# Visualization saved to html/note_135.html
# Processing Note 136 ========
# Visualization saved to html/note_136.html
# Processing Note 137 ========
# Visualization saved to html/note_137.html
# Processing Note 138 ========
# Visualization saved to html/note_138.html
# Processing Note 139 ========
# Visualization saved to html/note_139.html
# Processing Note 140 ========
# Visualization saved to html/note_140.html
# Processing Note 141 ========
# Visualization saved to html/note_141.html
# Processing Note 142 ========
# Visualization saved to html/note_142.html
# Processing Note 143 ========
# Visualization saved to html/note_143.html
# Processing Note 144 ========
# Visualization saved to html/note_144.html
# Processing Note 145 ========
# Visualization saved to html/note_145.html
# Processing Note 146 ========
# Visualization saved to html/note_146.html
# Processing Note 147 ========
# Visualization saved to html/note_147.html
# Processing Note 148 ========
# Visualization saved to html/note_148.html
# Processing Note 149 ========
# Visualization saved to html/note_149.html
# Processing Note 150 ========
# Visualization saved to html/note_150.html
# Processing Note 151 ========
# Visualization saved to html/note_151.html
# Processing Note 152 ========
# Visualization saved to html/note_152.html
# Processing Note 153 ========
# Visualization saved to html/note_153.html
# Processing Note 154 ========
# Visualization saved to html/note_154.html
# Processing Note 155 ========
# Visualization saved to html/note_155.html
# Processing Note 156 ========
# Visualization saved to html/note_156.html
# Processing Note 157 ========
# Visualization saved to html/note_157.html
# Processing Note 158 ========
# Visualization saved to html/note_158.html
# Processing Note 159 ========
# Visualization saved to html/note_159.html
# Processing Note 160 ========
# Visualization saved to html/note_160.html
# Processing Note 161 ========
# Visualization saved to html/note_161.html
# Processing Note 162 ========
# Visualization saved to html/note_162.html
# Processing Note 163 ========
# Visualization saved to html/note_163.html
# Processing Note 164 ========
# Visualization saved to html/note_164.html
# Processing Note 165 ========
# Visualization saved to html/note_165.html
# Processing Note 166 ========
# Visualization saved to html/note_166.html
# Processing Note 167 ========
# Visualization saved to html/note_167.html
# Processing Note 168 ========
# Visualization saved to html/note_168.html
# Processing Note 169 ========
# Visualization saved to html/note_169.html
# Processing Note 170 ========
# Visualization saved to html/note_170.html
# Processing Note 171 ========
# Visualization saved to html/note_171.html
# Processing Note 172 ========
# Visualization saved to html/note_172.html
# Processing Note 173 ========
# Visualization saved to html/note_173.html
# Processing Note 174 ========
# Visualization saved to html/note_174.html
# Processing Note 175 ========
# Visualization saved to html/note_175.html
# Processing Note 176 ========
# Visualization saved to html/note_176.html
# Processing Note 177 ========
# Visualization saved to html/note_177.html
# Processing Note 178 ========
# Visualization saved to html/note_178.html
# Processing Note 179 ========
# Visualization saved to html/note_179.html
# Processing Note 180 ========
# Visualization saved to html/note_180.html
# Processing Note 181 ========
# Visualization saved to html/note_181.html
# Processing Note 182 ========
# Visualization saved to html/note_182.html
# Processing Note 183 ========
# Visualization saved to html/note_183.html
# Processing Note 184 ========
# Visualization saved to html/note_184.html
# Processing Note 185 ========
# Visualization saved to html/note_185.html
# Processing Note 186 ========
# Visualization saved to html/note_186.html
# Processing Note 187 ========
# Visualization saved to html/note_187.html
# Processing Note 188 ========
# Visualization saved to html/note_188.html
# Processing Note 189 ========
# Visualization saved to html/note_189.html
# Processing Note 190 ========
# Visualization saved to html/note_190.html
# Processing Note 191 ========
# Visualization saved to html/note_191.html
# Processing Note 192 ========
# Visualization saved to html/note_192.html
# Processing Note 193 ========
# Visualization saved to html/note_193.html
# Processing Note 194 ========
# Visualization saved to html/note_194.html
# Processing Note 195 ========
# Visualization saved to html/note_195.html
# Processing Note 196 ========
# Visualization saved to html/note_196.html
# Processing Note 197 ========
# Visualization saved to html/note_197.html
# Processing Note 198 ========
# Visualization saved to html/note_198.html
# Processing Note 199 ========
# Visualization saved to html/note_199.html
# Processing Note 200 ========
# Visualization saved to html/note_200.html
# Processing Note 201 ========
# Visualization saved to html/note_201.html
# Processing Note 202 ========
# Visualization saved to html/note_202.html
# Processing Note 203 ========
# Visualization saved to html/note_203.html
# Processing Note 204 ========
# Visualization saved to html/note_204.html
# Processing Note 205 ========
# Visualization saved to html/note_205.html
# Processing Note 206 ========
# Visualization saved to html/note_206.html
# Processing Note 207 ========
# Visualization saved to html/note_207.html
# Processing Note 208 ========
# Visualization saved to html/note_208.html
# Processing Note 209 ========
# Visualization saved to html/note_209.html
# Processing Note 210 ========
# Visualization saved to html/note_210.html
# Processing Note 211 ========
# Visualization saved to html/note_211.html
# Processing Note 212 ========
# Visualization saved to html/note_212.html
# Processing Note 213 ========
# Visualization saved to html/note_213.html
# Processing Note 214 ========
# Visualization saved to html/note_214.html
# Processing Note 215 ========
# Visualization saved to html/note_215.html
# Processing Note 216 ========
# Visualization saved to html/note_216.html
# Processing Note 217 ========
# Visualization saved to html/note_217.html
# Processing Note 218 ========
# Visualization saved to html/note_218.html
# Processing Note 219 ========
# Visualization saved to html/note_219.html
# Processing Note 220 ========
# Visualization saved to html/note_220.html
# Processing Note 221 ========
# Visualization saved to html/note_221.html
# Processing Note 222 ========
# Visualization saved to html/note_222.html
# Processing Note 223 ========
# Visualization saved to html/note_223.html
# Processing Note 224 ========
# Visualization saved to html/note_224.html
# Processing Note 225 ========
# Visualization saved to html/note_225.html
# Processing Note 226 ========
# Visualization saved to html/note_226.html
# Processing Note 227 ========
# Visualization saved to html/note_227.html
# Processing Note 228 ========
# Visualization saved to html/note_228.html
# Processing Note 229 ========
# Visualization saved to html/note_229.html
# Processing Note 230 ========
# Visualization saved to html/note_230.html
# Processing Note 231 ========
# Visualization saved to html/note_231.html
# Processing Note 232 ========
# Visualization saved to html/note_232.html
# Processing Note 233 ========
# Visualization saved to html/note_233.html
# Processing Note 234 ========
# Visualization saved to html/note_234.html
# Processing Note 235 ========
# Visualization saved to html/note_235.html
# Processing Note 236 ========
# Visualization saved to html/note_236.html
# Processing Note 237 ========
# Visualization saved to html/note_237.html
# Processing Note 238 ========
# Visualization saved to html/note_238.html
# Processing Note 239 ========
# Visualization saved to html/note_239.html
# Processing Note 240 ========
# Visualization saved to html/note_240.html
# Processing Note 241 ========
# Visualization saved to html/note_241.html
# Processing Note 242 ========
# Visualization saved to html/note_242.html
# Processing Note 243 ========
# Visualization saved to html/note_243.html
# Processing Note 244 ========
# Visualization saved to html/note_244.html
# Processing Note 245 ========
# Visualization saved to html/note_245.html
# Processing Note 246 ========
# Visualization saved to html/note_246.html
# Processing Note 247 ========
# Visualization saved to html/note_247.html
# Processing Note 248 ========
# Visualization saved to html/note_248.html
# Processing Note 249 ========
# Visualization saved to html/note_249.html
# Processing Note 250 ========
# Visualization saved to html/note_250.html
# Processing Note 251 ========
# Visualization saved to html/note_251.html
# Processing Note 252 ========
# Visualization saved to html/note_252.html
# Processing Note 253 ========
# Visualization saved to html/note_253.html
# Processing Note 254 ========
# Visualization saved to html/note_254.html
# Processing Note 255 ========
# Visualization saved to html/note_255.html
# Processing Note 256 ========
# Visualization saved to html/note_256.html
# Processing Note 257 ========
# Visualization saved to html/note_257.html
# Processing Note 258 ========
# Visualization saved to html/note_258.html
# Processing Note 259 ========
# Visualization saved to html/note_259.html
# Processing Note 260 ========
# Visualization saved to html/note_260.html
# Processing Note 261 ========
# Visualization saved to html/note_261.html
# Processing Note 262 ========
# Visualization saved to html/note_262.html
# Processing Note 263 ========
# Visualization saved to html/note_263.html
# Processing Note 264 ========
# Visualization saved to html/note_264.html
# Processing Note 265 ========
# Visualization saved to html/note_265.html
# Processing Note 266 ========
# Visualization saved to html/note_266.html
# Processing Note 267 ========
# Visualization saved to html/note_267.html
# Processing Note 268 ========
# Visualization saved to html/note_268.html
# Processing Note 269 ========
# Visualization saved to html/note_269.html
# Processing Note 270 ========
# Visualization saved to html/note_270.html
# Processing Note 271 ========
# Visualization saved to html/note_271.html
# Processing Note 272 ========
# Visualization saved to html/note_272.html
# Processing Note 273 ========
# Visualization saved to html/note_273.html
# Processing Note 274 ========
# Visualization saved to html/note_274.html
# Processing Note 275 ========
# Visualization saved to html/note_275.html
# Processing Note 276 ========
# Visualization saved to html/note_276.html
# Processing Note 277 ========
# Visualization saved to html/note_277.html
# Processing Note 278 ========
# Visualization saved to html/note_278.html
# Processing Note 279 ========
# Visualization saved to html/note_279.html
# Processing Note 280 ========
# Visualization saved to html/note_280.html
# Processing Note 281 ========
# Visualization saved to html/note_281.html
# Processing Note 282 ========
# Visualization saved to html/note_282.html
# Processing Note 283 ========
# Visualization saved to html/note_283.html
# Processing Note 284 ========
# Visualization saved to html/note_284.html
# Processing Note 285 ========
# Visualization saved to html/note_285.html
# Processing Note 286 ========
# Visualization saved to html/note_286.html
# Processing Note 287 ========
# Visualization saved to html/note_287.html
# Processing Note 288 ========
# Visualization saved to html/note_288.html
# Processing Note 289 ========
# Visualization saved to html/note_289.html
# Processing Note 290 ========
# Visualization saved to html/note_290.html
# Processing Note 291 ========
# Visualization saved to html/note_291.html
# Processing Note 292 ========
# Visualization saved to html/note_292.html
# Processing Note 293 ========
# Visualization saved to html/note_293.html
# Processing Note 294 ========
# Visualization saved to html/note_294.html
# Processing Note 295 ========
# Visualization saved to html/note_295.html
# Processing Note 296 ========
# Visualization saved to html/note_296.html
# Processing Note 297 ========
# Visualization saved to html/note_297.html
# Processing Note 298 ========
# Visualization saved to html/note_298.html
# Processing Note 299 ========
# Visualization saved to html/note_299.html
# Processing Note 300 ========
# Visualization saved to html/note_300.html
# Processing Note 301 ========
# Visualization saved to html/note_301.html
# Processing Note 302 ========
# Visualization saved to html/note_302.html
# Processing Note 303 ========
# Visualization saved to html/note_303.html
# Processing Note 304 ========
# Visualization saved to html/note_304.html
# Processing Note 305 ========
# Visualization saved to html/note_305.html
# Processing Note 306 ========
# Visualization saved to html/note_306.html
# Processing Note 307 ========
# Visualization saved to html/note_307.html
# Processing Note 308 ========
# Visualization saved to html/note_308.html
# Processing Note 309 ========
# Visualization saved to html/note_309.html
# Processing Note 310 ========
# Visualization saved to html/note_310.html
# Processing Note 311 ========
# Visualization saved to html/note_311.html
# Processing Note 312 ========
# Visualization saved to html/note_312.html
# Processing Note 313 ========
# Visualization saved to html/note_313.html
# Processing Note 314 ========
# Visualization saved to html/note_314.html
# Processing Note 315 ========
# Visualization saved to html/note_315.html
# Processing Note 316 ========
# Visualization saved to html/note_316.html
# Processing Note 317 ========
# Visualization saved to html/note_317.html
# Processing Note 318 ========
# Visualization saved to html/note_318.html
# Processing Note 319 ========
# Visualization saved to html/note_319.html
# Processing Note 320 ========
# Visualization saved to html/note_320.html
# Processing Note 321 ========
# Visualization saved to html/note_321.html
# Processing Note 322 ========
# Visualization saved to html/note_322.html
# Processing Note 323 ========
# Visualization saved to html/note_323.html
# Processing Note 324 ========
# Visualization saved to html/note_324.html
# Processing Note 325 ========
# Visualization saved to html/note_325.html
# Processing Note 326 ========
# Visualization saved to html/note_326.html
# Processing Note 327 ========
# Visualization saved to html/note_327.html
# Processing Note 328 ========
# Visualization saved to html/note_328.html
# Processing Note 329 ========
# Visualization saved to html/note_329.html
# Processing Note 330 ========
# Visualization saved to html/note_330.html
# Processing Note 331 ========
# Visualization saved to html/note_331.html
# Processing Note 332 ========
# Visualization saved to html/note_332.html
# Processing Note 333 ========
# Visualization saved to html/note_333.html
# Processing Note 334 ========
# Visualization saved to html/note_334.html
# Processing Note 335 ========
# Visualization saved to html/note_335.html
# Processing Note 336 ========
# Visualization saved to html/note_336.html
# Processing Note 337 ========
# Visualization saved to html/note_337.html
# Processing Note 338 ========
# Visualization saved to html/note_338.html
# Processing Note 339 ========
# Visualization saved to html/note_339.html
# Processing Note 340 ========
# Visualization saved to html/note_340.html
# Processing Note 341 ========
# Visualization saved to html/note_341.html
# Processing Note 342 ========
# Visualization saved to html/note_342.html
# Processing Note 343 ========
# Visualization saved to html/note_343.html
# Processing Note 344 ========
# Visualization saved to html/note_344.html
# Processing Note 345 ========
# Visualization saved to html/note_345.html
# Processing Note 346 ========
# Visualization saved to html/note_346.html
# Processing Note 347 ========
# Visualization saved to html/note_347.html
# Processing Note 348 ========
# Visualization saved to html/note_348.html
# Processing Note 349 ========
# Visualization saved to html/note_349.html
# Processing Note 350 ========
# Visualization saved to html/note_350.html
# Processing Note 351 ========
# Visualization saved to html/note_351.html
# Processing Note 352 ========
# Visualization saved to html/note_352.html
# Processing Note 353 ========
# Visualization saved to html/note_353.html
# Processing Note 354 ========
# Visualization saved to html/note_354.html
# Processing Note 355 ========
# Visualization saved to html/note_355.html
# Processing Note 356 ========
# Visualization saved to html/note_356.html
# Processing Note 357 ========
# Visualization saved to html/note_357.html
# Processing Note 358 ========
# Visualization saved to html/note_358.html
# Processing Note 359 ========
# Visualization saved to html/note_359.html
# Processing Note 360 ========
# Visualization saved to html/note_360.html
# Processing Note 361 ========
# Visualization saved to html/note_361.html
# Processing Note 362 ========
# Visualization saved to html/note_362.html
# Processing Note 363 ========
# Visualization saved to html/note_363.html
# Processing Note 364 ========
# Visualization saved to html/note_364.html
# Processing Note 365 ========
# Visualization saved to html/note_365.html
# Processing Note 366 ========
# Visualization saved to html/note_366.html
# Processing Note 367 ========
# Visualization saved to html/note_367.html
# Processing Note 368 ========
# Visualization saved to html/note_368.html
# Processing Note 369 ========
# Visualization saved to html/note_369.html
# Processing Note 370 ========
# Visualization saved to html/note_370.html
# Processing Note 371 ========
# Visualization saved to html/note_371.html
# Processing Note 372 ========
# Visualization saved to html/note_372.html
# Processing Note 373 ========
# Visualization saved to html/note_373.html
# Processing Note 374 ========
# Visualization saved to html/note_374.html
# Processing Note 375 ========
# Visualization saved to html/note_375.html
# Processing Note 376 ========
# Visualization saved to html/note_376.html
# Processing Note 377 ========
# Visualization saved to html/note_377.html
# Processing Note 378 ========
# Visualization saved to html/note_378.html
# Processing Note 379 ========
# Visualization saved to html/note_379.html
# Processing Note 380 ========
# Visualization saved to html/note_380.html
# Processing Note 381 ========
# Visualization saved to html/note_381.html
# Processing Note 382 ========
# Visualization saved to html/note_382.html
# Processing Note 383 ========
# Visualization saved to html/note_383.html
# Processing Note 384 ========
# Visualization saved to html/note_384.html
# Processing Note 385 ========
# Visualization saved to html/note_385.html
# Processing Note 386 ========
# Visualization saved to html/note_386.html
# Processing Note 387 ========
# Visualization saved to html/note_387.html
# Processing Note 388 ========
# Visualization saved to html/note_388.html
# Processing Note 389 ========
# Visualization saved to html/note_389.html
# Processing Note 390 ========
# Visualization saved to html/note_390.html
# Processing Note 391 ========
# Visualization saved to html/note_391.html
# Processing Note 392 ========
# Visualization saved to html/note_392.html
# Processing Note 393 ========
# Visualization saved to html/note_393.html
# Processing Note 394 ========
# Visualization saved to html/note_394.html
# Processing Note 395 ========
# Visualization saved to html/note_395.html
# Processing Note 396 ========
# Visualization saved to html/note_396.html
# Processing Note 397 ========
# Visualization saved to html/note_397.html
# Processing Note 398 ========
# Visualization saved to html/note_398.html
# Processing Note 399 ========
# Visualization saved to html/note_399.html
# Processing Note 400 ========
# Visualization saved to html/note_400.html
# Processing Note 401 ========
# Visualization saved to html/note_401.html
# Processing Note 402 ========
# Visualization saved to html/note_402.html
# Processing Note 403 ========
# Visualization saved to html/note_403.html
# Processing Note 404 ========
# Visualization saved to html/note_404.html
# Processing Note 405 ========
# Visualization saved to html/note_405.html
# Processing Note 406 ========
# Visualization saved to html/note_406.html
# Processing Note 407 ========
# Visualization saved to html/note_407.html
# Processing Note 408 ========
# Visualization saved to html/note_408.html
# Processing Note 409 ========
# Visualization saved to html/note_409.html
# Processing Note 410 ========
# Visualization saved to html/note_410.html
# Processing Note 411 ========
# Visualization saved to html/note_411.html
# Processing Note 412 ========
# Visualization saved to html/note_412.html
# Processing Note 413 ========
# Visualization saved to html/note_413.html
# Processing Note 414 ========
# Visualization saved to html/note_414.html
# Processing Note 415 ========
# Visualization saved to html/note_415.html
# Processing Note 416 ========
# Visualization saved to html/note_416.html
# Processing Note 417 ========
# Visualization saved to html/note_417.html
# Processing Note 418 ========
# Visualization saved to html/note_418.html
# Processing Note 419 ========
# Visualization saved to html/note_419.html
# Processing Note 420 ========
# Visualization saved to html/note_420.html
# Processing Note 421 ========
# Visualization saved to html/note_421.html
# Processing Note 422 ========
# Visualization saved to html/note_422.html
# Processing Note 423 ========
# Visualization saved to html/note_423.html
# Processing Note 424 ========
# Visualization saved to html/note_424.html
# Processing Note 425 ========
# Visualization saved to html/note_425.html
# Processing Note 426 ========
# Visualization saved to html/note_426.html
# Processing Note 427 ========
# Visualization saved to html/note_427.html
# Processing Note 428 ========
# Visualization saved to html/note_428.html
# Processing Note 429 ========
# Visualization saved to html/note_429.html
# Processing Note 430 ========
# Visualization saved to html/note_430.html
# Processing Note 431 ========
# Visualization saved to html/note_431.html
# Processing Note 432 ========
# Visualization saved to html/note_432.html
# Processing Note 433 ========
# Visualization saved to html/note_433.html
# Processing Note 434 ========
# Visualization saved to html/note_434.html
# Processing Note 435 ========
# Visualization saved to html/note_435.html
# Processing Note 436 ========
# Visualization saved to html/note_436.html
# Processing Note 437 ========
# Visualization saved to html/note_437.html
# Processing Note 438 ========
# Visualization saved to html/note_438.html
# Processing Note 439 ========
# Visualization saved to html/note_439.html
# Processing Note 440 ========
# Visualization saved to html/note_440.html
# Processing Note 441 ========
# Visualization saved to html/note_441.html
# Processing Note 442 ========
# Visualization saved to html/note_442.html
# Processing Note 443 ========
# Visualization saved to html/note_443.html
# Processing Note 444 ========
# Visualization saved to html/note_444.html
# Processing Note 445 ========
# Visualization saved to html/note_445.html
# Processing Note 446 ========
# Visualization saved to html/note_446.html
# Processing Note 447 ========
# Visualization saved to html/note_447.html
# Processing Note 448 ========
# Visualization saved to html/note_448.html
# Processing Note 449 ========
# Visualization saved to html/note_449.html
# Processing Note 450 ========
# Visualization saved to html/note_450.html
# Processing Note 451 ========
# Visualization saved to html/note_451.html
# Processing Note 452 ========
# Visualization saved to html/note_452.html
# Processing Note 453 ========
# Visualization saved to html/note_453.html
# Processing Note 454 ========
# Visualization saved to html/note_454.html
# Processing Note 455 ========
# Visualization saved to html/note_455.html
# Processing Note 456 ========
# Visualization saved to html/note_456.html
# Processing Note 457 ========
# Visualization saved to html/note_457.html
# Processing Note 458 ========
# Visualization saved to html/note_458.html
# Processing Note 459 ========
# Visualization saved to html/note_459.html
# Processing Note 460 ========
# Visualization saved to html/note_460.html
# Processing Note 461 ========
# Visualization saved to html/note_461.html
# Processing Note 462 ========
# Visualization saved to html/note_462.html
# Processing Note 463 ========
# Visualization saved to html/note_463.html
# Processing Note 464 ========
# Visualization saved to html/note_464.html
# Processing Note 465 ========
# Visualization saved to html/note_465.html
# Processing Note 466 ========
# Visualization saved to html/note_466.html
# Processing Note 467 ========
# Visualization saved to html/note_467.html
# Processing Note 468 ========
# Visualization saved to html/note_468.html
# Processing Note 469 ========
# Visualization saved to html/note_469.html
# Processing Note 470 ========
# Visualization saved to html/note_470.html
# Processing Note 471 ========
# Visualization saved to html/note_471.html
# Processing Note 472 ========
# Visualization saved to html/note_472.html
# Processing Note 473 ========
# Visualization saved to html/note_473.html
# Processing Note 474 ========
# Visualization saved to html/note_474.html
# Processing Note 475 ========
# Visualization saved to html/note_475.html
# Processing Note 476 ========
# Visualization saved to html/note_476.html
# Processing Note 477 ========
# Visualization saved to html/note_477.html
# Processing Note 478 ========
# Visualization saved to html/note_478.html
# Processing Note 479 ========
# Visualization saved to html/note_479.html
# Processing Note 480 ========
# Visualization saved to html/note_480.html
# Processing Note 481 ========
# Visualization saved to html/note_481.html
# Processing Note 482 ========
# Visualization saved to html/note_482.html
# Processing Note 483 ========
# Visualization saved to html/note_483.html
# Processing Note 484 ========
# Visualization saved to html/note_484.html
# Processing Note 485 ========
# Visualization saved to html/note_485.html
# Processing Note 486 ========
# Visualization saved to html/note_486.html
# Processing Note 487 ========
# Visualization saved to html/note_487.html
# Processing Note 488 ========
# Visualization saved to html/note_488.html
# Processing Note 489 ========
# Visualization saved to html/note_489.html
# Processing Note 490 ========
# Visualization saved to html/note_490.html
# Processing Note 491 ========
# Visualization saved to html/note_491.html
# Processing Note 492 ========
# Visualization saved to html/note_492.html
# Processing Note 493 ========
# Visualization saved to html/note_493.html
# Processing Note 494 ========
# Visualization saved to html/note_494.html
# Processing Note 495 ========
# Visualization saved to html/note_495.html
# Processing Note 496 ========
# Visualization saved to html/note_496.html
# Processing Note 497 ========
# Visualization saved to html/note_497.html
# Processing Note 498 ========
# Visualization saved to html/note_498.html
# Processing Note 499 ========
# Visualization saved to html/note_499.html
# Processing Note 500 ========
# Visualization saved to html/note_500.html
# Processing Note 501 ========
# Visualization saved to html/note_501.html
# Processing Note 502 ========
# Visualization saved to html/note_502.html
# Processing Note 503 ========
# Visualization saved to html/note_503.html
# Processing Note 504 ========
# Visualization saved to html/note_504.html
# Processing Note 505 ========
# Visualization saved to html/note_505.html
# Processing Note 506 ========
# Visualization saved to html/note_506.html
# Processing Note 507 ========
# Visualization saved to html/note_507.html
# Processing Note 508 ========
# Visualization saved to html/note_508.html
# Processing Note 509 ========
# Visualization saved to html/note_509.html
# Processing Note 510 ========
# Visualization saved to html/note_510.html
# Processing Note 511 ========
# Visualization saved to html/note_511.html
# Processing Note 512 ========
# Visualization saved to html/note_512.html
# Processing Note 513 ========
# Visualization saved to html/note_513.html
# Processing Note 514 ========
# Visualization saved to html/note_514.html
# Processing Note 515 ========
# Visualization saved to html/note_515.html
# Processing Note 516 ========
# Visualization saved to html/note_516.html
# Processing Note 517 ========
# Visualization saved to html/note_517.html
# Processing Note 518 ========
# Visualization saved to html/note_518.html
# Processing Note 519 ========
# Visualization saved to html/note_519.html
# Processing Note 520 ========
# Visualization saved to html/note_520.html
# Processing Note 521 ========
# Visualization saved to html/note_521.html
# Processing Note 522 ========
# Visualization saved to html/note_522.html
# Processing Note 523 ========
# Visualization saved to html/note_523.html
# Processing Note 524 ========
# Visualization saved to html/note_524.html
# Processing Note 525 ========
# Visualization saved to html/note_525.html
# Processing Note 526 ========
# Visualization saved to html/note_526.html
# Processing Note 527 ========
# Visualization saved to html/note_527.html
# Processing Note 528 ========
# Visualization saved to html/note_528.html
# Processing Note 529 ========
# Visualization saved to html/note_529.html
# Processing Note 530 ========
# Visualization saved to html/note_530.html
# Processing Note 531 ========
# Visualization saved to html/note_531.html
# Processing Note 532 ========
# Visualization saved to html/note_532.html
# Processing Note 533 ========
# Visualization saved to html/note_533.html
# Processing Note 534 ========
# Visualization saved to html/note_534.html
# Processing Note 535 ========
# Visualization saved to html/note_535.html
# Processing Note 536 ========
# Visualization saved to html/note_536.html
# Processing Note 537 ========
# Visualization saved to html/note_537.html
# Processing Note 538 ========
# Visualization saved to html/note_538.html
# Processing Note 539 ========
# Visualization saved to html/note_539.html
# Processing Note 540 ========
# Visualization saved to html/note_540.html
# Processing Note 541 ========
# Visualization saved to html/note_541.html
# Processing Note 542 ========
# Visualization saved to html/note_542.html
# Processing Note 543 ========
# Visualization saved to html/note_543.html
# Processing Note 544 ========
# Visualization saved to html/note_544.html
# Processing Note 545 ========
# Visualization saved to html/note_545.html
# Processing Note 546 ========
# Visualization saved to html/note_546.html
# Processing Note 547 ========
# Visualization saved to html/note_547.html
# Processing Note 548 ========
# Visualization saved to html/note_548.html
# Processing Note 549 ========
# Visualization saved to html/note_549.html
# Processing Note 550 ========
# Visualization saved to html/note_550.html
# Processing Note 551 ========
# Visualization saved to html/note_551.html
# Processing Note 552 ========
# Visualization saved to html/note_552.html
# Processing Note 553 ========
# Visualization saved to html/note_553.html
# Processing Note 554 ========
# Visualization saved to html/note_554.html
# Processing Note 555 ========
# Visualization saved to html/note_555.html
# Processing Note 556 ========
# Visualization saved to html/note_556.html
# Processing Note 557 ========
# Visualization saved to html/note_557.html
# Processing Note 558 ========
# Visualization saved to html/note_558.html
# Processing Note 559 ========
# Visualization saved to html/note_559.html
# Processing Note 560 ========
# Visualization saved to html/note_560.html
# Processing Note 561 ========
# Visualization saved to html/note_561.html
# Processing Note 562 ========
# Visualization saved to html/note_562.html
# Processing Note 563 ========
# Visualization saved to html/note_563.html
# Processing Note 564 ========
# Visualization saved to html/note_564.html
# Processing Note 565 ========
# Visualization saved to html/note_565.html
# Processing Note 566 ========
# Visualization saved to html/note_566.html
# Processing Note 567 ========
# Visualization saved to html/note_567.html
# Processing Note 568 ========
# Visualization saved to html/note_568.html
# Processing Note 569 ========
# Visualization saved to html/note_569.html
# Processing Note 570 ========
# Visualization saved to html/note_570.html
# Processing Note 571 ========
# Visualization saved to html/note_571.html
# Processing Note 572 ========
# Visualization saved to html/note_572.html
# Processing Note 573 ========
# Visualization saved to html/note_573.html
# Processing Note 574 ========
# Visualization saved to html/note_574.html
# Processing Note 575 ========
# Visualization saved to html/note_575.html
# Processing Note 576 ========
# Visualization saved to html/note_576.html
# Processing Note 577 ========
# Visualization saved to html/note_577.html
# Processing Note 578 ========
# Visualization saved to html/note_578.html
# Processing Note 579 ========
# Visualization saved to html/note_579.html
# Processing Note 580 ========
# Visualization saved to html/note_580.html
# Processing Note 581 ========
# Visualization saved to html/note_581.html
# Processing Note 582 ========
# Visualization saved to html/note_582.html
# Processing Note 583 ========
# Visualization saved to html/note_583.html
# Processing Note 584 ========
# Visualization saved to html/note_584.html
# Processing Note 585 ========
# Visualization saved to html/note_585.html
# Processing Note 586 ========
# Visualization saved to html/note_586.html
# Processing Note 587 ========
# Visualization saved to html/note_587.html
# Processing Note 588 ========
# Visualization saved to html/note_588.html
# Processing Note 589 ========
# Visualization saved to html/note_589.html
# Processing Note 590 ========
# Visualization saved to html/note_590.html
# Processing Note 591 ========
# Visualization saved to html/note_591.html
# Processing Note 592 ========
# Visualization saved to html/note_592.html
# Processing Note 593 ========
# Visualization saved to html/note_593.html
# Processing Note 594 ========
# Visualization saved to html/note_594.html
# Processing Note 595 ========
# Visualization saved to html/note_595.html
# Processing Note 596 ========
# Visualization saved to html/note_596.html
# Processing Note 597 ========
# Visualization saved to html/note_597.html
# Processing Note 598 ========
# Visualization saved to html/note_598.html
# Processing Note 599 ========
# Visualization saved to html/note_599.html
# Processing Note 600 ========
# Visualization saved to html/note_600.html
# Processing Note 601 ========
# Visualization saved to html/note_601.html
# Processing Note 602 ========
# Visualization saved to html/note_602.html
# Processing Note 603 ========
# Visualization saved to html/note_603.html
# Processing Note 604 ========
# Visualization saved to html/note_604.html
# Processing Note 605 ========
# Visualization saved to html/note_605.html
# Processing Note 606 ========
# Visualization saved to html/note_606.html
# Processing Note 607 ========
# Visualization saved to html/note_607.html
# Processing Note 608 ========
# Visualization saved to html/note_608.html
# Processing Note 609 ========
# Visualization saved to html/note_609.html
# Processing Note 610 ========
# Visualization saved to html/note_610.html
# Processing Note 611 ========
# Visualization saved to html/note_611.html
# Processing Note 612 ========
# Visualization saved to html/note_612.html
# Processing Note 613 ========
# Visualization saved to html/note_613.html
# Processing Note 614 ========
# Visualization saved to html/note_614.html
# Processing Note 615 ========
# Visualization saved to html/note_615.html
# Processing Note 616 ========
# Visualization saved to html/note_616.html
# Processing Note 617 ========
# Visualization saved to html/note_617.html
# Processing Note 618 ========
# Visualization saved to html/note_618.html
# Processing Note 619 ========
# Visualization saved to html/note_619.html
# Processing Note 620 ========
# Visualization saved to html/note_620.html
# Processing Note 621 ========
# Visualization saved to html/note_621.html
# Processing Note 622 ========
# Visualization saved to html/note_622.html
# Processing Note 623 ========
# Visualization saved to html/note_623.html
# Processing Note 624 ========
# Visualization saved to html/note_624.html
# Processing Note 625 ========
# Visualization saved to html/note_625.html
# Processing Note 626 ========
# Visualization saved to html/note_626.html
# Processing Note 627 ========
# Visualization saved to html/note_627.html
# Processing Note 628 ========
# Visualization saved to html/note_628.html
# Processing Note 629 ========
# Visualization saved to html/note_629.html
# Processing Note 630 ========
# Visualization saved to html/note_630.html
# Processing Note 631 ========
# Visualization saved to html/note_631.html
# Processing Note 632 ========
# Visualization saved to html/note_632.html
# Processing Note 633 ========
# Visualization saved to html/note_633.html
# Processing Note 634 ========
# Visualization saved to html/note_634.html
# Processing Note 635 ========
# Visualization saved to html/note_635.html
# Processing Note 636 ========
# Visualization saved to html/note_636.html
# Processing Note 637 ========
# Visualization saved to html/note_637.html
# Processing Note 638 ========
# Visualization saved to html/note_638.html
# Processing Note 639 ========
# Visualization saved to html/note_639.html
# Processing Note 640 ========
# Visualization saved to html/note_640.html
# Processing Note 641 ========
# Visualization saved to html/note_641.html
# Processing Note 642 ========
# Visualization saved to html/note_642.html
# Processing Note 643 ========
# Visualization saved to html/note_643.html
# Processing Note 644 ========
# Visualization saved to html/note_644.html
# Processing Note 645 ========
# Visualization saved to html/note_645.html
# Processing Note 646 ========
# Visualization saved to html/note_646.html
# Processing Note 647 ========
# Visualization saved to html/note_647.html
# Processing Note 648 ========
# Visualization saved to html/note_648.html
# Processing Note 649 ========
# Visualization saved to html/note_649.html
# Processing Note 650 ========
# Visualization saved to html/note_650.html
# Processing Note 651 ========
# Visualization saved to html/note_651.html
# Processing Note 652 ========
# Visualization saved to html/note_652.html
# Processing Note 653 ========
# Visualization saved to html/note_653.html
# Processing Note 654 ========
# Visualization saved to html/note_654.html
# Processing Note 655 ========
# Visualization saved to html/note_655.html
# Processing Note 656 ========
# Visualization saved to html/note_656.html
# Processing Note 657 ========
# Visualization saved to html/note_657.html
# Processing Note 658 ========
# Visualization saved to html/note_658.html
# Processing Note 659 ========
# Visualization saved to html/note_659.html
# Processing Note 660 ========
# Visualization saved to html/note_660.html
# Processing Note 661 ========
# Visualization saved to html/note_661.html
# Processing Note 662 ========
# Visualization saved to html/note_662.html
# Processing Note 663 ========
# Visualization saved to html/note_663.html
# Processing Note 664 ========
# Visualization saved to html/note_664.html
# Processing Note 665 ========
# Visualization saved to html/note_665.html
# Processing Note 666 ========
# Visualization saved to html/note_666.html
# Processing Note 667 ========
# Visualization saved to html/note_667.html
# Processing Note 668 ========
# Visualization saved to html/note_668.html
# Processing Note 669 ========
# Visualization saved to html/note_669.html
# Processing Note 670 ========
# Visualization saved to html/note_670.html
# Processing Note 671 ========
# Visualization saved to html/note_671.html
# Processing Note 672 ========
# Visualization saved to html/note_672.html
# Processing Note 673 ========
# Visualization saved to html/note_673.html
# Processing Note 674 ========
# Visualization saved to html/note_674.html
# Processing Note 675 ========
# Visualization saved to html/note_675.html
# Processing Note 676 ========
# Visualization saved to html/note_676.html
# Processing Note 677 ========
# Visualization saved to html/note_677.html
# Processing Note 678 ========
# Visualization saved to html/note_678.html
# ...
# Processing Note 10609 ========
# Visualization saved to html/note_10609.html
# Processing Note 10610 ========
# Visualization saved to html/note_10610.html
# Processing Note 10611 ========
# Visualization saved to html/note_10611.html
# Processing Note 10612 ========
# Visualization saved to html/note_10612.html
# Processing Note 10613 ========
# Visualization saved to html/note_10613.html
# Processing Note 10614 ========
# Visualization saved to html/note_10614.html
# Processing Note 10615 ========
# Visualization saved to html/note_10615.html
# Processing Note 10616 ========
# Visualization saved to html/note_10616.html
# Processing Note 10617 ========
# Visualization saved to html/note_10617.html
# Processing Note 10618 ========
# Visualization saved to html/note_10618.html
# Processing Note 10619 ========
# Visualization saved to html/note_10619.html
# Processing Note 10620 ========
# Visualization saved to html/note_10620.html
# Processing Note 10621 ========
# Visualization saved to html/note_10621.html
# Processing Note 10622 ========
# Visualization saved to html/note_10622.html
# Processing Note 10623 ========
# Visualization saved to html/note_10623.html
# Processing Note 10624 ========
# Visualization saved to html/note_10624.html
# Processing Note 10625 ========
# Visualization saved to html/note_10625.html
# Processing Note 10626 ========
# Visualization saved to html/note_10626.html
# Processing Note 10627 ========
# Visualization saved to html/note_10627.html
# Processing Note 10628 ========
# Visualization saved to html/note_10628.html
# Processing Note 10629 ========
# Visualization saved to html/note_10629.html
# Processing Note 10630 ========
# Visualization saved to html/note_10630.html
# Processing Note 10631 ========
# Visualization saved to html/note_10631.html
# Processing Note 10632 ========
# Visualization saved to html/note_10632.html
# Processing Note 10633 ========
# Visualization saved to html/note_10633.html
# Processing Note 10634 ========
# Visualization saved to html/note_10634.html
# Processing Note 10635 ========
# Visualization saved to html/note_10635.html
# Processing Note 10636 ========
# Visualization saved to html/note_10636.html
# Processing Note 10637 ========
# Visualization saved to html/note_10637.html
# Processing Note 10638 ========
# Visualization saved to html/note_10638.html
# Processing Note 10639 ========
# Visualization saved to html/note_10639.html
# Processing Note 10640 ========
# Visualization saved to html/note_10640.html
# Processing Note 10641 ========
# Visualization saved to html/note_10641.html
# Processing Note 10642 ========
# Visualization saved to html/note_10642.html
# Processing Note 10643 ========
# Visualization saved to html/note_10643.html
# Processing Note 10644 ========
# Visualization saved to html/note_10644.html
# Processing Note 10645 ========
# Visualization saved to html/note_10645.html
# Processing Note 10646 ========
# Visualization saved to html/note_10646.html
# Processing Note 10647 ========
# Visualization saved to html/note_10647.html
# Processing Note 10648 ========
# Visualization saved to html/note_10648.html
# Processing Note 10649 ========
# Visualization saved to html/note_10649.html
# Processing Note 10650 ========
# Visualization saved to html/note_10650.html
# Processing Note 10651 ========
# Visualization saved to html/note_10651.html
# Processing Note 10652 ========
# Visualization saved to html/note_10652.html
# Processing Note 10653 ========
# Visualization saved to html/note_10653.html
# Processing Note 10654 ========
# Visualization saved to html/note_10654.html
# Processing Note 10655 ========
# Visualization saved to html/note_10655.html
# Processing Note 10656 ========
# Visualization saved to html/note_10656.html
# Processing Note 10657 ========
# Visualization saved to html/note_10657.html
# Processing Note 10658 ========
# Visualization saved to html/note_10658.html
# Processing Note 10659 ========
# Visualization saved to html/note_10659.html
# Processing Note 10660 ========
# Visualization saved to html/note_10660.html
# Processing Note 10661 ========
# Visualization saved to html/note_10661.html
# Processing Note 10662 ========
# Visualization saved to html/note_10662.html
# Processing Note 10663 ========
# Visualization saved to html/note_10663.html
# Processing Note 10664 ========
# Visualization saved to html/note_10664.html
# Processing Note 10665 ========
# Visualization saved to html/note_10665.html
# Processing Note 10666 ========
# Visualization saved to html/note_10666.html
# Processing Note 10667 ========
# Visualization saved to html/note_10667.html
# Processing Note 10668 ========
# Visualization saved to html/note_10668.html
# Processing Note 10669 ========
# Visualization saved to html/note_10669.html
# Processing Note 10670 ========
# Visualization saved to html/note_10670.html
# Processing Note 10671 ========
# Visualization saved to html/note_10671.html
# Processing Note 10672 ========
# Visualization saved to html/note_10672.html
# Processing Note 10673 ========
# Visualization saved to html/note_10673.html
# Processing Note 10674 ========
# Visualization saved to html/note_10674.html
# Processing Note 10675 ========
# Visualization saved to html/note_10675.html
# Processing Note 10676 ========
# Visualization saved to html/note_10676.html
# Processing Note 10677 ========
# Visualization saved to html/note_10677.html
# Processing Note 10678 ========
# Visualization saved to html/note_10678.html
# Processing Note 10679 ========
# Visualization saved to html/note_10679.html
# Processing Note 10680 ========
# Visualization saved to html/note_10680.html
# Processing Note 10681 ========
# Visualization saved to html/note_10681.html
# Processing Note 10682 ========
# Visualization saved to html/note_10682.html
# Processing Note 10683 ========
# Visualization saved to html/note_10683.html
# Processing Note 10684 ========
# Visualization saved to html/note_10684.html
# Processing Note 10685 ========
# Visualization saved to html/note_10685.html
# Processing Note 10686 ========
# Visualization saved to html/note_10686.html
# Processing Note 10687 ========
# Visualization saved to html/note_10687.html
# Processing Note 10688 ========
# Visualization saved to html/note_10688.html
# Processing Note 10689 ========
# Visualization saved to html/note_10689.html
# Processing Note 10690 ========
# Visualization saved to html/note_10690.html
# Processing Note 10691 ========
# Visualization saved to html/note_10691.html
# Processing Note 10692 ========
# Visualization saved to html/note_10692.html
# Processing Note 10693 ========
# Visualization saved to html/note_10693.html
# Processing Note 10694 ========
# Visualization saved to html/note_10694.html
# Processing Note 10695 ========
# Visualization saved to html/note_10695.html
# Processing Note 10696 ========
# Visualization saved to html/note_10696.html
# Processing Note 10697 ========
# Visualization saved to html/note_10697.html
# Processing Note 10698 ========
# Visualization saved to html/note_10698.html
# Processing Note 10699 ========
# Visualization saved to html/note_10699.html
# Processing Note 10700 ========
# Visualization saved to html/note_10700.html
# Processing Note 10701 ========
# Visualization saved to html/note_10701.html
# Processing Note 10702 ========
# Visualization saved to html/note_10702.html
# Processing Note 10703 ========
# Visualization saved to html/note_10703.html
# Processing Note 10704 ========
# Visualization saved to html/note_10704.html
# Processing Note 10705 ========
# Visualization saved to html/note_10705.html
# Processing Note 10706 ========
# Visualization saved to html/note_10706.html
# Processing Note 10707 ========
# Visualization saved to html/note_10707.html
# Processing Note 10708 ========
# Visualization saved to html/note_10708.html
# Processing Note 10709 ========
# Visualization saved to html/note_10709.html
# Processing Note 10710 ========
# Visualization saved to html/note_10710.html
# Processing Note 10711 ========
# Visualization saved to html/note_10711.html
# Processing Note 10712 ========
# Visualization saved to html/note_10712.html
# Processing Note 10713 ========
# Visualization saved to html/note_10713.html
# Processing Note 10714 ========
# Visualization saved to html/note_10714.html
# Processing Note 10715 ========
# Visualization saved to html/note_10715.html
# Processing Note 10716 ========
# Visualization saved to html/note_10716.html
# Processing Note 10717 ========
# Visualization saved to html/note_10717.html
# Processing Note 10718 ========
# Visualization saved to html/note_10718.html
# Processing Note 10719 ========
# Visualization saved to html/note_10719.html
# Processing Note 10720 ========
# Visualization saved to html/note_10720.html
# Processing Note 10721 ========
# Visualization saved to html/note_10721.html
# Processing Note 10722 ========
# Visualization saved to html/note_10722.html
# Processing Note 10723 ========
# Visualization saved to html/note_10723.html
# Processing Note 10724 ========
# Visualization saved to html/note_10724.html
# Processing Note 10725 ========
# Visualization saved to html/note_10725.html
# Processing Note 10726 ========
# Visualization saved to html/note_10726.html
# Processing Note 10727 ========
# Visualization saved to html/note_10727.html
# Processing Note 10728 ========
# Visualization saved to html/note_10728.html
# Processing Note 10729 ========
# Visualization saved to html/note_10729.html
# Processing Note 10730 ========
# Visualization saved to html/note_10730.html
# Processing Note 10731 ========
# Visualization saved to html/note_10731.html
# Processing Note 10732 ========
# Visualization saved to html/note_10732.html
# Processing Note 10733 ========
# Visualization saved to html/note_10733.html
# Processing Note 10734 ========
# Visualization saved to html/note_10734.html
# Processing Note 10735 ========
# Visualization saved to html/note_10735.html
# Processing Note 10736 ========
# Visualization saved to html/note_10736.html
# Processing Note 10737 ========
# Visualization saved to html/note_10737.html
# Processing Note 10738 ========
# Visualization saved to html/note_10738.html
# Processing Note 10739 ========
# Visualization saved to html/note_10739.html
# Processing Note 10740 ========
# Visualization saved to html/note_10740.html
# Processing Note 10741 ========
# Visualization saved to html/note_10741.html
# Processing Note 10742 ========
# Visualization saved to html/note_10742.html
# Processing Note 10743 ========
# Visualization saved to html/note_10743.html
# Processing Note 10744 ========
# Visualization saved to html/note_10744.html
# Processing Note 10745 ========
# Visualization saved to html/note_10745.html
# Processing Note 10746 ========
# Visualization saved to html/note_10746.html
# Processing Note 10747 ========
# Visualization saved to html/note_10747.html
# Processing Note 10748 ========
# Visualization saved to html/note_10748.html
# Processing Note 10749 ========
# Visualization saved to html/note_10749.html
# Processing Note 10750 ========
# Visualization saved to html/note_10750.html
# Processing Note 10751 ========
# Visualization saved to html/note_10751.html
# Processing Note 10752 ========
# Visualization saved to html/note_10752.html
# Processing Note 10753 ========
# Visualization saved to html/note_10753.html
# Processing Note 10754 ========
# Visualization saved to html/note_10754.html
# Processing Note 10755 ========
# Visualization saved to html/note_10755.html
# Processing Note 10756 ========
# Visualization saved to html/note_10756.html
# Processing Note 10757 ========
# Visualization saved to html/note_10757.html
# Processing Note 10758 ========
# Visualization saved to html/note_10758.html
# Processing Note 10759 ========
# Visualization saved to html/note_10759.html
# Processing Note 10760 ========
# Visualization saved to html/note_10760.html
# Processing Note 10761 ========
# Visualization saved to html/note_10761.html
# Processing Note 10762 ========
# Visualization saved to html/note_10762.html
# Processing Note 10763 ========
# Visualization saved to html/note_10763.html
# Processing Note 10764 ========
# Visualization saved to html/note_10764.html
# Processing Note 10765 ========
# Visualization saved to html/note_10765.html
# Processing Note 10766 ========
# Visualization saved to html/note_10766.html
# Processing Note 10767 ========
# Visualization saved to html/note_10767.html
# Processing Note 10768 ========
# Visualization saved to html/note_10768.html
# Processing Note 10769 ========
# Visualization saved to html/note_10769.html
# Processing Note 10770 ========
# Visualization saved to html/note_10770.html
# Processing Note 10771 ========
# Visualization saved to html/note_10771.html
# Processing Note 10772 ========
# Visualization saved to html/note_10772.html
# Processing Note 10773 ========
# Visualization saved to html/note_10773.html
# Processing Note 10774 ========
# Visualization saved to html/note_10774.html
# Processing Note 10775 ========
# Visualization saved to html/note_10775.html
# Processing Note 10776 ========
# Visualization saved to html/note_10776.html
# Processing Note 10777 ========
# Visualization saved to html/note_10777.html
# Processing Note 10778 ========
# Visualization saved to html/note_10778.html
# Processing Note 10779 ========
# Visualization saved to html/note_10779.html
# Processing Note 10780 ========
# Visualization saved to html/note_10780.html
# Processing Note 10781 ========
# Visualization saved to html/note_10781.html
# Processing Note 10782 ========
# Visualization saved to html/note_10782.html
# Processing Note 10783 ========
# Visualization saved to html/note_10783.html
# Processing Note 10784 ========
# Visualization saved to html/note_10784.html
# Processing Note 10785 ========
# Visualization saved to html/note_10785.html
# Processing Note 10786 ========
# Visualization saved to html/note_10786.html
# Processing Note 10787 ========
# Visualization saved to html/note_10787.html
# Processing Note 10788 ========
# Visualization saved to html/note_10788.html
# Processing Note 10789 ========
# Visualization saved to html/note_10789.html
# Processing Note 10790 ========
# Visualization saved to html/note_10790.html
# Processing Note 10791 ========
# Visualization saved to html/note_10791.html
# Processing Note 10792 ========
# Visualization saved to html/note_10792.html
# Processing Note 10793 ========
# Visualization saved to html/note_10793.html
# Processing Note 10794 ========
# Visualization saved to html/note_10794.html
# Processing Note 10795 ========
# Visualization saved to html/note_10795.html
# Processing Note 10796 ========
# Visualization saved to html/note_10796.html
# Processing Note 10797 ========
# Visualization saved to html/note_10797.html
# Processing Note 10798 ========
# Visualization saved to html/note_10798.html
# Processing Note 10799 ========
# Visualization saved to html/note_10799.html
# Processing Note 10800 ========
# Visualization saved to html/note_10800.html
# Processing Note 10801 ========
# Visualization saved to html/note_10801.html
# Processing Note 10802 ========
# Visualization saved to html/note_10802.html
# Processing Note 10803 ========
# Visualization saved to html/note_10803.html
# Processing Note 10804 ========
# Visualization saved to html/note_10804.html
# Processing Note 10805 ========
# Visualization saved to html/note_10805.html
# Processing Note 10806 ========
# Visualization saved to html/note_10806.html
# Processing Note 10807 ========
# Visualization saved to html/note_10807.html
# Processing Note 10808 ========
# Visualization saved to html/note_10808.html
# Processing Note 10809 ========
# Visualization saved to html/note_10809.html
# Processing Note 10810 ========
# Visualization saved to html/note_10810.html
# Processing Note 10811 ========
# Visualization saved to html/note_10811.html
# Processing Note 10812 ========
# Visualization saved to html/note_10812.html
# Processing Note 10813 ========
# Visualization saved to html/note_10813.html
# Processing Note 10814 ========
# Visualization saved to html/note_10814.html
# Processing Note 10815 ========
# Visualization saved to html/note_10815.html
# Processing Note 10816 ========
# Visualization saved to html/note_10816.html
# Processing Note 10817 ========
# Visualization saved to html/note_10817.html
# Processing Note 10818 ========
# Visualization saved to html/note_10818.html
# Processing Note 10819 ========
# Visualization saved to html/note_10819.html
# Processing Note 10820 ========
# Visualization saved to html/note_10820.html
# Processing Note 10821 ========
# Visualization saved to html/note_10821.html
